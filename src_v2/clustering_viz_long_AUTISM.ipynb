# %% [markdown]
# # CNN - AE model validation

# %%
import os
import csv
import random
import umap
import numpy as np
from os import path
from scipy import stats
from sklearn import preprocessing
from sklearn.manifold.t_sne import TSNE
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits import mplot3d
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
# data directories
homedir = os.path.expanduser('~')
prjdir = 'data1/stratification_ILRM'
datadir = 'data'
outdir = path.join(homedir, prjdir, datadir, 'neurodev-disorder')
expdir = path.join(homedir, prjdir, datadir, 'experiments/neurodev-disorder-2019-03-14-05-15-16-nobn-noact-norelu-10-l64')
# sub-sampling
n_samples = None

# get the list of diagnosed diseases associated with mrns
with open(path.join(outdir, 'cohort-mrn_diseases.csv')) as f:
    rd = csv.reader(f)
    mrn_disease = {r[0]: r[1::] for r in rd}

# evaluate potential disease classes

# read encoded vectors file and ordered medical record numbers
with open(path.join(expdir, 'mrns.csv')) as f:
    rd = csv.reader(f)
    mrns = [r[0] for r in rd]
    
# (1) first diagnosis
gt_disease = {}
for m in mrn_disease:
    if mrn_disease[m][0]!='pervasive developmental disorder' and m in mrns:
        gt_disease[m] = mrn_disease[m][0]
    else:
        pass

with open(path.join(expdir, 'encoded_vect.csv')) as f:
    rd = csv.reader(f)
    encoded = [list(map(float, r)) for r in rd]

tmp_mrns = []
tmp_encoded = []
for idx, m in enumerate(mrns):
    if m in gt_disease.keys():
        tmp_mrns.append(m)
        tmp_encoded.append(encoded[idx])
    else:
        pass
mrns = tmp_mrns
encoded = tmp_encoded

# %%
len(gt_disease)
# Out:
# 13031

# %%
set_mrns = set(mrns)
    
# read the vocabulary
with open(path.join(outdir, 'cohort-new_vocab.csv')) as f:    
    rd = csv.reader(f)
    next(rd)
    vocab = {r[1]: r[0] for r in rd}
len_vocab = len(vocab)

# read raw data
with open(path.join(outdir, 'cohort-new_ehr.csv')) as f:
    rd = csv.reader(f)
    raw_ehr = {}
    for r in rd:
        if r[0] in gt_disease.keys():
            raw_ehr.setdefault(r[0], list()).extend(list(map(int, r[1::])))

# raw data (scaled) counts
scaler = StandardScaler()
data = raw_ehr.values()
mrn_list = list(raw_ehr.keys())
raw_data = np.zeros((len(data), len_vocab))
for idx, token_list in enumerate(data):
    for t in token_list:
        raw_data[idx, t - 1] += 1

raw_data_scaled = scaler.fit_transform(raw_data)

# ##Read LSTM encoded vectors file and ordered medical record numbers
# with open(expdir + '/LSTMencoded_vect.csv') as f:
#     rd = csv.reader(f)
#     lstm_encoded_vect = []
#     for r in rd:
#         lstm_encoded_vect.append(list(map(float, r))) 
#     #svd = TruncatedSVD(lstm_encoded_vect, n_components=100)
#     #lstm_encoded_vect = svd.fit_transform(lstm_encoded_vect)
    
# with open(expdir + '/LSTMmrns.csv') as f:
#     rd = csv.reader(f)
#     lstm_mrns = []
#     for r in rd:
#         lstm_mrns.append(r[0])

# %%
# tmp_mrns = []
# tmp_encoded = []
# for idx, m in enumerate(lstm_mrns):
#     if m in gt_disease.keys():
#         tmp_mrns.append(m)
#         tmp_encoded.append(lstm_encoded_vect[idx])
#     else:
#         pass
# lstm_mrns = tmp_mrns
# lstm_encoded_vect = tmp_encoded

# %%
disease_count = {}
for d in gt_disease.values():
    if d not in disease_count:
        disease_count[d] = 1
    else:
        disease_count[d] += 1
print(len(gt_disease))
# Out:
# 13031

# %%
disease_count
# Out:
# {'OTH': 4894,
#  'attention deficit': 5924,
#  'autism': 814,
#  'mental retardation': 1399}

# %% [markdown]
# >`svd_tfidf():` returns the SVD matrix of the TFIDF matrix of the raw ehr data;
#
# >`silhouette_analysis():` hierarchical clustering on input data maximizing the Silhouette Index
#
# >`single_plot():` one plot of all the clusters
#
# >`nonoveralp_plot():` N different plots, one per cluster, with N = no. of clusters
#
# > `outer_clustering_analysis():` external validation of clustering (entropy and Purity scores)

# %%
# Hierarchical clustering parameters
# Frequency count analysis parameters
ehr_strat_model = False

if ehr_strat_model == True:
    HCpar = {'linkage_clu':'complete',
             'affinity_clu':'cosine',
             'min_cl':2,
             'max_cl':11}
else:
    HCpar = {'linkage_clu':'ward',
             'affinity_clu':'euclidean',
             'min_cl':2,
             'max_cl':11}
FRpar = {'n_terms':20,
        'ty_terms':['icd9', 'medication', 'lab', 'cpt', 'procedure']}

# %%
# analyze clustering using silhouette scores
def silhouette_analysis(data,
                        min_clu=HCpar['min_cl'],
                        max_clu=HCpar['max_cl'],
                       preproc=False):
    if preproc:
        data = preprocessing.scale(data)
    # bound analysis range
    if min_clu < 2:
        min_clu = 2

    # run analysis for every clustering size
    best_silh = 0
    silh_scores = []
    for n in range(min_clu, max_clu, 1):
        hclu = AgglomerativeClustering(n_clusters=n,
                                       linkage=HCpar['linkage_clu'],
                                       affinity=HCpar['affinity_clu'])
        lbl = hclu.fit_predict(data).tolist()
        silh = silhouette_score(data, lbl, metric=HCpar['affinity_clu'])
        if silh < 0:
            break
        print(' -- {0}: {1:.3f}'.format(n, silh))
        silh_scores.append(silh)
        if silh > best_silh:
            best_silh = silh
            n_clu = n
            label = lbl
    try:
        print('No. of clusters: {0} -- Silhouette Score: {1:.3f}\n'.format(
            n_clu, best_silh))

    except UnboundLocalError:
        hclu = AgglomerativeClustering(n_clusters=min_clu,
                                       linkage=HCpar['linkage_clu'],
                                       affinity=HCpar['affinity_clu'])
        n_clu = min_clu
        label = hclu.fit_predict(data).tolist()
        print('No. of Clusters: {0} -- Silhouette Score: {1:.3f}\n'.format(
            n_clu, best_silh))

    plt.plot(range(min_clu, max_clu, 1), silh_scores)
    return (n_clu, label, silh_scores)


# SVD matrix of the TFIDF matrix of the raw ehr data
def svd_tfidf(data, len_vocab, n_dimensions=200, tfidf=False):
    if tfidf:
    # apply tf-idf
        tfidf = TfidfTransformer()
        mtx = tfidf.fit_transform(data)
    else:
        scaler = MinMaxScaler()
        mtx = scaler.fit_transform(data)
    # reduce size of the matrix
    svd = TruncatedSVD(n_components=n_dimensions)
    svd_mtx = svd.fit_transform(mtx)

    return svd_mtx


# one plot with all the clusters
def single_plot(data, mrn_disease, colors):
    plt.figure(figsize=(20,10))
    for cl in set(mrn_disease):
        x = [d[0] for j, d in enumerate(data) if mrn_disease[j] == cl]
        y = [d[1] for j, d in enumerate(data) if mrn_disease[j] == cl]
        cols = [c for j, c in enumerate(colors) if mrn_disease[j] == cl]
        plt.xticks([])
        plt.yticks([])
        plt.scatter(x,y,c=cols, label=cl)
    plt.legend(loc=1)
#     plt.savefig(path.join(homedir, prjdir, datadir, 'neurodev-disorder/neurodev-data.png'))
 
    
# non-overlapping plots, one per cluster
def nonoverlap_plot(data, mrn_disease, colors):
    fig, ax = plt.subplots(len(set(mrn_disease)), 1, figsize=(20, 10*len(set(mrn_disease))))
    for idx, cl in enumerate(set(mrn_disease)):
        x = [d[0] for j, d in enumerate(data) if mrn_disease[j] == cl]
        y = [d[1] for j, d in enumerate(data) if mrn_disease[j] == cl]
        cols = [c for j, c in enumerate(colors) if mrn_disease[j] == cl]
        ax[idx].set_xticks([])
        ax[idx].set_yticks([])
        ax[idx].scatter(x, y, c=cols, label=cl)
        ax[idx].legend()

        
# external clustering analysis
def outer_clustering_analysis(data, gt_clu, preproc=False):
    
    if preproc:
        data = preprocessing.scale(data)
        
    label_clu = sorted(set(gt_clu))

    # format clustering ground truth
    didx = {d: i for i, d in enumerate(label_clu)}
    idxd = {i:d for d, i in didx.items()}
    gt = [didx[d] for d in gt_clu]

    # validate cluster number
    if len(label_clu) == 1:
        n_clu = 3
    else:
        n_clu = len(label_clu)

    # run clustering
    hclust = AgglomerativeClustering(n_clusters=n_clu,
                                     linkage=HCpar['linkage_clu'],
                                     affinity=HCpar['affinity_clu'])
    clusters = hclust.fit_predict(data).tolist()

    # count cluster occurrences
    cnt_clu = [0] * n_clu
    for c in clusters:
        cnt_clu[c] += 1
    class_clu = [[0] * n_clu for _ in range(len(label_clu))]
    for i, gi in enumerate(gt):
        class_clu[gi][clusters[i]] += 1

    # compute entropy and purity
    entropy = 0
    purity = 0
    for j in range(0, max(clusters) + 1):
        en = 0
        pu = []
        for i in range(0, max(gt) + 1):
            pij = class_clu[i][j] / cnt_clu[j]
            pu.append(pij)
            if pij != 0:
                en += -(pij * np.log2(pij))
        max_pu = max(pu)
        ds_max = []
        for idx, p in enumerate(pu):
            if p == max_pu:
                ds_max.append(idxd[idx])
        print(
            'Cluster: {0} -- '
            'Entropy: {1:.3f}, '
            'Purity: {2:.3f}'.format(j, en, max_pu))
        for d in ds_max:
            print("max(P) in cluster disease {0}".format(d))
        cweight = cnt_clu[j] / len(gt)
        entropy += cweight * en
        purity += cweight * max_pu

    print('Average Entropy: {0:.2f}'.format(entropy))
    print('Average Purity: {0:.2f}'.format(purity))
    
    return clusters

#Input: ehr lists corresponding to a cluster 
#Output: dictionary of term counts
def FreqDict(tokens):
    freq_dict = {}
    tok = []
    for seq in tokens:
        tok.extend(seq)
    
    tok = set(tok)
    for t in tok:
        for seq in tokens:
            if t in seq:
                if t not in freq_dict:
                    freq_dict[t] = 1
                else:
                    freq_dict[t] += 1
    return freq_dict
#Input: dictionary cluster:ehrs; list mrns
#Output:
def freq_term(data, pred_class):
    list_terms = []
    for subc in range(len(set(pred_class))):
        tmp_data = {}
        for j in range(len(pred_class)):
            if pred_class[j] == subc:
                tmp_data.setdefault(subc, list()).append([rd for rd in data[j] 
                                                           if rd!=0 and 
                                                           (str.split(vocab[str(rd)], "::")[0] 
                                                           in FRpar['ty_terms'])])
        print("Cluster {0} numerosity: {1}".format(subc, len(tmp_data[subc])))
        term_count = FreqDict(tmp_data[subc])
        clust_mostfreq = []
        for l in range(FRpar['n_terms']):
            try:
                MFMT = max(term_count, key=(lambda key: term_count[key]))
                num_MFMT = 0
                subc_termc = 0
                for ehr in tmp_data[subc]:
                    for e in ehr:
                        if e == MFMT:
                            subc_termc += 1
                for seq in raw_ehr.values():
                    for t in seq:
                        if t == MFMT:
                            num_MFMT += 1
                print("% most frequent term:{0} "
                       "= {1:.2f} ({2} out of {3} terms in the whole dataset"
                       "-- N patients in cluster {4})".format(vocab[str(MFMT)], 
                                                              subc_termc/num_MFMT, 
                                                              subc_termc,
                                                              num_MFMT,
                                                              term_count[MFMT]))
                term_count.pop(MFMT)
                clust_mostfreq.append(MFMT)
            except ValueError:
                pass
        print("\n")
        list_terms.append(clust_mostfreq)
    return list_terms

##Hierarchical clustering function. Max silhouette.
def hclust_ehr(data):
    best_silh = -1
    list_silh = []
    for nc in range(HCpar['min_cl'],HCpar['max_cl'],1):
        hclust = AgglomerativeClustering(n_clusters=nc, 
                                         linkage=HCpar['linkage_clu'], 
                                         affinity=HCpar['affinity_clu'])
        tmp_label = hclust.fit_predict(data).tolist()
        tmp_silh = silhouette_score(data, tmp_label, metric=HCpar['affinity_clu'])
        print(nc, tmp_silh)
        list_silh.append(float(tmp_silh))
        if tmp_silh > best_silh:
            best_silh = tmp_silh
            n_clust = nc
            label = tmp_label
    try:
        print("Number of clusters found:{0}, Silhouette score:{1:.3f}\n".format(n_clust, best_silh))
    except UnboundLocalError:
        hclust = AgglomerativeClustering(n_clusters=HCpar['min_cl'],
                                         linkage=HCpar['linkage_clu'],
                                         affinity=HCpar['affinity_clu'])
        n_clust = HCpar['min_cl']
        label = hclust.fit_predict(data).tolist()
        best_silh = silhouette_score(data, label)
        print("Number of clusters found:{0}, Silhouette score:{1:.3f}\n".format(n_clust, best_silh))
    return n_clust, label, list_silh

def chi_test(data, new_classes, term, mrns):
    count_mat = np.zeros((2, len(set(new_classes))), dtype=int)
    for c in set(new_classes):
        for idx, m in enumerate(mrns):
            if new_classes[idx] == c:
                if term in data[idx]:
                    count_mat[1][c] += 1
                else:
                    count_mat[0][c] += 1
    print("Count matrix:\n {0}".format(count_mat))
    chi2_stat, p_val, dof, ex = stats.chi2_contingency(count_mat)
    string = "Chi-squared test statistics: chi2_stat = {0} -- p_val = {1} -- dof = {2}".format(
                                                                  chi2_stat,
                                                                  p_val,
                                                                  dof)#row = classes, columns = vocab
    print(string)
    
##Internal clustering validation
def inner_clustering_analysis(disease_class, data, mrns, viz_data, preproc=False):
    if preproc:
        data = preprocessing.scale(data)
    dis_viz_data = []
    subclass_dis = []
    for dis in sorted(set(disease_class)):
        tmp_data = []
        tmp_mrn = []
        tmp_raw_ehr = []
        for idx, d in enumerate(disease_class):
            if d == dis:
                dis_viz_data.append(viz_data[idx])
                tmp_data.append(data[idx])
                tmp_mrn.append(mrns[idx])
                tmp_raw_ehr.append(raw_ehr[mrns[idx]])
        print("Inspecting disease: {0}\n".format(dis))
        n_clust, label, _ = hclust_ehr(tmp_data)
        subclass_dis.extend([dis + ': subclust ' + str(l) for l in label])
        list_terms = freq_term(tmp_raw_ehr, label)
        for l in range(len(set(label))):
            for lt in range(len(list_terms[l])):
                print("Odds ratio chi2 test for cluster {0}"
                      "term: {1}".format(l, vocab[str(list_terms[l][lt])]))
                try:
                    chi_test(tmp_raw_ehr, label, list_terms[l][lt], tmp_mrn)
                except ValueError:
                    print("empty class(es)")
                    pass
            print("\n\n")
    return(dis_viz_data, subclass_dis)

# %% [markdown]
# ## Run t-SNE for data visualization

# %%
# initialize T-SNE
reducer = umap.UMAP(n_neighbors=200, min_dist=0.5, metric = HCpar['affinity_clu'], n_components=2)
# tsne = TSNE(n_components=2, n_iter=5000, perplexity=40, random_state=42)

# %%
# plot colors
col_dict = matplotlib.colors.CSS4_COLORS
c_out = ['mintcream', 'cornsilk', 'lavenderblush', 'aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'powderblue', 'floralwhite', 'ghostwhite',
 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue',
 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'linen', 'palegoldenrod', 'palegreen', 'paleturquoise', 'palevioletred', 'papayawhip',
 'peachpuff', 'mistyrose', 'lemonchiffon', 'lightblue', 'seashell', 'white', 'blanchedalmond', 'oldlace', 'moccasin', 'snow', 'darkgray',
 'ivory', 'whitesmoke']
colormap = [c for c in col_dict if c not in c_out]

# %%
# t-SNE on the CNN encoded vectors
# encoded = preprocessing.scale(encoded)
encoded_umap = reducer.fit_transform(encoded).tolist()
# encoded_tsne = tsne.fit_transform(encoded).tolist()

print('Computed: CNN - AE encoded vectors umap')
# Out:
# Computed: CNN - AE encoded vectors umap

# %%
# t-SNE on the raw vectores
# raw_tsne = tsne.fit_transform(raw_data_scaled).tolist()
# print("Computed: raw count data t-SNE")

# %%
# t-SNE on the TF-IDF + SVD matrix
svd_mat = svd_tfidf(raw_data, len_vocab, n_dimensions = 100)
tfidf_umap = reducer.fit_transform(svd_mat).tolist()
# tfidf_tsne = tsne.fit_transform(svd_mat).tolist()
print("Computed: TF-IDF matrix umap")
# Out:
# Computed: TF-IDF matrix umap

# %%
# t-SNE on the LSTM encoded vectors
lstm_encoded_umap = reducer.fit_transform(lstm_encoded_vect).tolist()
# lstm_encoded_tsne = tsne.fit_transform(lstm_encoded_vect).tolist()
print("Computed LSTM encoded vectors umap")
# Out:
# Computed LSTM encoded vectors umap

# %% [markdown]
# ## t-SNE visualization and external clustering validation

# %%
# choose the disease classes: first_disease, oth_disease
disease_class_first = [gt_disease[m] for m in mrns]
raw_disease_class_first = [gt_disease[m] for m in mrn_list]
# lstm_disease_class_first = [gt_disease[m] for m in lstm_mrns]
disease_dict = {d: i for i, d in enumerate(set(disease_class_first))}

# %%
# dis_tmp = []
# for d in disease_class_first:
#     if d == 'mental retardation':
#         dis_tmp.append('intellectual disability')
#     elif d == 'pervasive developmental disorder':
#         dis_tmp.append('autism')
#     else:
#         dis_tmp.append(d)
# disease_class_first = dis_tmp

# dis_tmp = []
# for d in raw_disease_class_first:
#     if d == 'mental retardation':
#         dis_tmp.append('intellectual disability')
#     elif d == 'pervasive developmental disorder':
#         dis_tmp.append('autism')
#     else:
#         dis_tmp.append(d)
# raw_disease_class_first = dis_tmp

# disease_dict = {d: i for i, d in enumerate(set(disease_class_first))}

# %% [markdown]
# ### CNN - AE encodings

# %%
# plot data
colors_en1 = [colormap[disease_dict[v]] for v in disease_class_first]
single_plot(encoded_umap, disease_class_first, colors_en1)

# %%
# nonoverlap_plot(encoded_umap, disease_class_first, colors_en1)

# %%
# plot cluster results
clusters = outer_clustering_analysis(encoded, disease_class_first, preproc=False)
colors_en2 = [colormap[v] for v in clusters]
single_plot(encoded_umap, clusters, colors_en2)
for i in range(len(set(clusters))):
    print("Cluster numerosity:{0}".format(clusters.count(i)))
# Out:
# Cluster: 0 -- Entropy: 1.632, Purity: 0.506
# max(P) in cluster disease OTH
# Cluster: 1 -- Entropy: 1.229, Purity: 0.722
# max(P) in cluster disease attention deficit
# Cluster: 2 -- Entropy: 1.594, Purity: 0.584
# max(P) in cluster disease attention deficit
# Cluster: 3 -- Entropy: 1.393, Purity: 0.517
# max(P) in cluster disease OTH
# Average Entropy: 1.47
# Average Purity: 0.57
# Cluster numerosity:4923
# Cluster numerosity:3107
# Cluster numerosity:1957
# Cluster numerosity:3044

# %%
 _, _, _ = silhouette_analysis(encoded, preproc=False)
# Out:
#  -- 2: 0.097
#  -- 3: 0.072
#  -- 4: 0.075
#  -- 5: 0.064
#  -- 6: 0.068
#  -- 7: 0.071
#  -- 8: 0.060
#  -- 9: 0.064
#  -- 10: 0.047
# No. of clusters: 2 -- Silhouette Score: 0.097

# %%
# inner clustering analysis
encoded_subplots, en_sub_clust = inner_clustering_analysis(disease_class_first, encoded, mrns, 
                                                           encoded_umap, preproc=False)
# Out:
# Inspecting disease: OTH
#
# 2 0.10577868631938932
# 3 0.10833470825638439
# 4 0.09016164604725373
# 5 0.08823771858194639
# 6 0.06294038422087037
# 7 0.06966787465785412
# 8 0.07234577090468708
# 9 0.056617050608153974
# 10 0.0564484827187463
# Number of clusters found:3, Silhouette score:0.108
#
# Cluster 0 numerosity: 1913
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.44 (4254 out of 9732 terms in the whole dataset-- N patients in cluster 895)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.35 (1292 out of 3689 terms in the whole dataset-- N patients in cluster 768)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.26 (1754 out of 6708 terms in the whole dataset-- N patients in cluster 761)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.34 (1646 out of 4828 terms in the whole dataset-- N patients in cluster 751)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.32 (1290 out of 4018 terms in the whole dataset-- N patients in cluster 748)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.12 (1268 out of 10191 terms in the whole dataset-- N patients in cluster 654)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.34 (895 out of 2616 terms in the whole dataset-- N patients in cluster 597)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.47 (2302 out of 4897 terms in the whole dataset-- N patients in cluster 577)
# % most frequent term:medication::Midazolam::6960::C0026056 = 0.37 (780 out of 2105 terms in the whole dataset-- N patients in cluster 547)
# % most frequent term:medication::Cefazolin::2180::C0007546 = 0.40 (721 out of 1814 terms in the whole dataset-- N patients in cluster 499)
# % most frequent term:medication::Morphine::7052::C0026549 = 0.35 (713 out of 2009 terms in the whole dataset-- N patients in cluster 456)
# % most frequent term:medication::Aspirin::1191::C0004057 = 0.59 (857 out of 1459 terms in the whole dataset-- N patients in cluster 416)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.51 (848 out of 1649 terms in the whole dataset-- N patients in cluster 412)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.41 (2537 out of 6138 terms in the whole dataset-- N patients in cluster 399)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.20 (730 out of 3709 terms in the whole dataset-- N patients in cluster 391)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.10 (678 out of 6543 terms in the whole dataset-- N patients in cluster 372)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.41 (1190 out of 2909 terms in the whole dataset-- N patients in cluster 366)
# % most frequent term:medication::Heparin::5224::C0019134 = 0.33 (759 out of 2307 terms in the whole dataset-- N patients in cluster 361)
# % most frequent term:medication::Potassium chloride::8591::C0032825 = 0.42 (670 out of 1582 terms in the whole dataset-- N patients in cluster 357)
# % most frequent term:icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134 = 0.74 (769 out of 1046 terms in the whole dataset-- N patients in cluster 352)
#
#
# Cluster 1 numerosity: 2435
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.06 (621 out of 10191 terms in the whole dataset-- N patients in cluster 363)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.06 (548 out of 9732 terms in the whole dataset-- N patients in cluster 264)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.06 (402 out of 6708 terms in the whole dataset-- N patients in cluster 259)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.08 (397 out of 4921 terms in the whole dataset-- N patients in cluster 233)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.06 (542 out of 8472 terms in the whole dataset-- N patients in cluster 231)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.09 (364 out of 4272 terms in the whole dataset-- N patients in cluster 213)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.05 (545 out of 11994 terms in the whole dataset-- N patients in cluster 208)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.08 (343 out of 4418 terms in the whole dataset-- N patients in cluster 206)
# % most frequent term:icd9::Accidents occurring in unspecified place::E849.9::C0261380 = 0.10 (249 out of 2588 terms in the whole dataset-- N patients in cluster 204)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.09 (439 out of 4828 terms in the whole dataset-- N patients in cluster 197)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.06 (399 out of 7169 terms in the whole dataset-- N patients in cluster 190)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.06 (858 out of 13823 terms in the whole dataset-- N patients in cluster 182)
# % most frequent term:medication::Nasal spray::126542::C0461725 = 0.08 (261 out of 3223 terms in the whole dataset-- N patients in cluster 178)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.06 (252 out of 4018 terms in the whole dataset-- N patients in cluster 171)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.06 (383 out of 6292 terms in the whole dataset-- N patients in cluster 157)
# % most frequent term:icd9::Other malaise and fatigue::780.79::C0695252 = 0.09 (226 out of 2405 terms in the whole dataset-- N patients in cluster 152)
# % most frequent term:icd9::Headache::784.0::n/a = 0.09 (248 out of 2777 terms in the whole dataset-- N patients in cluster 151)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.05 (202 out of 3689 terms in the whole dataset-- N patients in cluster 147)
# % most frequent term:icd9::Abdominal pain, unspecified site::789.00::C0000737 = 0.09 (224 out of 2449 terms in the whole dataset-- N patients in cluster 146)
# % most frequent term:medication::Fluticasone::41126::C0082607 = 0.07 (260 out of 3813 terms in the whole dataset-- N patients in cluster 145)
#
#
# Cluster 2 numerosity: 546
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.07 (342 out of 4828 terms in the whole dataset-- N patients in cluster 213)
# % most frequent term:icd9::Supervision of other normal pregnancy::V22.1::C0038843 = 0.38 (722 out of 1901 terms in the whole dataset-- N patients in cluster 210)
# % most frequent term:medication::Oxytocin::7824::C0030095 = 0.44 (252 out of 567 terms in the whole dataset-- N patients in cluster 185)
# % most frequent term:icd9::Outcome of delivery, single liveborn::V27.0::C1313895 = 0.44 (269 out of 605 terms in the whole dataset-- N patients in cluster 183)
# % most frequent term:icd9::Routine gynecological examination::V72.31::C1455982 = 0.20 (428 out of 2124 terms in the whole dataset-- N patients in cluster 175)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.03 (211 out of 6543 terms in the whole dataset-- N patients in cluster 156)
# % most frequent term:medication::Zolpidem::39993::C0078839 = 0.09 (200 out of 2200 terms in the whole dataset-- N patients in cluster 145)
# % most frequent term:icd9::Other general counseling and advice on contraceptive management::V25.09::C0029624 = 0.16 (617 out of 3943 terms in the whole dataset-- N patients in cluster 143)
# % most frequent term:medication::Ibuprofen::5640::C0020740 = 0.11 (178 out of 1655 terms in the whole dataset-- N patients in cluster 129)
# % most frequent term:icd9::Human immunodeficiency virus (hiv) counseling::V65.44::C0476681 = 0.20 (251 out of 1242 terms in the whole dataset-- N patients in cluster 125)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.02 (205 out of 10191 terms in the whole dataset-- N patients in cluster 125)
# % most frequent term:medication::Ketorolac::35827::C0073631 = 0.13 (165 out of 1285 terms in the whole dataset-- N patients in cluster 118)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.02 (164 out of 6708 terms in the whole dataset-- N patients in cluster 116)
# % most frequent term:medication::LRW = 0.51 (132 out of 259 terms in the whole dataset-- N patients in cluster 106)
# % most frequent term:icd9::Supervision of normal first pregnancy::V22.0::C0260550 = 0.31 (345 out of 1096 terms in the whole dataset-- N patients in cluster 103)
# % most frequent term:medication::Iron::90176::C0302583 = 0.05 (129 out of 2438 terms in the whole dataset-- N patients in cluster 100)
# % most frequent term:medication::Docusate sodium 100 mg::1099278::C3153447 = 0.05 (133 out of 2490 terms in the whole dataset-- N patients in cluster 97)
# % most frequent term:medication::ZZ IMS TEMPLATE = 0.05 (124 out of 2329 terms in the whole dataset-- N patients in cluster 96)
# % most frequent term:medication::Rubella virus vaccine::9486::C0035923 = 0.60 (123 out of 205 terms in the whole dataset-- N patients in cluster 94)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.02 (123 out of 7169 terms in the whole dataset-- N patients in cluster 93)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[1018 2171  532]
#  [ 895  264   14]]
# Chi-squared test statistics: chi2_stat = 914.0032185964109 -- p_val = 3.362968975968792e-199 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[1145 2288  455]
#  [ 768  147   91]]
# Chi-squared test statistics: chi2_stat = 768.9589588377787 -- p_val = 1.0536192174909047e-167 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[1152 2176  430]
#  [ 761  259  116]]
# Chi-squared test statistics: chi2_stat = 511.853335657621 -- p_val = 7.119678618276347e-112 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[1162 2238  333]
#  [ 751  197  213]]
# Chi-squared test statistics: chi2_stat = 654.5046769671386 -- p_val = 7.518223058138221e-143 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[1165 2264  453]
#  [ 748  171   93]]
# Chi-squared test statistics: chi2_stat = 677.0870433630379 -- p_val = 9.384619085233819e-148 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1259 2072  421]
#  [ 654  363  125]]
# Chi-squared test statistics: chi2_stat = 222.6625381396609 -- p_val = 4.461122816284514e-49 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[1316 2313  507]
#  [ 597  122   39]]
# Chi-squared test statistics: chi2_stat = 594.4129772929458 -- p_val = 8.411278154457734e-130 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[1336 2311  540]
#  [ 577  124    6]]
# Chi-squared test statistics: chi2_stat = 633.3722011663228 -- p_val = 2.917252503914149e-138 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Midazolam::6960::C0026056
# Count matrix:
#  [[1366 2340  511]
#  [ 547   95   35]]
# Chi-squared test statistics: chi2_stat = 576.4168968726651 -- p_val = 6.802384965540778e-126 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Cefazolin::2180::C0007546
# Count matrix:
#  [[1414 2360  482]
#  [ 499   75   64]]
# Chi-squared test statistics: chi2_stat = 501.0400617208295 -- p_val = 1.5868394583008217e-109 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Morphine::7052::C0026549
# Count matrix:
#  [[1457 2348  484]
#  [ 456   87   62]]
# Chi-squared test statistics: chi2_stat = 406.6363516895414 -- p_val = 5.0123127318199014e-89 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Aspirin::1191::C0004057
# Count matrix:
#  [[1497 2391  540]
#  [ 416   44    6]]
# Chi-squared test statistics: chi2_stat = 544.9930760518037 -- p_val = 4.531658740667555e-119 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[1501 2353  541]
#  [ 412   82    5]]
# Chi-squared test statistics: chi2_stat = 444.0561419688802 -- p_val = 3.7534785974216523e-97 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[1514 2350  540]
#  [ 399   85    6]]
# Chi-squared test statistics: chi2_stat = 412.812445297068 -- p_val = 2.285159262244282e-90 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Acetaminophen 325 mg::315263::C0982952
# Count matrix:
#  [[1522 2302  485]
#  [ 391  133   61]]
# Chi-squared test statistics: chi2_stat = 228.69260354802387 -- p_val = 2.1879234019346074e-50 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[1541 2311  390]
#  [ 372  124  156]]
# Chi-squared test statistics: chi2_stat = 314.8929616364874 -- p_val = 4.1866069065021936e-69 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[1547 2374  542]
#  [ 366   61    4]]
# Chi-squared test statistics: chi2_stat = 418.6786750202382 -- p_val = 1.2164124992043154e-91 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Heparin::5224::C0019134
# Count matrix:
#  [[1552 2377  541]
#  [ 361   58    5]]
# Chi-squared test statistics: chi2_stat = 414.7215034409184 -- p_val = 8.797712477897507e-91 -- dof = 2
# Odds ratio chi2 test for cluster 0term: medication::Potassium chloride::8591::C0032825
# Count matrix:
#  [[1556 2398  539]
#  [ 357   37    7]]
# Chi-squared test statistics: chi2_stat = 457.5409773385351 -- p_val = 4.428321552181619e-100 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134
# Count matrix:
#  [[1561 2400  546]
#  [ 352   35    0]]
# Chi-squared test statistics: chi2_stat = 476.08332146137036 -- p_val = 4.1669691153740616e-104 -- dof = 2
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1259 2072  421]
#  [ 654  363  125]]
# Chi-squared test statistics: chi2_stat = 222.6625381396609 -- p_val = 4.461122816284514e-49 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[1018 2171  532]
#  [ 895  264   14]]
# Chi-squared test statistics: chi2_stat = 914.0032185964109 -- p_val = 3.362968975968792e-199 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[1152 2176  430]
#  [ 761  259  116]]
# Chi-squared test statistics: chi2_stat = 511.853335657621 -- p_val = 7.119678618276347e-112 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[1771 2202  530]
#  [ 142  233   16]]
# Chi-squared test statistics: chi2_stat = 28.107441250763976 -- p_val = 7.880371327796292e-07 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[1667 2204  492]
#  [ 246  231   54]]
# Chi-squared test statistics: chi2_stat = 13.184424342187574 -- p_val = 0.0013710037117245285 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[1714 2222  488]
#  [ 199  213   58]]
# Chi-squared test statistics: chi2_stat = 4.115693024774819 -- p_val = 0.12772873618688196 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1738 2227  514]
#  [ 175  208   32]]
# Chi-squared test statistics: chi2_stat = 5.938256724516863 -- p_val = 0.05134804772804083 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[1837 2229  530]
#  [  76  206   16]]
# Chi-squared test statistics: chi2_stat = 48.44495578380102 -- p_val = 3.022118667758233e-11 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Accidents occurring in unspecified place::E849.9::C0261380
# Count matrix:
#  [[1847 2231  531]
#  [  66  204   15]]
# Chi-squared test statistics: chi2_stat = 58.03891622372436 -- p_val = 2.494649147474197e-13 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[1162 2238  333]
#  [ 751  197  213]]
# Chi-squared test statistics: chi2_stat = 654.5046769671386 -- p_val = 7.518223058138221e-143 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[1718 2245  453]
#  [ 195  190   93]]
# Chi-squared test statistics: chi2_stat = 43.76121599293444 -- p_val = 3.143204853768148e-10 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[1908 2253  536]
#  [   5  182   10]]
# Chi-squared test statistics: chi2_stat = 151.93187678177952 -- p_val = 1.0195584872131598e-33 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Nasal spray::126542::C0461725
# Count matrix:
#  [[1772 2257  536]
#  [ 141  178   10]]
# Chi-squared test statistics: chi2_stat = 23.4515991482262 -- p_val = 8.082578830895991e-06 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[1165 2264  453]
#  [ 748  171   93]]
# Chi-squared test statistics: chi2_stat = 677.0870433630379 -- p_val = 9.384619085233819e-148 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Albuterol sulfate::142153::C0543495
# Count matrix:
#  [[1732 2278  528]
#  [ 181  157   18]]
# Chi-squared test statistics: chi2_stat = 28.84264699151008 -- p_val = 5.456306824943539e-07 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Other malaise and fatigue::780.79::C0695252
# Count matrix:
#  [[1694 2283  516]
#  [ 219  152   30]]
# Chi-squared test statistics: chi2_stat = 44.547005754597116 -- p_val = 2.1219766845472142e-10 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Headache::784.0::n/a
# Count matrix:
#  [[1819 2284  522]
#  [  94  151   24]]
# Chi-squared test statistics: chi2_stat = 4.852769753053562 -- p_val = 0.08835567257807891 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[1145 2288  455]
#  [ 768  147   91]]
# Chi-squared test statistics: chi2_stat = 768.9589588377787 -- p_val = 1.0536192174909047e-167 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Abdominal pain, unspecified site::789.00::C0000737
# Count matrix:
#  [[1783 2289  512]
#  [ 130  146   34]]
# Chi-squared test statistics: chi2_stat = 1.1667274078534695 -- p_val = 0.5580181981688869 -- dof = 2
# Odds ratio chi2 test for cluster 1term: medication::Fluticasone::41126::C0082607
# Count matrix:
#  [[1743 2290  536]
#  [ 170  145   10]]
# Chi-squared test statistics: chi2_stat = 37.77967758586172 -- p_val = 6.255287111693894e-09 -- dof = 2
#
#
#
# Odds ratio chi2 test for cluster 2term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[1162 2238  333]
#  [ 751  197  213]]
# Chi-squared test statistics: chi2_stat = 654.5046769671386 -- p_val = 7.518223058138221e-143 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Supervision of other normal pregnancy::V22.1::C0038843
# Count matrix:
#  [[1887 2408  336]
#  [  26   27  210]]
# Chi-squared test statistics: chi2_stat = 1323.2399988689185 -- p_val = 4.592880319380172e-288 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Oxytocin::7824::C0030095
# Count matrix:
#  [[1895 2426  361]
#  [  18    9  185]]
# Chi-squared test statistics: chi2_stat = 1295.846279044969 -- p_val = 4.079019748530461e-282 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Outcome of delivery, single liveborn::V27.0::C1313895
# Count matrix:
#  [[1893 2398  363]
#  [  20   37  183]]
# Chi-squared test statistics: chi2_stat = 1079.387368780297 -- p_val = 4.111600889321198e-235 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Routine gynecological examination::V72.31::C1455982
# Count matrix:
#  [[1838 2330  371]
#  [  75  105  175]]
# Chi-squared test statistics: chi2_stat = 561.9673276043703 -- p_val = 9.339966225142352e-123 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[1541 2311  390]
#  [ 372  124  156]]
# Chi-squared test statistics: chi2_stat = 314.8929616364874 -- p_val = 4.1866069065021936e-69 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Zolpidem::39993::C0078839
# Count matrix:
#  [[1645 2384  401]
#  [ 268   51  145]]
# Chi-squared test statistics: chi2_stat = 386.0229196120768 -- p_val = 1.500334383295112e-84 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Other general counseling and advice on contraceptive management::V25.09::C0029624
# Count matrix:
#  [[1905 2373  403]
#  [   8   62  143]]
# Chi-squared test statistics: chi2_stat = 715.7159330311333 -- p_val = 3.839368851508467e-156 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Ibuprofen::5640::C0020740
# Count matrix:
#  [[1831 2371  417]
#  [  82   64  129]]
# Chi-squared test statistics: chi2_stat = 381.3127006714024 -- p_val = 1.5812447966063942e-83 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Human immunodeficiency virus (hiv) counseling::V65.44::C0476681
# Count matrix:
#  [[1909 2398  421]
#  [   4   37  125]]
# Chi-squared test statistics: chi2_stat = 718.8968624561699 -- p_val = 7.825818816048058e-157 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1259 2072  421]
#  [ 654  363  125]]
# Chi-squared test statistics: chi2_stat = 222.6625381396609 -- p_val = 4.461122816284514e-49 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Ketorolac::35827::C0073631
# Count matrix:
#  [[1656 2369  428]
#  [ 257   66  118]]
# Chi-squared test statistics: chi2_stat = 269.28108885871546 -- p_val = 3.3601178820090505e-59 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[1152 2176  430]
#  [ 761  259  116]]
# Chi-squared test statistics: chi2_stat = 511.853335657621 -- p_val = 7.119678618276347e-112 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::LRW
# Count matrix:
#  [[1890 2430  440]
#  [  23    5  106]]
# Chi-squared test statistics: chi2_stat = 645.7404067531027 -- p_val = 6.015230897319023e-141 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Supervision of normal first pregnancy::V22.0::C0260550
# Count matrix:
#  [[1908 2423  443]
#  [   5   12  103]]
# Chi-squared test statistics: chi2_stat = 692.3578942274341 -- p_val = 4.533081397205728e-151 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Iron::90176::C0302583
# Count matrix:
#  [[1736 2346  446]
#  [ 177   89  100]]
# Chi-squared test statistics: chi2_stat = 152.81138799039263 -- p_val = 6.567932970296974e-34 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Docusate sodium 100 mg::1099278::C3153447
# Count matrix:
#  [[1633 2369  449]
#  [ 280   66   97]]
# Chi-squared test statistics: chi2_stat = 241.7767155285814 -- p_val = 3.1539390522288456e-53 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::ZZ IMS TEMPLATE
# Count matrix:
#  [[1789 2394  450]
#  [ 124   41   96]]
# Chi-squared test statistics: chi2_stat = 231.50403874647037 -- p_val = 5.36459223997198e-51 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Rubella virus vaccine::9486::C0035923
# Count matrix:
#  [[1901 2431  452]
#  [  12    4   94]]
# Chi-squared test statistics: chi2_stat = 627.7541518613384 -- p_val = 4.8408087772935575e-137 -- dof = 2
# Odds ratio chi2 test for cluster 2term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[1718 2245  453]
#  [ 195  190   93]]
# Chi-squared test statistics: chi2_stat = 43.76121599293444 -- p_val = 3.143204853768148e-10 -- dof = 2
#
#
#
# Inspecting disease: attention deficit
#
# 2 0.09082755109270901
# 3 0.0923612329851659
# 4 0.09026937540189794
# 5 0.09461145111445864
# 6 0.08037043994237211
# 7 0.08589489455897571
# 8 0.07141983557049798
# 9 0.04893069370171076
# 10 0.052181413377229056
# Number of clusters found:5, Silhouette score:0.095
#
# Cluster 0 numerosity: 1970
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.20 (9453 out of 46765 terms in the whole dataset-- N patients in cluster 1551)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.45 (4204 out of 9379 terms in the whole dataset-- N patients in cluster 954)
# % most frequent term:medication::Dextroamphetamine::3288::C0011812 = 0.69 (6254 out of 9086 terms in the whole dataset-- N patients in cluster 756)
# % most frequent term:medication::Amphetamine::725::C0002658 = 0.68 (5950 out of 8795 terms in the whole dataset-- N patients in cluster 745)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.35 (1500 out of 4272 terms in the whole dataset-- N patients in cluster 603)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.15 (1262 out of 8472 terms in the whole dataset-- N patients in cluster 576)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.13 (1293 out of 10191 terms in the whole dataset-- N patients in cluster 562)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.30 (2351 out of 7751 terms in the whole dataset-- N patients in cluster 504)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.32 (2122 out of 6557 terms in the whole dataset-- N patients in cluster 504)
# % most frequent term:medication::Methylphenidate::6901::C0025810 = 0.28 (2350 out of 8507 terms in the whole dataset-- N patients in cluster 470)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.26 (1270 out of 4828 terms in the whole dataset-- N patients in cluster 419)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.15 (1022 out of 6708 terms in the whole dataset-- N patients in cluster 411)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.16 (1144 out of 7169 terms in the whole dataset-- N patients in cluster 408)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.21 (842 out of 4018 terms in the whole dataset-- N patients in cluster 386)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.14 (937 out of 6543 terms in the whole dataset-- N patients in cluster 380)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.14 (1630 out of 11994 terms in the whole dataset-- N patients in cluster 365)
# % most frequent term:medication::Nasal spray::126542::C0461725 = 0.21 (683 out of 3223 terms in the whole dataset-- N patients in cluster 343)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.13 (581 out of 4418 terms in the whole dataset-- N patients in cluster 334)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.07 (1018 out of 13823 terms in the whole dataset-- N patients in cluster 331)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.18 (667 out of 3689 terms in the whole dataset-- N patients in cluster 329)
#
#
# Cluster 1 numerosity: 1355
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.08 (3832 out of 46765 terms in the whole dataset-- N patients in cluster 1064)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.18 (1653 out of 9379 terms in the whole dataset-- N patients in cluster 577)
# % most frequent term:medication::Methylphenidate::6901::C0025810 = 0.04 (374 out of 8507 terms in the whole dataset-- N patients in cluster 203)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.03 (198 out of 6732 terms in the whole dataset-- N patients in cluster 118)
# % most frequent term:medication::Dextroamphetamine::3288::C0011812 = 0.02 (203 out of 9086 terms in the whole dataset-- N patients in cluster 110)
# % most frequent term:medication::Amphetamine::725::C0002658 = 0.02 (196 out of 8795 terms in the whole dataset-- N patients in cluster 106)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.03 (181 out of 6557 terms in the whole dataset-- N patients in cluster 85)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.03 (153 out of 5092 terms in the whole dataset-- N patients in cluster 85)
# % most frequent term:medication::Dexmethylphenidate::352372::C1169997 = 0.11 (173 out of 1582 terms in the whole dataset-- N patients in cluster 81)
# % most frequent term:icd9::Other unknown and unspecified cause of morbidity and mortality::799.9::C0476465 = 0.14 (75 out of 543 terms in the whole dataset-- N patients in cluster 72)
# % most frequent term:medication::Lisdexamfetamine::700810::C1873633 = 0.07 (214 out of 2989 terms in the whole dataset-- N patients in cluster 70)
# % most frequent term:icd9::Other specific developmental learning difficulties::315.2::C0338982 = 0.13 (126 out of 1006 terms in the whole dataset-- N patients in cluster 70)
# % most frequent term:icd9::Unspecified delay in development::315.9::n/a = 0.03 (101 out of 3002 terms in the whole dataset-- N patients in cluster 60)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.01 (71 out of 6543 terms in the whole dataset-- N patients in cluster 58)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.01 (103 out of 13823 terms in the whole dataset-- N patients in cluster 58)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.01 (65 out of 10191 terms in the whole dataset-- N patients in cluster 56)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.01 (64 out of 6042 terms in the whole dataset-- N patients in cluster 51)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.01 (70 out of 11994 terms in the whole dataset-- N patients in cluster 49)
# % most frequent term:medication::Guanfacine::40114::C0079466 = 0.06 (72 out of 1111 terms in the whole dataset-- N patients in cluster 46)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.01 (52 out of 7751 terms in the whole dataset-- N patients in cluster 38)
#
#
# Cluster 2 numerosity: 1156
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.38 (17885 out of 46765 terms in the whole dataset-- N patients in cluster 1128)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.32 (2063 out of 6543 terms in the whole dataset-- N patients in cluster 680)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.56 (3367 out of 6042 terms in the whole dataset-- N patients in cluster 618)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.63 (4242 out of 6732 terms in the whole dataset-- N patients in cluster 587)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.42 (2121 out of 5092 terms in the whole dataset-- N patients in cluster 514)
# % most frequent term:medication::Methylphenidate::6901::C0025810 = 0.32 (2730 out of 8507 terms in the whole dataset-- N patients in cluster 485)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.11 (1119 out of 10191 terms in the whole dataset-- N patients in cluster 458)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.32 (2502 out of 7751 terms in the whole dataset-- N patients in cluster 415)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.17 (1572 out of 9379 terms in the whole dataset-- N patients in cluster 401)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.09 (1115 out of 11994 terms in the whole dataset-- N patients in cluster 366)
# % most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.16 (934 out of 5663 terms in the whole dataset-- N patients in cluster 358)
# % most frequent term:medication::Chlorpromazine::2403::C0008286 = 0.54 (840 out of 1559 terms in the whole dataset-- N patients in cluster 311)
# % most frequent term:icd9::Counseling for parent-child problem, unspecified::V61.20::C0375882 = 0.54 (1979 out of 3673 terms in the whole dataset-- N patients in cluster 288)
# % most frequent term:medication::Risperidone::35636::C0073393 = 0.51 (847 out of 1659 terms in the whole dataset-- N patients in cluster 281)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.26 (1734 out of 6557 terms in the whole dataset-- N patients in cluster 270)
# % most frequent term:icd9::Other and unspecified special symptoms or syndromes, not elsewhere classified::307.9::C0302371 = 0.34 (477 out of 1389 terms in the whole dataset-- N patients in cluster 232)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.10 (388 out of 3709 terms in the whole dataset-- N patients in cluster 223)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.08 (1122 out of 13823 terms in the whole dataset-- N patients in cluster 219)
# % most frequent term:medication::Amphetamine::725::C0002658 = 0.14 (1258 out of 8795 terms in the whole dataset-- N patients in cluster 190)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.05 (349 out of 7169 terms in the whole dataset-- N patients in cluster 190)
#
#
# Cluster 3 numerosity: 1270
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.30 (13828 out of 46765 terms in the whole dataset-- N patients in cluster 1164)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.55 (7638 out of 13823 terms in the whole dataset-- N patients in cluster 948)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.36 (3066 out of 8472 terms in the whole dataset-- N patients in cluster 795)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.43 (1907 out of 4418 terms in the whole dataset-- N patients in cluster 648)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.38 (1892 out of 4921 terms in the whole dataset-- N patients in cluster 619)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.41 (4912 out of 11994 terms in the whole dataset-- N patients in cluster 605)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.39 (2821 out of 7169 terms in the whole dataset-- N patients in cluster 571)
# % most frequent term:icd9::Acute pharyngitis::462::C0001344 = 0.46 (1278 out of 2769 terms in the whole dataset-- N patients in cluster 546)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.38 (722 out of 1876 terms in the whole dataset-- N patients in cluster 538)
# % most frequent term:icd9::Unspecified viral infection::079.99::C0153114 = 0.48 (1039 out of 2185 terms in the whole dataset-- N patients in cluster 520)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.22 (2202 out of 10191 terms in the whole dataset-- N patients in cluster 517)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.40 (2507 out of 6292 terms in the whole dataset-- N patients in cluster 513)
# % most frequent term:icd9::Rash and other nonspecific skin eruption::782.1::C0015230 = 0.34 (943 out of 2759 terms in the whole dataset-- N patients in cluster 496)
# % most frequent term:icd9::Allergic rhinitis, cause unspecified::477.9::C2607914 = 0.50 (2234 out of 4471 terms in the whole dataset-- N patients in cluster 479)
# % most frequent term:icd9::Accidents occurring in unspecified place::E849.9::C0261380 = 0.31 (796 out of 2588 terms in the whole dataset-- N patients in cluster 456)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.42 (2120 out of 5092 terms in the whole dataset-- N patients in cluster 446)
# % most frequent term:medication::Nasal spray::126542::C0461725 = 0.36 (1156 out of 3223 terms in the whole dataset-- N patients in cluster 444)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against other viral diseases::V04.89::C1260454 = 0.48 (1025 out of 2117 terms in the whole dataset-- N patients in cluster 444)
# % most frequent term:medication::Albuterol::435::C0001927 = 0.36 (1649 out of 4518 terms in the whole dataset-- N patients in cluster 437)
# % most frequent term:icd9::Other specified vaccination::V03.89::C0478550 = 0.49 (477 out of 974 terms in the whole dataset-- N patients in cluster 427)
#
#
# Cluster 4 numerosity: 173
# % most frequent term:icd9::Short stature::783.43::C0349588 = 0.63 (1914 out of 3049 terms in the whole dataset-- N patients in cluster 147)
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.02 (1030 out of 46765 terms in the whole dataset-- N patients in cluster 131)
# % most frequent term:medication::Cartridge::1649572::C4018981 = 0.66 (498 out of 752 terms in the whole dataset-- N patients in cluster 85)
# % most frequent term:medication::Somatropin::61148::C0169964 = 0.70 (190 out of 272 terms in the whole dataset-- N patients in cluster 69)
# % most frequent term:icd9::Pituitary dwarfism::253.3::C0013338 = 0.75 (665 out of 892 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:medication::Arginine::1091::C0003765 = 0.32 (57 out of 176 terms in the whole dataset-- N patients in cluster 55)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.05 (451 out of 9379 terms in the whole dataset-- N patients in cluster 54)
# % most frequent term:medication::Pen injector::1649571::C4025916 = 0.27 (270 out of 993 terms in the whole dataset-- N patients in cluster 50)
# % most frequent term:medication::Levodopa::6375::C0023570 = 0.31 (48 out of 154 terms in the whole dataset-- N patients in cluster 47)
# % most frequent term:icd9::Precocious sexual development and puberty, not elsewhere classified::259.1::C0869515 = 0.45 (420 out of 928 terms in the whole dataset-- N patients in cluster 46)
# % most frequent term:icd9::Unspecified vitamin d deficiency::268.9::C0042870 = 0.10 (295 out of 2959 terms in the whole dataset-- N patients in cluster 43)
# % most frequent term:medication::Methylphenidate::6901::C0025810 = 0.01 (126 out of 8507 terms in the whole dataset-- N patients in cluster 42)
# % most frequent term:icd9::Esophageal reflux::530.81::C0017168 = 0.07 (330 out of 4622 terms in the whole dataset-- N patients in cluster 35)
# % most frequent term:medication::Vitamin d3::1244014::C3265062 = 0.11 (236 out of 2147 terms in the whole dataset-- N patients in cluster 35)
# % most frequent term:medication::Cholecalciferol::2418::C0008318 = 0.16 (235 out of 1460 terms in the whole dataset-- N patients in cluster 34)
# % most frequent term:medication::Norditropin::202829::C0699617 = 0.76 (225 out of 297 terms in the whole dataset-- N patients in cluster 32)
# % most frequent term:icd9::Failure to thrive::783.41::C0015544 = 0.18 (267 out of 1521 terms in the whole dataset-- N patients in cluster 31)
# % most frequent term:medication::Nutropin::202831::C0699619 = 0.88 (224 out of 254 terms in the whole dataset-- N patients in cluster 31)
# % most frequent term:icd9::Other specified congenital anomalies::759.89::C0478095 = 0.54 (434 out of 800 terms in the whole dataset-- N patients in cluster 29)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.00 (31 out of 10191 terms in the whole dataset-- N patients in cluster 28)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 419  291   28  106   42]
#  [1551 1064 1128 1164  131]]
# Chi-squared test statistics: chi2_stat = 305.23240052278226 -- p_val = 8.054960145542478e-65 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[1016  778  755  846  119]
#  [ 954  577  401  424   54]]
# Chi-squared test statistics: chi2_stat = 102.64060570776842 -- p_val = 2.694920202914987e-21 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Dextroamphetamine::3288::C0011812
# Count matrix:
#  [[1214 1245  987 1051  154]
#  [ 756  110  169  219   19]]
# Chi-squared test statistics: chi2_stat = 533.7783211358724 -- p_val = 3.307237829399745e-114 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Amphetamine::725::C0002658
# Count matrix:
#  [[1225 1249  966 1056  154]
#  [ 745  106  190  214   19]]
# Chi-squared test statistics: chi2_stat = 506.0351269657715 -- p_val = 3.3168978801133176e-108 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[1367 1320 1065 1013  170]
#  [ 603   35   91  257    3]]
# Chi-squared test statistics: chi2_stat = 572.2624168458334 -- p_val = 1.5591054165567696e-122 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[1394 1335  998  475  168]
#  [ 576   20  158  795    5]]
# Chi-squared test statistics: chi2_stat = 1449.3188209092903 -- p_val = 0.0 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1408 1299  698  753  145]
#  [ 562   56  458  517   28]]
# Chi-squared test statistics: chi2_stat = 581.2854484551206 -- p_val = 1.7390809945705979e-124 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[1466 1317  741 1073  169]
#  [ 504   38  415  197    4]]
# Chi-squared test statistics: chi2_stat = 529.5571759417871 -- p_val = 2.7079479215952645e-113 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[1466 1270  886 1072  157]
#  [ 504   85  270  198   16]]
# Chi-squared test statistics: chi2_stat = 238.23861022260837 -- p_val = 2.222060673260234e-50 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Methylphenidate::6901::C0025810
# Count matrix:
#  [[1500 1152  671  888  131]
#  [ 470  203  485  382   42]]
# Chi-squared test statistics: chi2_stat = 248.56033539298235 -- p_val = 1.3295090117981903e-52 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[1551 1351 1109 1195  171]
#  [ 419    4   47   75    2]]
# Chi-squared test statistics: chi2_stat = 536.739538650838 -- p_val = 7.565522491045127e-115 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[1559 1348 1058 1067  165]
#  [ 411    7   98  203    8]]
# Chi-squared test statistics: chi2_stat = 350.0863844950633 -- p_val = 1.6800675643054326e-74 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[1562 1331  966  699  163]
#  [ 408   24  190  571   10]]
# Chi-squared test statistics: chi2_stat = 798.103899533735 -- p_val = 1.977227376018033e-171 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[1584 1350 1088 1081  160]
#  [ 386    5   68  189   13]]
# Chi-squared test statistics: chi2_stat = 353.0740357745522 -- p_val = 3.8039622692371195e-75 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[1590 1297  476  966  169]
#  [ 380   58  680  304    4]]
# Chi-squared test statistics: chi2_stat = 1123.7108325878896 -- p_val = 5.491486568366582e-242 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1605 1306  790  665  157]
#  [ 365   49  366  605   16]]
# Chi-squared test statistics: chi2_stat = 795.4779910765213 -- p_val = 7.325507384722789e-171 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Nasal spray::126542::C0461725
# Count matrix:
#  [[1627 1335 1103  826  167]
#  [ 343   20   53  444    6]]
# Chi-squared test statistics: chi2_stat = 731.3427336194617 -- p_val = 5.6914143160195855e-157 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[1636 1337 1003  622  169]
#  [ 334   18  153  648    4]]
# Chi-squared test statistics: chi2_stat = 1157.2215986068838 -- p_val = 2.989917199926638e-249 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[1639 1297  937  322  165]
#  [ 331   58  219  948    8]]
# Chi-squared test statistics: chi2_stat = 2031.2179105186137 -- p_val = 0.0 -- dof = 4
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[1641 1345 1090 1082  163]
#  [ 329   10   66  188   10]]
# Chi-squared test statistics: chi2_stat = 282.35935927060416 -- p_val = 6.906876790575392e-60 -- dof = 4
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 419  291   28  106   42]
#  [1551 1064 1128 1164  131]]
# Chi-squared test statistics: chi2_stat = 305.23240052278226 -- p_val = 8.054960145542478e-65 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[1016  778  755  846  119]
#  [ 954  577  401  424   54]]
# Chi-squared test statistics: chi2_stat = 102.64060570776842 -- p_val = 2.694920202914987e-21 -- dof = 4
# Odds ratio chi2 test for cluster 1term: medication::Methylphenidate::6901::C0025810
# Count matrix:
#  [[1500 1152  671  888  131]
#  [ 470  203  485  382   42]]
# Chi-squared test statistics: chi2_stat = 248.56033539298235 -- p_val = 1.3295090117981903e-52 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Oppositional defiant disorder::313.81::C0029121
# Count matrix:
#  [[1807 1237  569  990  170]
#  [ 163  118  587  280    3]]
# Chi-squared test statistics: chi2_stat = 1021.9762995288133 -- p_val = 6.164901591648108e-220 -- dof = 4
# Odds ratio chi2 test for cluster 1term: medication::Dextroamphetamine::3288::C0011812
# Count matrix:
#  [[1214 1245  987 1051  154]
#  [ 756  110  169  219   19]]
# Chi-squared test statistics: chi2_stat = 533.7783211358724 -- p_val = 3.307237829399745e-114 -- dof = 4
# Odds ratio chi2 test for cluster 1term: medication::Amphetamine::725::C0002658
# Count matrix:
#  [[1225 1249  966 1056  154]
#  [ 745  106  190  214   19]]
# Chi-squared test statistics: chi2_stat = 506.0351269657715 -- p_val = 3.3168978801133176e-108 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[1466 1270  886 1072  157]
#  [ 504   85  270  198   16]]
# Chi-squared test statistics: chi2_stat = 238.23861022260837 -- p_val = 2.222060673260234e-50 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified disturbance of conduct::312.9::C0149654
# ...
#  [108  27]]
# Chi-squared test statistics: chi2_stat = 50.051626237615146 -- p_val = 1.4975362839070758e-12 -- dof = 1
#
#
#
# Inspecting disease: mental retardation
#
# 2 0.2779384909010813
# 3 0.16591193793370548
# 4 0.14590481079676612
# 5 0.13422845454326585
# 6 0.0686922100549301
# 7 0.06592206943040883
# 8 0.06510882608916153
# 9 0.07151174488618636
# 10 0.0671614861735196
# Number of clusters found:2, Silhouette score:0.278
#
# Cluster 0 numerosity: 1226
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.90 (5381 out of 6009 terms in the whole dataset-- N patients in cluster 997)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.25 (2547 out of 10191 terms in the whole dataset-- N patients in cluster 639)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.35 (2335 out of 6708 terms in the whole dataset-- N patients in cluster 581)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.29 (1082 out of 3709 terms in the whole dataset-- N patients in cluster 438)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.19 (1576 out of 8472 terms in the whole dataset-- N patients in cluster 435)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.75 (3679 out of 4911 terms in the whole dataset-- N patients in cluster 415)
# % most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.35 (1989 out of 5663 terms in the whole dataset-- N patients in cluster 412)
# % most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.69 (2508 out of 3658 terms in the whole dataset-- N patients in cluster 406)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.19 (1266 out of 6543 terms in the whole dataset-- N patients in cluster 400)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.19 (776 out of 4018 terms in the whole dataset-- N patients in cluster 386)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.45 (2051 out of 4607 terms in the whole dataset-- N patients in cluster 383)
# % most frequent term:icd9::Severe intellectual disabilities::318.1::C0036857 = 0.92 (1287 out of 1398 terms in the whole dataset-- N patients in cluster 373)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.20 (734 out of 3689 terms in the whole dataset-- N patients in cluster 367)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.31 (3046 out of 9732 terms in the whole dataset-- N patients in cluster 358)
# % most frequent term:icd9::Mild intellectual disabilities::317::C0026106 = 0.81 (1830 out of 2260 terms in the whole dataset-- N patients in cluster 350)
# % most frequent term:icd9::Profound intellectual disabilities::318.2::C3161330 = 0.98 (2143 out of 2187 terms in the whole dataset-- N patients in cluster 349)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.23 (601 out of 2616 terms in the whole dataset-- N patients in cluster 343)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.19 (912 out of 4921 terms in the whole dataset-- N patients in cluster 342)
# % most frequent term:icd9::Infantile cerebral palsy, unspecified::343.9::C0392549 = 0.95 (3199 out of 3369 terms in the whole dataset-- N patients in cluster 330)
# % most frequent term:medication::Oral powder::346289::C1160731 = 0.43 (1015 out of 2367 terms in the whole dataset-- N patients in cluster 328)
#
#
# Cluster 1 numerosity: 173
# % most frequent term:icd9::Family history of intellectual disabilities::V18.4::C0260530 = 0.91 (318 out of 349 terms in the whole dataset-- N patients in cluster 145)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.06 (281 out of 4828 terms in the whole dataset-- N patients in cluster 119)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.03 (197 out of 6543 terms in the whole dataset-- N patients in cluster 115)
# % most frequent term:icd9::Supervision of other normal pregnancy::V22.1::C0038843 = 0.34 (651 out of 1901 terms in the whole dataset-- N patients in cluster 110)
# % most frequent term:medication::Oxytocin::7824::C0030095 = 0.29 (167 out of 567 terms in the whole dataset-- N patients in cluster 110)
# % most frequent term:medication::Zolpidem::39993::C0078839 = 0.07 (159 out of 2200 terms in the whole dataset-- N patients in cluster 109)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.03 (200 out of 6708 terms in the whole dataset-- N patients in cluster 109)
# % most frequent term:medication::Ketorolac::35827::C0073631 = 0.12 (159 out of 1285 terms in the whole dataset-- N patients in cluster 108)
# % most frequent term:medication::Docusate sodium 100 mg::1099278::C3153447 = 0.07 (169 out of 2490 terms in the whole dataset-- N patients in cluster 107)
# % most frequent term:icd9::Outcome of delivery, single liveborn::V27.0::C1313895 = 0.26 (157 out of 605 terms in the whole dataset-- N patients in cluster 102)
# % most frequent term:medication::ZZ IMS TEMPLATE = 0.06 (136 out of 2329 terms in the whole dataset-- N patients in cluster 101)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.03 (203 out of 7169 terms in the whole dataset-- N patients in cluster 98)
# % most frequent term:medication::Oral drops::317002::C0991577 = 0.11 (119 out of 1097 terms in the whole dataset-- N patients in cluster 98)
# % most frequent term:medication::Simethicone 40 mg::316668::C0989909 = 0.32 (118 out of 368 terms in the whole dataset-- N patients in cluster 98)
# % most frequent term:medication::Menthol::6750::C0025368 = 0.26 (104 out of 406 terms in the whole dataset-- N patients in cluster 91)
# % most frequent term:medication::Benzocaine::1399::C0005059 = 0.25 (104 out of 423 terms in the whole dataset-- N patients in cluster 90)
# % most frequent term:icd9::Encounter for routine screening for malformation using ultrasonics::V28.3::C2349862 = 0.40 (138 out of 348 terms in the whole dataset-- N patients in cluster 85)
# % most frequent term:medication::Iron::90176::C0302583 = 0.07 (160 out of 2438 terms in the whole dataset-- N patients in cluster 84)
# % most frequent term:icd9::Screening for genetic disease carrier status::V82.71::C1719700 = 0.84 (164 out of 195 terms in the whole dataset-- N patients in cluster 80)
# % most frequent term:icd9::Other investigation and testing::V26.29::C0878723 = 0.90 (162 out of 181 terms in the whole dataset-- N patients in cluster 75)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[229 152]
#  [997  21]]
# Chi-squared test statistics: chi2_stat = 362.6813898992896 -- p_val = 7.340488357113336e-81 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[587 123]
#  [639  50]]
# Chi-squared test statistics: chi2_stat = 31.778786652895647 -- p_val = 1.727694714041234e-08 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[645  64]
#  [581 109]]
# Chi-squared test statistics: chi2_stat = 14.172681355906011 -- p_val = 0.0001667743951593848 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Acetaminophen 325 mg::315263::C0982952
# Count matrix:
#  [[788 118]
#  [438  55]]
# Chi-squared test statistics: chi2_stat = 0.8629868820560505 -- p_val = 0.352904181617424 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[791 113]
#  [435  60]]
# Chi-squared test statistics: chi2_stat = 0.014607975792353914 -- p_val = 0.9037991851993099 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[811 168]
#  [415   5]]
# Chi-squared test statistics: chi2_stat = 67.7040626244772 -- p_val = 1.8997169985125823e-16 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841
# Count matrix:
#  [[814 160]
#  [412  13]]
# Chi-squared test statistics: chi2_stat = 47.56974138946492 -- p_val = 5.30815111685755e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other convulsions::780.39::C0490011
# Count matrix:
#  [[820 172]
#  [406   1]]
# Chi-squared test statistics: chi2_stat = 76.23868879275 -- p_val = 2.513683775606234e-18 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[826  58]
#  [400 115]]
# Chi-squared test statistics: chi2_stat = 73.22253910507244 -- p_val = 1.1582550871962246e-17 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[840 103]
#  [386  70]]
# Chi-squared test statistics: chi2_stat = 5.160855047781537 -- p_val = 0.023101521448977192 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[843 163]
#  [383  10]]
# Chi-squared test statistics: chi2_stat = 47.39547498233914 -- p_val = 5.801645762225811e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Severe intellectual disabilities::318.1::C0036857
# Count matrix:
#  [[853 173]
#  [373   0]]
# Chi-squared test statistics: chi2_stat = 70.22113317604612 -- p_val = 5.3015426931114857e-17 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[859 103]
#  [367  70]]
# Chi-squared test statistics: chi2_stat = 7.340363930322033 -- p_val = 0.006742318802492922 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[868 165]
#  [358   8]]
# Chi-squared test statistics: chi2_stat = 46.139583541362526 -- p_val = 1.1012093793002504e-11 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Mild intellectual disabilities::317::C0026106
# Count matrix:
#  [[876 157]
#  [350  16]]
# Chi-squared test statistics: chi2_stat = 28.242097732363174 -- p_val = 1.0705077736951232e-07 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Profound intellectual disabilities::318.2::C3161330
# Count matrix:
#  [[877 172]
#  [349   1]]
# Chi-squared test statistics: chi2_stat = 61.38028914109253 -- p_val = 4.704972224403001e-15 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[883 140]
#  [343  33]]
# Chi-squared test statistics: chi2_stat = 5.668616585305636 -- p_val = 0.017271071243820938 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[884 158]
#  [342  15]]
# Chi-squared test statistics: chi2_stat = 28.47900282521811 -- p_val = 9.472016602217524e-08 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Infantile cerebral palsy, unspecified::343.9::C0392549
# Count matrix:
#  [[896 172]
#  [330   1]]
# Chi-squared test statistics: chi2_stat = 56.780768613367485 -- p_val = 4.872078204677315e-14 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Oral powder::346289::C1160731
# Count matrix:
#  [[898 165]
#  [328   8]]
# Chi-squared test statistics: chi2_stat = 39.48012348103944 -- p_val = 3.314156407085822e-10 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Family history of intellectual disabilities::V18.4::C0260530
# Count matrix:
#  [[1213   28]
#  [  13  145]]
# Chi-squared test statistics: chi2_stat = 1028.1156196251459 -- p_val = 1.390040667605851e-225 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[960  54]
#  [266 119]]
# Chi-squared test statistics: chi2_stat = 166.18813422664806 -- p_val = 5.032342039691841e-38 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[826  58]
#  [400 115]]
# Chi-squared test statistics: chi2_stat = 73.22253910507244 -- p_val = 1.1582550871962246e-17 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Supervision of other normal pregnancy::V22.1::C0038843
# Count matrix:
#  [[1220   63]
#  [   6  110]]
# Chi-squared test statistics: chi2_stat = 785.4154235689564 -- p_val = 7.99920672048757e-173 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Oxytocin::7824::C0030095
# Count matrix:
#  [[1222   63]
#  [   4  110]]
# Chi-squared test statistics: chi2_stat = 802.10407261199 -- p_val = 1.8819089610819506e-176 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Zolpidem::39993::C0078839
# Count matrix:
#  [[1160   64]
#  [  66  109]]
# Chi-squared test statistics: chi2_stat = 454.7075643920569 -- p_val = 6.817592079022247e-101 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[645  64]
#  [581 109]]
# Chi-squared test statistics: chi2_stat = 14.172681355906011 -- p_val = 0.0001667743951593848 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Ketorolac::35827::C0073631
# Count matrix:
#  [[1102   65]
#  [ 124  108]]
# Chi-squared test statistics: chi2_stat = 296.16293432875153 -- p_val = 2.2581688941407025e-66 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Docusate sodium 100 mg::1099278::C3153447
# Count matrix:
#  [[934  66]
#  [292 107]]
# Chi-squared test statistics: chi2_stat = 105.71203218122429 -- p_val = 8.526805453498186e-25 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Outcome of delivery, single liveborn::V27.0::C1313895
# Count matrix:
#  [[1222   71]
#  [   4  102]]
# Chi-squared test statistics: chi2_stat = 735.9337960659566 -- p_val = 4.591337449717981e-162 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::ZZ IMS TEMPLATE
# Count matrix:
#  [[1002   72]
#  [ 224  101]]
# Chi-squared test statistics: chi2_stat = 134.52900289938555 -- p_val = 4.185621321634592e-31 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[996  75]
#  [230  98]]
# Chi-squared test statistics: chi2_stat = 119.1467155988292 -- p_val = 9.726283312741688e-28 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Oral drops::317002::C0991577
# Count matrix:
#  [[1158   75]
#  [  68   98]]
# Chi-squared test statistics: chi2_stat = 373.69420943279886 -- p_val = 2.9367085532034133e-83 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Simethicone 40 mg::316668::C0989909
# Count matrix:
#  [[1206   75]
#  [  20   98]]
# Chi-squared test statistics: chi2_stat = 587.0564556593147 -- p_val = 1.0943943422724043e-129 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Menthol::6750::C0025368
# Count matrix:
#  [[1191   82]
#  [  35   91]]
# Chi-squared test statistics: chi2_stat = 451.7519804930216 -- p_val = 2.9980424465869747e-100 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Benzocaine::1399::C0005059
# Count matrix:
#  [[1195   83]
#  [  31   90]]
# Chi-squared test statistics: chi2_stat = 463.81644014767596 -- p_val = 7.101913043664627e-103 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Encounter for routine screening for malformation using ultrasonics::V28.3::C2349862
# Count matrix:
#  [[1222   88]
#  [   4   85]]
# Chi-squared test statistics: chi2_stat = 598.0842507373035 -- p_val = 4.370094637011116e-132 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Iron::90176::C0302583
# Count matrix:
#  [[1018   89]
#  [ 208   84]]
# Chi-squared test statistics: chi2_stat = 89.69831319634247 -- p_val = 2.7739142481807082e-21 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Screening for genetic disease carrier status::V82.71::C1719700
# Count matrix:
#  [[1222   93]
#  [   4   80]]
# Chi-squared test statistics: chi2_stat = 558.2461643986401 -- p_val = 2.0236635431783733e-123 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other investigation and testing::V26.29::C0878723
# Count matrix:
#  [[1225   98]
#  [   1   75]]
# Chi-squared test statistics: chi2_stat = 544.1641251942501 -- p_val = 2.3417592069167528e-120 -- dof = 1

# %%
encoded_new_disease_dict = {}
for idx, nd in enumerate(set(en_sub_clust)):
    encoded_new_disease_dict[nd] = idx
colors_en3 = [colormap[encoded_new_disease_dict[v]] for v in en_sub_clust]
single_plot(encoded_subplots, en_sub_clust, colors_en3)

# %%
# nonoverlap_plot(encoded_subplots, en_sub_clust, colors_en3)

# %% [markdown]
# ### Raw Counts

# %%
# plot data
# colors_raw1 = [colormap[disease_dict[v]] for v in disease_class_first]
# single_plot(raw_tsne, disease_class_first, colors_raw1)

# plot cluster results
# clusters = outer_clustering_analysis(raw_data_scaled, gt_disease.values())
# colors_raw2 = [colormap[v] for v in clusters]
# single_plot(raw_tsne, clusters, colors_raw2)

# %% [markdown]
# ### Tfidf matrix

# %%
# plot data
colors_tfidf1 = [colormap[disease_dict[v]] for v in raw_disease_class_first]
single_plot(tfidf_umap, raw_disease_class_first, colors_tfidf1)

# nonoverlap_plot(tfidf_umap, disease_class_first, colors_en1)

# plot cluster results
clusters = outer_clustering_analysis(svd_mat, raw_disease_class_first)
colors_tfidf2 = [colormap[v] for v in clusters]
single_plot(tfidf_umap, clusters, colors_tfidf2)
for i in range(len(set(clusters))):
    print("Cluster numerosity:{0}".format(clusters.count(i)))
    
_,_,_ = silhouette_analysis(svd_mat)

tfidf_subplots, tfidf_sub_clust = inner_clustering_analysis(raw_disease_class_first, svd_mat, 
                                                            mrn_list, tfidf_umap)

tfidf_new_disease_dict = {}
for idx, nd in enumerate(set(tfidf_sub_clust)):
    tfidf_new_disease_dict[nd] = idx
colors_count3 = [colormap[tfidf_new_disease_dict[v]] for v in tfidf_sub_clust]
single_plot(tfidf_subplots, tfidf_sub_clust, colors_count3)
# Out:
# Cluster: 0 -- Entropy: 1.706, Purity: 0.410
# max(P) in cluster disease mental retardation
# Cluster: 1 -- Entropy: 1.587, Purity: 0.455
# max(P) in cluster disease attention deficit
# Cluster: 2 -- Entropy: 1.483, Purity: 0.513
# max(P) in cluster disease autism
# Cluster: 3 -- Entropy: 1.239, Purity: 0.739
# max(P) in cluster disease attention deficit
# Average Entropy: 1.58
# Average Purity: 0.47
# Cluster numerosity:944
# Cluster numerosity:11311
# Cluster numerosity:113
# Cluster numerosity:663
#  -- 2: 0.597
#  -- 3: 0.595
#  -- 4: 0.581
#  -- 5: 0.576
#  -- 6: 0.515
#  -- 7: 0.515
#  -- 8: 0.515
#  -- 9: 0.518
#  -- 10: 0.520
# No. of clusters: 2 -- Silhouette Score: 0.597
#
# Inspecting disease: OTH
#
# 2 0.9491890941061404
# 3 0.9479440236178482
# 4 0.9464790146648145
# 5 0.7052206893181767
# 6 0.5543837657286406
# 7 0.5544698381339661
# 8 0.5577297244763834
# 9 0.5587859180035019
# 10 0.5669905594005593
# Number of clusters found:2, Silhouette score:0.949
#
# Cluster 0 numerosity: 4
# % most frequent term:medication::Glucagon::4832::C0017687 = 0.08 (87 out of 1130 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::LANCETS = 0.04 (17 out of 451 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.00 (24 out of 6292 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.02 (154 out of 9732 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.03 (121 out of 4828 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Hydromorphone::3423::C0012306 = 0.03 (34 out of 1286 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.00 (18 out of 8472 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::ALCOHOL SWABS = 0.08 (30 out of 363 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.01 (16 out of 2616 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Levofloxacin 750 mg::330371::C1126013 = 0.07 (9 out of 125 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Water::11295::C0043047 = 0.04 (40 out of 891 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Generalized pain::780.96::n/a = 0.22 (66 out of 300 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Urinary tract infection, site not specified::599.0::C0042029 = 0.06 (98 out of 1642 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.04 (58 out of 1649 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Sulbactam::10167::C0038665 = 0.08 (26 out of 312 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.04 (250 out of 6138 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Polyneuropathy in diabetes::357.2::C0271680 = 0.13 (17 out of 126 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134 = 0.03 (36 out of 1046 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, uncontrolled::250.02::C0375115 = 0.11 (83 out of 777 terms in the whole dataset-- N patients in cluster 4)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.03 (110 out of 3689 terms in the whole dataset-- N patients in cluster 4)
#
#
# Cluster 1 numerosity: 4890
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.48 (4672 out of 9732 terms in the whole dataset-- N patients in cluster 1169)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.48 (2306 out of 4828 terms in the whole dataset-- N patients in cluster 1157)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.20 (2027 out of 10191 terms in the whole dataset-- N patients in cluster 1138)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.33 (2227 out of 6708 terms in the whole dataset-- N patients in cluster 1132)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.41 (1650 out of 4018 terms in the whole dataset-- N patients in cluster 1008)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.40 (1490 out of 3689 terms in the whole dataset-- N patients in cluster 1002)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.41 (1070 out of 2616 terms in the whole dataset-- N patients in cluster 754)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.50 (2430 out of 4897 terms in the whole dataset-- N patients in cluster 704)
# % most frequent term:medication::Midazolam::6960::C0026056 = 0.43 (913 out of 2105 terms in the whole dataset-- N patients in cluster 674)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.17 (1081 out of 6543 terms in the whole dataset-- N patients in cluster 648)
# % most frequent term:medication::Cefazolin::2180::C0007546 = 0.48 (869 out of 1814 terms in the whole dataset-- N patients in cluster 634)
# % most frequent term:medication::Morphine::7052::C0026549 = 0.44 (890 out of 2009 terms in the whole dataset-- N patients in cluster 601)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.27 (1009 out of 3709 terms in the whole dataset-- N patients in cluster 582)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.14 (1170 out of 8472 terms in the whole dataset-- N patients in cluster 527)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.54 (886 out of 1649 terms in the whole dataset-- N patients in cluster 495)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.40 (2481 out of 6138 terms in the whole dataset-- N patients in cluster 486)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.15 (1061 out of 7169 terms in the whole dataset-- N patients in cluster 475)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.23 (984 out of 4272 terms in the whole dataset-- N patients in cluster 468)
# % most frequent term:medication::Zolpidem::39993::C0078839 = 0.36 (803 out of 2200 terms in the whole dataset-- N patients in cluster 462)
# % most frequent term:medication::Aspirin::1191::C0004057 = 0.58 (847 out of 1459 terms in the whole dataset-- N patients in cluster 462)
#
#
# Odds ratio chi2 test for cluster 0term: medication::Glucagon::4832::C0017687
# Count matrix:
#  [[   0 4639]
#  [   4  251]]
# Chi-squared test statistics: chi2_stat = 54.88677640154631 -- p_val = 1.2767716360049112e-13 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::LANCETS
# Count matrix:
#  [[   0 4844]
#  [   4   46]]
# Chi-squared test statistics: chi2_stat = 296.0626252058077 -- p_val = 2.374714153727153e-66 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Albuterol sulfate::142153::C0543495
# Count matrix:
#  [[   0 4538]
#  [   4  352]]
# Chi-squared test statistics: chi2_stat = 38.19939692435984 -- p_val = 6.387215845098497e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[   0 3721]
#  [   4 1169]]
# Chi-squared test statistics: chi2_stat = 8.866836514628053 -- p_val = 0.002903979472108381 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[   0 3733]
#  [   4 1157]]
# Chi-squared test statistics: chi2_stat = 8.998746098392155 -- p_val = 0.0027016490758868233 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Hydromorphone::3423::C0012306
# Count matrix:
#  [[   0 4533]
#  [   4  357]]
# Chi-squared test statistics: chi2_stat = 37.61588115589347 -- p_val = 8.614028558827002e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[   0 4363]
#  [   4  527]]
# Chi-squared test statistics: chi2_stat = 24.315733787718308 -- p_val = 8.176842938891104e-07 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::ALCOHOL SWABS
# Count matrix:
#  [[   0 4863]
#  [   4   27]]
# Chi-squared test statistics: chi2_stat = 479.935001123942 -- p_val = 2.2074317391247226e-106 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[   0 4136]
#  [   4  754]]
# Chi-squared test statistics: chi2_stat = 15.859839147400256 -- p_val = 6.821095926151492e-05 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Levofloxacin 750 mg::330371::C1126013
# Count matrix:
#  [[   0 4861]
#  [   4   29]]
# Chi-squared test statistics: chi2_stat = 450.6092498578281 -- p_val = 5.315280055753022e-100 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Water::11295::C0043047
# Count matrix:
#  [[   0 4683]
#  [   4  207]]
# Chi-squared test statistics: chi2_stat = 67.15278478204984 -- p_val = 2.5126013644127564e-16 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Generalized pain::780.96::n/a
# Count matrix:
#  [[   0 4852]
#  [   4   38]]
# Chi-squared test statistics: chi2_stat = 353.2058925131402 -- p_val = 8.492196785082481e-79 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Urinary tract infection, site not specified::599.0::C0042029
# Count matrix:
#  [[   0 4636]
#  [   4  254]]
# Chi-squared test statistics: chi2_stat = 54.20281841904472 -- p_val = 1.808272964535483e-13 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[   0 4395]
#  [   4  495]]
# Chi-squared test statistics: chi2_stat = 26.12677190022425 -- p_val = 3.1972014730417113e-07 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Sulbactam::10167::C0038665
# Count matrix:
#  [[   0 4825]
#  [   4   65]]
# Chi-squared test statistics: chi2_stat = 213.45343482053863 -- p_val = 2.423554170471424e-48 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[   0 4404]
#  [   4  486]]
# Chi-squared test statistics: chi2_stat = 26.678759184808754 -- p_val = 2.4024808748530096e-07 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Polyneuropathy in diabetes::357.2::C0271680
# Count matrix:
#  [[   0 4863]
#  [   4   27]]
# Chi-squared test statistics: chi2_stat = 479.935001123942 -- p_val = 2.2074317391247226e-106 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134
# Count matrix:
#  [[   0 4507]
#  [   4  383]]
# Chi-squared test statistics: chi2_stat = 34.824688995410476 -- p_val = 3.6076935631761905e-09 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, uncontrolled::250.02::C0375115
# Count matrix:
#  [[   0 4813]
#  [   4   77]]
# Chi-squared test statistics: chi2_stat = 181.24718394459384 -- p_val = 2.5888956401452206e-41 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[   0 3888]
#  [   4 1002]]
# Chi-squared test statistics: chi2_stat = 10.986134917349858 -- p_val = 0.0009179605115611435 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[   0 3721]
#  [   4 1169]]
# Chi-squared test statistics: chi2_stat = 8.866836514628053 -- p_val = 0.002903979472108381 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[   0 3733]
#  [   4 1157]]
# Chi-squared test statistics: chi2_stat = 8.998746098392155 -- p_val = 0.0027016490758868233 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[   0 3752]
#  [   4 1138]]
# Chi-squared test statistics: chi2_stat = 9.213287259548338 -- p_val = 0.0024026488333341624 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[   0 3758]
#  [   4 1132]]
# Chi-squared test statistics: chi2_stat = 9.282531831873102 -- p_val = 0.002313494364487509 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[   0 3882]
#  [   4 1008]]
# Chi-squared test statistics: chi2_stat = 10.897853423463204 -- p_val = 0.0009627576466065087 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[   0 3888]
#  [   4 1002]]
# Chi-squared test statistics: chi2_stat = 10.986134917349858 -- p_val = 0.0009179605115611435 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[   0 4136]
#  [   4  754]]
# Chi-squared test statistics: chi2_stat = 15.859839147400256 -- p_val = 6.821095926151492e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[   1 4186]
#  [   3  704]]
# Chi-squared test statistics: chi2_stat = 7.479542391006258 -- p_val = 0.006240392973128075 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Midazolam::6960::C0026056
# Count matrix:
#  [[   1 4216]
#  [   3  674]]
# Chi-squared test statistics: chi2_stat = 7.954541927527304 -- p_val = 0.0047966847665345735 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[   0 4242]
#  [   4  648]]
# Chi-squared test statistics: chi2_stat = 19.07523537271233 -- p_val = 1.2566500107520688e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Cefazolin::2180::C0007546
# Count matrix:
#  [[   0 4256]
#  [   4  634]]
# Chi-squared test statistics: chi2_stat = 19.57983934858391 -- p_val = 9.648195097101912e-06 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Morphine::7052::C0026549
# Count matrix:
#  [[   0 4289]
#  [   4  601]]
# Chi-squared test statistics: chi2_stat = 20.861714114347084 -- p_val = 4.9366384991487715e-06 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Acetaminophen 325 mg::315263::C0982952
# Count matrix:
#  [[   1 4308]
#  [   3  582]]
# Chi-squared test statistics: chi2_stat = 9.718390629233184 -- p_val = 0.001824331981330457 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[   0 4363]
#  [   4  527]]
# Chi-squared test statistics: chi2_stat = 24.315733787718308 -- p_val = 8.176842938891104e-07 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[   0 4395]
#  [   4  495]]
# Chi-squared test statistics: chi2_stat = 26.12677190022425 -- p_val = 3.1972014730417113e-07 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[   0 4404]
#  [   4  486]]
# Chi-squared test statistics: chi2_stat = 26.678759184808754 -- p_val = 2.4024808748530096e-07 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[   1 4415]
#  [   3  475]]
# Chi-squared test statistics: chi2_stat = 12.631356945795726 -- p_val = 0.0003793297270185676 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[   2 4422]
#  [   2  468]]
# Chi-squared test statistics: chi2_stat = 3.5886118873124953 -- p_val = 0.05817681913498519 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Zolpidem::39993::C0078839
# Count matrix:
#  [[   2 4428]
#  [   2  462]]
# Chi-squared test statistics: chi2_stat = 3.6620702536343672 -- p_val = 0.0556644263599348 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aspirin::1191::C0004057
# Count matrix:
#  [[   0 4428]
#  [   4  462]]
# Chi-squared test statistics: chi2_stat = 28.254992928220396 -- p_val = 1.0633997790284085e-07 -- dof = 1
#
#
#
# Inspecting disease: attention deficit
#
# 2 0.5566080084072342
# 3 0.5441604152665566
# 4 0.5420017591818062
# 5 0.5464670517232785
# 6 0.5410941448688926
# 7 0.5184504052716208
# 8 0.5193249664328043
# 9 0.521395222808792
# 10 0.5216629498811899
# Number of clusters found:2, Silhouette score:0.557
#
# Cluster 0 numerosity: 1000
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.31 (14355 out of 46765 terms in the whole dataset-- N patients in cluster 894)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.42 (3529 out of 8472 terms in the whole dataset-- N patients in cluster 892)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.51 (7006 out of 13823 terms in the whole dataset-- N patients in cluster 717)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.41 (774 out of 1876 terms in the whole dataset-- N patients in cluster 581)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.37 (1652 out of 4418 terms in the whole dataset-- N patients in cluster 537)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.40 (2896 out of 7169 terms in the whole dataset-- N patients in cluster 526)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against other viral diseases::V04.89::C1260454 = 0.57 (1200 out of 2117 terms in the whole dataset-- N patients in cluster 499)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.32 (1589 out of 4921 terms in the whole dataset-- N patients in cluster 482)
# % most frequent term:icd9::Other specified vaccination::V03.89::C0478550 = 0.58 (563 out of 974 terms in the whole dataset-- N patients in cluster 480)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555 = 0.43 (876 out of 2019 terms in the whole dataset-- N patients in cluster 477)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.21 (2116 out of 10191 terms in the whole dataset-- N patients in cluster 467)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.38 (4614 out of 11994 terms in the whole dataset-- N patients in cluster 456)
# % most frequent term:icd9::Rash and other nonspecific skin eruption::782.1::C0015230 = 0.33 (914 out of 2759 terms in the whole dataset-- N patients in cluster 450)
# % most frequent term:medication::H PAPILLOMAVIRUS VAC,QVAL(PF) 20MCG-40MCG-40MCG-20MCG/0.5ML IM SUSP = 0.62 (1062 out of 1707 terms in the whole dataset-- N patients in cluster 448)
# % most frequent term:medication::Hepatitis a virus::1491862::C0376325 = 0.52 (685 out of 1311 terms in the whole dataset-- N patients in cluster 446)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.38 (2390 out of 6292 terms in the whole dataset-- N patients in cluster 439)
# % most frequent term:icd9::Acute pharyngitis::462::C0001344 = 0.39 (1092 out of 2769 terms in the whole dataset-- N patients in cluster 439)
# % most frequent term:icd9::Unspecified viral infection::079.99::C0153114 = 0.40 (879 out of 2185 terms in the whole dataset-- N patients in cluster 416)
# % most frequent term:medication::Nasal spray::126542::C0461725 = 0.35 (1135 out of 3223 terms in the whole dataset-- N patients in cluster 393)
# % most frequent term:icd9::Headache::784.0::n/a = 0.32 (882 out of 2777 terms in the whole dataset-- N patients in cluster 380)
#
#
# Cluster 1 numerosity: 4924
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.68 (31673 out of 46765 terms in the whole dataset-- N patients in cluster 4144)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.81 (7635 out of 9379 terms in the whole dataset-- N patients in cluster 2038)
# % most frequent term:medication::Methylphenidate::6901::C0025810 = 0.71 (6015 out of 8507 terms in the whole dataset-- N patients in cluster 1293)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.25 (2594 out of 10191 terms in the whole dataset-- N patients in cluster 1154)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.42 (2747 out of 6543 terms in the whole dataset-- N patients in cluster 1082)
# % most frequent term:medication::Amphetamine::725::C0002658 = 0.75 (6634 out of 8795 terms in the whole dataset-- N patients in cluster 1050)
# % most frequent term:medication::Dextroamphetamine::3288::C0011812 = 0.75 (6850 out of 9086 terms in the whole dataset-- N patients in cluster 1044)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.27 (3196 out of 11994 terms in the whole dataset-- N patients in cluster 945)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.69 (4652 out of 6732 terms in the whole dataset-- N patients in cluster 914)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.59 (3552 out of 6042 terms in the whole dataset-- N patients in cluster 891)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.47 (3674 out of 7751 terms in the whole dataset-- N patients in cluster 867)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.54 (2749 out of 5092 terms in the whole dataset-- N patients in cluster 849)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.21 (2905 out of 13823 terms in the whole dataset-- N patients in cluster 847)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.57 (3740 out of 6557 terms in the whole dataset-- N patients in cluster 825)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.20 (1468 out of 7169 terms in the whole dataset-- N patients in cluster 677)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.14 (1206 out of 8472 terms in the whole dataset-- N patients in cluster 662)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.33 (1407 out of 4272 terms in the whole dataset-- N patients in cluster 641)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.26 (1127 out of 4418 terms in the whole dataset-- N patients in cluster 620)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.25 (1212 out of 4921 terms in the whole dataset-- N patients in cluster 608)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.20 (1285 out of 6292 terms in the whole dataset-- N patients in cluster 568)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 106  780]
#  [ 894 4144]]
# Chi-squared test statistics: chi2_stat = 17.53903150248996 -- p_val = 2.8146977261732863e-05 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[ 108 4262]
#  [ 892  662]]
# Chi-squared test statistics: chi2_stat = 2461.1646511291356 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[ 283 4077]
#  [ 717  847]]
# Chi-squared test statistics: chi2_stat = 1267.7111100041634 -- p_val = 1.1752172123100767e-277 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390
# Count matrix:
#  [[ 419 4677]
#  [ 581  247]]
# Chi-squared test statistics: chi2_stat = 1943.6216934710797 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[ 463 4304]
#  [ 537  620]]
# Chi-squared test statistics: chi2_stat = 891.1447379154747 -- p_val = 8.2576947757522385e-196 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[ 474 4247]
#  [ 526  677]]
# Chi-squared test statistics: chi2_stat = 772.8448315364068 -- p_val = 4.3272393705721714e-170 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against other viral diseases::V04.89::C1260454
# Count matrix:
#  [[ 501 4722]
#  [ 499  202]]
# Chi-squared test statistics: chi2_stat = 1666.6319472656608 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[ 518 4316]
#  [ 482  608]]
# Chi-squared test statistics: chi2_stat = 709.211529019434 -- p_val = 2.969034004997821e-156 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other specified vaccination::V03.89::C0478550
# Count matrix:
#  [[ 520 4729]
#  [ 480  195]]
# Chi-squared test statistics: chi2_stat = 1592.4151465221828 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555
# Count matrix:
#  [[ 523 4731]
#  [ 477  193]]
# Chi-squared test statistics: chi2_stat = 1583.922234678734 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[ 533 3770]
#  [ 467 1154]]
# Chi-squared test statistics: chi2_stat = 225.1593742756415 -- p_val = 6.777199599907204e-51 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[ 544 3979]
#  [ 456  945]]
# Chi-squared test statistics: chi2_stat = 319.5714836584979 -- p_val = 1.7957321967872555e-71 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Rash and other nonspecific skin eruption::782.1::C0015230
# Count matrix:
#  [[ 550 4508]
#  [ 450  416]]
# Chi-squared test statistics: chi2_stat = 886.7845861928947 -- p_val = 7.323461718985186e-195 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::H PAPILLOMAVIRUS VAC,QVAL(PF) 20MCG-40MCG-40MCG-20MCG/0.5ML IM SUSP
# Count matrix:
#  [[ 552 4725]
#  [ 448  199]]
# Chi-squared test statistics: chi2_stat = 1415.1312804877427 -- p_val = 1.082386085672145e-309 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Hepatitis a virus::1491862::C0376325
# Count matrix:
#  [[ 554 4781]
#  [ 446  143]]
# Chi-squared test statistics: chi2_stat = 1609.2190782328087 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Albuterol sulfate::142153::C0543495
# Count matrix:
#  [[ 561 4356]
#  [ 439  568]]
# Chi-squared test statistics: chi2_stat = 614.7941009001534 -- p_val = 1.013978847198626e-135 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Acute pharyngitis::462::C0001344
# Count matrix:
#  [[ 561 4370]
#  [ 439  554]]
# Chi-squared test statistics: chi2_stat = 632.6833222355298 -- p_val = 1.303843023465964e-139 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified viral infection::079.99::C0153114
# Count matrix:
#  [[ 584 4523]
#  [ 416  401]]
# Chi-squared test statistics: chi2_stat = 779.7145669520197 -- p_val = 1.388513405848609e-171 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Nasal spray::126542::C0461725
# Count matrix:
#  [[ 607 4451]
#  [ 393  473]]
# Chi-squared test statistics: chi2_stat = 584.8063408067165 -- p_val = 3.377622791629457e-129 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Headache::784.0::n/a
# Count matrix:
#  [[ 620 4398]
#  [ 380  526]]
# Chi-squared test statistics: chi2_stat = 476.7003158314049 -- p_val = 1.1162274136763502e-105 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 106  780]
#  [ 894 4144]]
# Chi-squared test statistics: chi2_stat = 17.53903150248996 -- p_val = 2.8146977261732863e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[ 628 2886]
#  [ 372 2038]]
# Chi-squared test statistics: chi2_stat = 5.8721303372615266 -- p_val = 0.015382426109493273 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Methylphenidate::6901::C0025810
# Count matrix:
#  [[ 711 3631]
#  [ 289 1293]]
# Chi-squared test statistics: chi2_stat = 2.82822598922738 -- p_val = 0.09262061980417925 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[ 533 3770]
#  [ 467 1154]]
# Chi-squared test statistics: chi2_stat = 225.1593742756415 -- p_val = 6.777199599907204e-51 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[ 656 3842]
#  [ 344 1082]]
# Chi-squared test statistics: chi2_stat = 69.54107790997072 -- p_val = 7.483952761959126e-17 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Amphetamine::725::C0002658
# Count matrix:
#  [[ 776 3874]
#  [ 224 1050]]
# Chi-squared test statistics: chi2_stat = 0.507993089330093 -- p_val = 0.47600892528528027 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Dextroamphetamine::3288::C0011812
# Count matrix:
#  [[ 771 3880]
#  [ 229 1044]]
# Chi-squared test statistics: chi2_stat = 1.3211699012076412 -- p_val = 0.25038219790368443 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[ 544 3979]
#  [ 456  945]]
# Chi-squared test statistics: chi2_stat = 319.5714836584979 -- p_val = 1.7957321967872555e-71 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Oppositional defiant disorder::313.81::C0029121
# Count matrix:
#  [[ 763 4010]
#  [ 237  914]]
# Chi-squared test statistics: chi2_stat = 13.689910015194535 -- p_val = 0.00021560979795281105 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified episodic mood disorder::296.90::C1456434
# Count matrix:
#  [[ 783 4033]
#  [ 217  891]]
# Chi-squared test statistics: chi2_stat = 6.868953373214529 -- p_val = 0.008770600294810525 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[ 709 4057]
#  [ 291  867]]
# Chi-squared test statistics: chi2_stat = 69.07658394340982 -- p_val = 9.471323134516046e-17 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified disturbance of conduct::312.9::C0149654
# Count matrix:
#  [[ 644 4075]
#  [ 356  849]]
# Chi-squared test statistics: chi2_stat = 171.74820651420652 -- p_val = 3.0715097333216637e-39 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[ 283 4077]
#  [ 717  847]]
# Chi-squared test statistics: chi2_stat = 1267.7111100041634 -- p_val = 1.1752172123100767e-277 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[ 752 4099]
#  [ 248  825]]
# Chi-squared test statistics: chi2_stat = 35.73311991378885 -- p_val = 2.2628414195759745e-09 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[ 474 4247]
#  [ 526  677]]
# Chi-squared test statistics: chi2_stat = 772.8448315364068 -- p_val = 4.3272393705721714e-170 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[ 108 4262]
#  [ 892  662]]
# Chi-squared test statistics: chi2_stat = 2461.1646511291356 -- p_val = 0.0 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[ 652 4283]
#  [ 348  641]]
# Chi-squared test statistics: chi2_stat = 281.99942628461866 -- p_val = 2.7535435329865127e-63 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[ 463 4304]
#  [ 537  620]]
# Chi-squared test statistics: chi2_stat = 891.1447379154747 -- p_val = 8.2576947757522385e-196 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[ 518 4316]
#  [ 482  608]]
# Chi-squared test statistics: chi2_stat = 709.211529019434 -- p_val = 2.969034004997821e-156 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Albuterol sulfate::142153::C0543495
# Count matrix:
#  [[ 561 4356]
#  [ 439  568]]
# Chi-squared test statistics: chi2_stat = 614.7941009001534 -- p_val = 1.013978847198626e-135 -- dof = 1
#
#
#
# Inspecting disease: autism
#
# 2 0.6922630241730454
# 3 0.6033888719677719
# 4 0.6058218084636232
# 5 0.6114461500463172
# 6 0.6124238950300731
# 7 0.6073094950687663
# 8 0.6143254629143469
# 9 0.615791794983765
# 10 0.6171091174095852
# Number of clusters found:2, Silhouette score:0.692
#
# Cluster 0 numerosity: 752
# % most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.73 (3555 out of 4845 terms in the whole dataset-- N patients in cluster 748)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.09 (1227 out of 13823 terms in the whole dataset-- N patients in cluster 196)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.06 (566 out of 10191 terms in the whole dataset-- N patients in cluster 184)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.06 (504 out of 8472 terms in the whole dataset-- N patients in cluster 168)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.08 (398 out of 4921 terms in the whole dataset-- N patients in cluster 140)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.07 (321 out of 4418 terms in the whole dataset-- N patients in cluster 138)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.04 (275 out of 6543 terms in the whole dataset-- N patients in cluster 137)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.06 (739 out of 11994 terms in the whole dataset-- N patients in cluster 133)
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.01 (345 out of 46765 terms in the whole dataset-- N patients in cluster 114)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.05 (193 out of 4018 terms in the whole dataset-- N patients in cluster 113)
# % most frequent term:icd9::Fever, unspecified::780.60::C0015967 = 0.11 (268 out of 2406 terms in the whole dataset-- N patients in cluster 110)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.06 (436 out of 7169 terms in the whole dataset-- N patients in cluster 109)
# % most frequent term:medication::Albuterol sulfate::142153::C0543495 = 0.06 (407 out of 6292 terms in the whole dataset-- N patients in cluster 108)
# % most frequent term:icd9::Rash and other nonspecific skin eruption::782.1::C0015230 = 0.07 (203 out of 2759 terms in the whole dataset-- N patients in cluster 105)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.06 (114 out of 1876 terms in the whole dataset-- N patients in cluster 105)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.04 (157 out of 3689 terms in the whole dataset-- N patients in cluster 105)
# % most frequent term:icd9::Unspecified delay in development::315.9::n/a = 0.08 (246 out of 3002 terms in the whole dataset-- N patients in cluster 105)
# % most frequent term:icd9::Vomiting alone::787.03::C0728950 = 0.10 (183 out of 1913 terms in the whole dataset-- N patients in cluster 103)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.04 (247 out of 6708 terms in the whole dataset-- N patients in cluster 102)
# % most frequent term:medication::Nasal spray::126542::C0461725 = 0.07 (230 out of 3223 terms in the whole dataset-- N patients in cluster 100)
#
#
# Cluster 1 numerosity: 62
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.04 (303 out of 8472 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:medication::Hepatitis a virus::1491862::C0376325 = 0.10 (126 out of 1311 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555 = 0.14 (290 out of 2019 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.05 (684 out of 13823 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against varicella::V05.4::C0375770 = 0.13 (97 out of 766 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Other specified vaccinations against streptococcus pneumoniae [pneumococcus]::V03.82::C0375766 = 0.23 (250 out of 1089 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.14 (263 out of 1876 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.06 (268 out of 4845 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:medication::PNEUMOCOCCAL 13-VAL CONJ VACCINE-DIP CRM (PF) 0.5 ML IM SYRINGE = 0.34 (180 out of 537 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against measles-mumps-rubella (mmr)::V06.4::C0496634 = 0.18 (96 out of 543 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Other specified vaccinations against hemophilus influenza, type b [hib]::V03.81::C0375765 = 0.35 (174 out of 491 terms in the whole dataset-- N patients in cluster 61)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against poliomyelitis::V04.0::C1962940 = 0.28 (210 out of 743 terms in the whole dataset-- N patients in cluster 60)
# % most frequent term:medication::Virus::T005::n/a = 0.10 (69 out of 700 terms in the whole dataset-- N patients in cluster 60)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against other viral diseases::V04.89::C1260454 = 0.07 (146 out of 2117 terms in the whole dataset-- N patients in cluster 55)
# % most frequent term:medication::Hepatitis b virus::1427211::C0019169 = 0.20 (119 out of 581 terms in the whole dataset-- N patients in cluster 53)
# % most frequent term:medication::Oral drops::317002::C0991577 = 0.14 (153 out of 1097 terms in the whole dataset-- N patients in cluster 50)
# % most frequent term:medication::HAEMOPHILUS B POLYSACCHARID CONJ-TETANUS TOX (PF) 10 MCG/0.5 ML IM = 0.41 (82 out of 199 terms in the whole dataset-- N patients in cluster 49)
# % most frequent term:medication::ROTAVIRUS VACCINE LIVE, PENTA VALENT 2 ML ORAL SUSP = 0.49 (121 out of 246 terms in the whole dataset-- N patients in cluster 48)
# % most frequent term:medication::DP(A)T-POLIO-HIB CONJ-TET (PF) 15 LF UNIT-20 MCG-5 LF /0.5ML IM KIT = 0.56 (118 out of 212 terms in the whole dataset-- N patients in cluster 47)
# % most frequent term:medication::DIPH,PERTUS(ACEL),TET PED (PF) 25 LF UNIT-58 MCG-10 LF/0.5ML IM SUSP = 0.15 (56 out of 369 terms in the whole dataset-- N patients in cluster 46)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Autistic disorder, current or active state::299.00::C0154446
# Count matrix:
#  [[  4   0]
#  [748  62]]
# Chi-squared test statistics: chi2_stat = 0.1362272887592465 -- p_val = 0.7120607831007173 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[556   0]
#  [196  62]]
# Chi-squared test statistics: chi2_stat = 141.23331854430342 -- p_val = 1.4306178303355343e-32 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[568  24]
#  [184  38]]
# Chi-squared test statistics: chi2_stat = 37.31986342870625 -- p_val = 1.0025823165270074e-09 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[584   0]
#  [168  62]]
# Chi-squared test statistics: chi2_stat = 166.59597589933412 -- p_val = 4.099042523293935e-38 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[612  29]
#  [140  33]]
# Chi-squared test statistics: chi2_stat = 38.95049372373529 -- p_val = 4.346903374139212e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[614  17]
#  [138  45]]
# Chi-squared test statistics: chi2_stat = 93.56866607060141 -- p_val = 3.923499872723087e-22 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[615  45]
#  [137  17]]
# Chi-squared test statistics: chi2_stat = 2.5899119501094883 -- p_val = 0.10754631420141815 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[619  38]
#  [133  24]]
# Chi-squared test statistics: chi2_stat = 14.939753150886677 -- p_val = 0.00011099925910204224 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[638  60]
#  [114   2]]
# Chi-squared test statistics: chi2_stat = 5.734502227385458 -- p_val = 0.016634782169638845 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[639  51]
#  [113  11]]
# Chi-squared test statistics: chi2_stat = 0.15056721815866617 -- p_val = 0.6979938926335395 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Fever, unspecified::780.60::C0015967
# Count matrix:
#  [[642  18]
#  [110  44]]
# Chi-squared test statistics: chi2_stat = 114.87905304237344 -- p_val = 8.364668191924999e-27 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[643  34]
#  [109  28]]
# Chi-squared test statistics: chi2_stat = 36.322243168093024 -- p_val = 1.6724418179601096e-09 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Albuterol sulfate::142153::C0543495
# Count matrix:
#  [[644  31]
#  [108  31]]
# Chi-squared test statistics: chi2_stat = 48.88872894683567 -- p_val = 2.7090302422633664e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Rash and other nonspecific skin eruption::782.1::C0015230
# Count matrix:
#  [[647  35]
#  [105  27]]
# Chi-squared test statistics: chi2_stat = 34.755464385410434 -- p_val = 3.738279588431794e-09 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390
# Count matrix:
#  [[647   0]
#  [105  62]]
# Chi-squared test statistics: chi2_stat = 254.75826042509323 -- p_val = 2.3830559844956284e-57 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[647  48]
#  [105  14]]
# Chi-squared test statistics: chi2_stat = 2.752568183769314 -- p_val = 0.09709835293071423 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified delay in development::315.9::n/a
# Count matrix:
#  [[647  32]
#  [105  30]]
# Chi-squared test statistics: chi2_stat = 46.60702934802845 -- p_val = 8.674851288832396e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Vomiting alone::787.03::C0728950
# Count matrix:
#  [[649  34]
#  [103  28]]
# Chi-squared test statistics: chi2_stat = 39.6958074086966 -- p_val = 2.9676188981433363e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[650  29]
#  [102  33]]
# Chi-squared test statistics: chi2_stat = 62.29430691168241 -- p_val = 2.9577891188333253e-15 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Nasal spray::126542::C0461725
# Count matrix:
#  [[652  45]
#  [100  17]]
# Chi-squared test statistics: chi2_stat = 8.168671616732983 -- p_val = 0.004262010950425382 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[584   0]
#  [168  62]]
# Chi-squared test statistics: chi2_stat = 166.59597589933412 -- p_val = 4.099042523293935e-38 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Hepatitis a virus::1491862::C0376325
# Count matrix:
#  [[678   0]
#  [ 74  62]]
# Chi-squared test statistics: chi2_stat = 328.12417558995486 -- p_val = 2.4623392978421866e-73 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555
# Count matrix:
#  [[672   0]
#  [ 80  62]]
# Chi-squared test statistics: chi2_stat = 311.42433628623075 -- p_val = 1.0689191974407203e-69 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[556   0]
#  [196  62]]
# Chi-squared test statistics: chi2_stat = 141.23331854430342 -- p_val = 1.4306178303355343e-32 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against varicella::V05.4::C0375770
# Count matrix:
#  [[691   0]
#  [ 61  62]]
# Chi-squared test statistics: chi2_stat = 369.89642080449994 -- p_val = 1.9712718279826074e-82 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other specified vaccinations against streptococcus pneumoniae [pneumococcus]::V03.82::C0375766
# Count matrix:
#  [[719   0]
#  [ 33  62]]
# Chi-squared test statistics: chi2_stat = 498.6970992720486 -- p_val = 1.8258114562181874e-110 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390
# Count matrix:
#  [[647   0]
#  [105  62]]
# Chi-squared test statistics: chi2_stat = 254.75826042509323 -- p_val = 2.3830559844956284e-57 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Autistic disorder, current or active state::299.00::C0154446
# Count matrix:
#  [[  4   0]
#  [748  62]]
# Chi-squared test statistics: chi2_stat = 0.1362272887592465 -- p_val = 0.7120607831007173 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::PNEUMOCOCCAL 13-VAL CONJ VACCINE-DIP CRM (PF) 0.5 ML IM SYRINGE
# Count matrix:
#  [[730   0]
#  [ 22  62]]
# Chi-squared test statistics: chi2_stat = 572.7903874309629 -- p_val = 1.3878259360858314e-126 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against measles-mumps-rubella (mmr)::V06.4::C0496634
# Count matrix:
#  [[704   0]
#  [ 48  62]]
# Chi-squared test statistics: chi2_stat = 421.5421327401124 -- p_val = 1.1266377161829582e-93 -- dof = 1
# ...
# Number of clusters found:2, Silhouette score:0.384
#
# Cluster 0 numerosity: 379
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.50 (3025 out of 6009 terms in the whole dataset-- N patients in cluster 328)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.16 (1329 out of 8472 terms in the whole dataset-- N patients in cluster 301)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.16 (1627 out of 10191 terms in the whole dataset-- N patients in cluster 269)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.24 (1627 out of 6708 terms in the whole dataset-- N patients in cluster 265)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.33 (1519 out of 4607 terms in the whole dataset-- N patients in cluster 213)
# % most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.24 (1347 out of 5663 terms in the whole dataset-- N patients in cluster 201)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.12 (464 out of 4018 terms in the whole dataset-- N patients in cluster 191)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.14 (676 out of 4921 terms in the whole dataset-- N patients in cluster 190)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.15 (643 out of 4272 terms in the whole dataset-- N patients in cluster 189)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.15 (573 out of 3709 terms in the whole dataset-- N patients in cluster 185)
# % most frequent term:icd9::Rash and other nonspecific skin eruption::782.1::C0015230 = 0.17 (477 out of 2759 terms in the whole dataset-- N patients in cluster 183)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.12 (452 out of 3689 terms in the whole dataset-- N patients in cluster 182)
# % most frequent term:icd9::Profound intellectual disabilities::318.2::C3161330 = 0.67 (1462 out of 2187 terms in the whole dataset-- N patients in cluster 174)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.14 (356 out of 2616 terms in the whole dataset-- N patients in cluster 171)
# % most frequent term:icd9::Accidents occurring in unspecified place::E849.9::C0261380 = 0.16 (410 out of 2588 terms in the whole dataset-- N patients in cluster 167)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.49 (2408 out of 4911 terms in the whole dataset-- N patients in cluster 161)
# % most frequent term:medication::Oral powder::346289::C1160731 = 0.29 (680 out of 2367 terms in the whole dataset-- N patients in cluster 159)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.11 (483 out of 4418 terms in the whole dataset-- N patients in cluster 157)
# % most frequent term:medication::Heparin::5224::C0019134 = 0.24 (548 out of 2307 terms in the whole dataset-- N patients in cluster 156)
# % most frequent term:medication::Midazolam::6960::C0026056 = 0.14 (295 out of 2105 terms in the whole dataset-- N patients in cluster 156)
#
#
# Cluster 1 numerosity: 1020
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.40 (2423 out of 6009 terms in the whole dataset-- N patients in cluster 690)
# % most frequent term:medication::Sodium chloride::9863::C0037494 = 0.14 (908 out of 6708 terms in the whole dataset-- N patients in cluster 425)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.10 (1050 out of 10191 terms in the whole dataset-- N patients in cluster 420)
# % most frequent term:medication::Diphenhydramine::3498::C0012522 = 0.14 (888 out of 6543 terms in the whole dataset-- N patients in cluster 369)
# % most frequent term:medication::Acetaminophen 325 mg::315263::C0982952 = 0.16 (599 out of 3709 terms in the whole dataset-- N patients in cluster 308)
# % most frequent term:medication::Docusate sodium 100 mg::1099278::C3153447 = 0.21 (528 out of 2490 terms in the whole dataset-- N patients in cluster 270)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.11 (423 out of 4018 terms in the whole dataset-- N patients in cluster 265)
# % most frequent term:icd9::Mild intellectual disabilities::317::C0026106 = 0.34 (768 out of 2260 terms in the whole dataset-- N patients in cluster 260)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.26 (1287 out of 4911 terms in the whole dataset-- N patients in cluster 259)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.11 (395 out of 3689 terms in the whole dataset-- N patients in cluster 255)
# % most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.29 (1044 out of 3658 terms in the whole dataset-- N patients in cluster 254)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.09 (440 out of 4828 terms in the whole dataset-- N patients in cluster 249)
# % most frequent term:medication::ZZ IMS TEMPLATE = 0.18 (424 out of 2329 terms in the whole dataset-- N patients in cluster 237)
# % most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.12 (695 out of 5663 terms in the whole dataset-- N patients in cluster 224)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.11 (1066 out of 9732 terms in the whole dataset-- N patients in cluster 222)
# % most frequent term:icd9::Severe intellectual disabilities::318.1::C0036857 = 0.34 (478 out of 1398 terms in the whole dataset-- N patients in cluster 218)
# % most frequent term:icd9::Infantile cerebral palsy, unspecified::343.9::C0392549 = 0.32 (1068 out of 3369 terms in the whole dataset-- N patients in cluster 210)
# % most frequent term:medication::Propofol::8782::C0033487 = 0.11 (292 out of 2616 terms in the whole dataset-- N patients in cluster 205)
# % most frequent term:medication::Aerosol::324049::C1112870 = 0.06 (402 out of 7169 terms in the whole dataset-- N patients in cluster 200)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.05 (413 out of 8472 terms in the whole dataset-- N patients in cluster 194)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[ 51 330]
#  [328 690]]
# Chi-squared test statistics: chi2_stat = 48.84146168569189 -- p_val = 2.7751088731088745e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[ 78 826]
#  [301 194]]
# Chi-squared test statistics: chi2_stat = 438.2784673674289 -- p_val = 2.5651910545613166e-97 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[110 600]
#  [269 420]]
# Chi-squared test statistics: chi2_stat = 96.98744719942763 -- p_val = 6.976825117783768e-23 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[114 595]
#  [265 425]]
# Chi-squared test statistics: chi2_stat = 87.12576364366406 -- p_val = 1.0183531746340779e-20 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[166 840]
#  [213 180]]
# Chi-squared test statistics: chi2_stat = 201.42217381604928 -- p_val = 1.0220851993679338e-45 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841
# Count matrix:
#  [[178 796]
#  [201 224]]
# Chi-squared test statistics: chi2_stat = 124.68588988283541 -- p_val = 5.962364836914043e-29 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[188 755]
#  [191 265]]
# Chi-squared test statistics: chi2_stat = 73.86633567500928 -- p_val = 8.358977873385868e-18 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[189 853]
#  [190 167]]
# Chi-squared test statistics: chi2_stat = 163.92378345668556 -- p_val = 1.5718519720725193e-37 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[190 882]
#  [189 138]]
# Chi-squared test statistics: chi2_stat = 201.70494523346508 -- p_val = 8.867115857538532e-46 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Acetaminophen 325 mg::315263::C0982952
# Count matrix:
#  [[194 712]
#  [185 308]]
# Chi-squared test statistics: chi2_stat = 41.15271118288268 -- p_val = 1.4078783754694916e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Rash and other nonspecific skin eruption::782.1::C0015230
# Count matrix:
#  [[196 901]
#  [183 119]]
# Chi-squared test statistics: chi2_stat = 216.73899096895627 -- p_val = 4.652822429342648e-49 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[197 765]
#  [182 255]]
# Chi-squared test statistics: chi2_stat = 67.11181190757253 -- p_val = 2.565367489497184e-16 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Profound intellectual disabilities::318.2::C3161330
# Count matrix:
#  [[205 844]
#  [174 176]]
# Chi-squared test statistics: chi2_stat = 119.43291292746171 -- p_val = 8.419520723792578e-28 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[208 815]
#  [171 205]]
# Chi-squared test statistics: chi2_stat = 86.75370044285657 -- p_val = 1.229136090170627e-20 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Accidents occurring in unspecified place::E849.9::C0261380
# Count matrix:
#  [[212 875]
#  [167 145]]
# Chi-squared test statistics: chi2_stat = 140.3496129629386 -- p_val = 2.2323491772315227e-32 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[218 761]
#  [161 259]]
# Chi-squared test statistics: chi2_stat = 37.597917703207365 -- p_val = 8.693723949618027e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Oral powder::346289::C1160731
# Count matrix:
#  [[220 843]
#  [159 177]]
# Chi-squared test statistics: chi2_stat = 90.28732295421813 -- p_val = 2.059680698908449e-21 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[222 888]
#  [157 132]]
# Chi-squared test statistics: chi2_stat = 135.04900667426244 -- p_val = 3.2211934483350966e-31 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Heparin::5224::C0019134
# Count matrix:
#  [[223 862]
#  [156 158]]
# Chi-squared test statistics: chi2_stat = 103.14088187900511 -- p_val = 3.1214293612014225e-24 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Midazolam::6960::C0026056
# Count matrix:
#  [[223 852]
#  [156 168]]
# Chi-squared test statistics: chi2_stat = 93.2759207419382 -- p_val = 4.548928245584411e-22 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[ 51 330]
#  [328 690]]
# Chi-squared test statistics: chi2_stat = 48.84146168569189 -- p_val = 2.7751088731088745e-12 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Sodium chloride::9863::C0037494
# Count matrix:
#  [[114 595]
#  [265 425]]
# Chi-squared test statistics: chi2_stat = 87.12576364366406 -- p_val = 1.0183531746340779e-20 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[110 600]
#  [269 420]]
# Chi-squared test statistics: chi2_stat = 96.98744719942763 -- p_val = 6.976825117783768e-23 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Diphenhydramine::3498::C0012522
# Count matrix:
#  [[233 651]
#  [146 369]]
# Chi-squared test statistics: chi2_stat = 0.5568238978402283 -- p_val = 0.4555427804785055 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Acetaminophen 325 mg::315263::C0982952
# Count matrix:
#  [[194 712]
#  [185 308]]
# Chi-squared test statistics: chi2_stat = 41.15271118288268 -- p_val = 1.4078783754694916e-10 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Docusate sodium 100 mg::1099278::C3153447
# Count matrix:
#  [[250 750]
#  [129 270]]
# Chi-squared test statistics: chi2_stat = 7.393207132501897 -- p_val = 0.006547064871053302 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[188 755]
#  [191 265]]
# Chi-squared test statistics: chi2_stat = 73.86633567500928 -- p_val = 8.358977873385868e-18 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Mild intellectual disabilities::317::C0026106
# Count matrix:
#  [[273 760]
#  [106 260]]
# Chi-squared test statistics: chi2_stat = 0.7548692996226433 -- p_val = 0.38493894706597953 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[218 761]
#  [161 259]]
# Chi-squared test statistics: chi2_stat = 37.597917703207365 -- p_val = 8.693723949618027e-10 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[197 765]
#  [182 255]]
# Chi-squared test statistics: chi2_stat = 67.11181190757253 -- p_val = 2.565367489497184e-16 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other convulsions::780.39::C0490011
# Count matrix:
#  [[226 766]
#  [153 254]]
# Chi-squared test statistics: chi2_stat = 31.301588388438187 -- p_val = 2.2089883777208078e-08 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[243 771]
#  [136 249]]
# Chi-squared test statistics: chi2_stat = 17.66193144889597 -- p_val = 2.6385486994919884e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::ZZ IMS TEMPLATE
# Count matrix:
#  [[291 783]
#  [ 88 237]]
# Chi-squared test statistics: chi2_stat = 0.004200369597755703 -- p_val = 0.948325073578489 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841
# Count matrix:
#  [[178 796]
#  [201 224]]
# Chi-squared test statistics: chi2_stat = 124.68588988283541 -- p_val = 5.962364836914043e-29 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[235 798]
#  [144 222]]
# Chi-squared test statistics: chi2_stat = 36.8447407111388 -- p_val = 1.2792070098151298e-09 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Severe intellectual disabilities::318.1::C0036857
# Count matrix:
#  [[224 802]
#  [155 218]]
# Chi-squared test statistics: chi2_stat = 52.878075275374 -- p_val = 3.5490917692298104e-13 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Infantile cerebral palsy, unspecified::343.9::C0392549
# Count matrix:
#  [[258 810]
#  [121 210]]
# Chi-squared test statistics: chi2_stat = 19.04355707869887 -- p_val = 1.2776842607244733e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Propofol::8782::C0033487
# Count matrix:
#  [[208 815]
#  [171 205]]
# Chi-squared test statistics: chi2_stat = 86.75370044285657 -- p_val = 1.229136090170627e-20 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aerosol::324049::C1112870
# Count matrix:
#  [[251 820]
#  [128 200]]
# Chi-squared test statistics: chi2_stat = 30.107530464617632 -- p_val = 4.087409409881087e-08 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[ 78 826]
#  [301 194]]
# Chi-squared test statistics: chi2_stat = 438.2784673674289 -- p_val = 2.5651910545613166e-97 -- dof = 1

# %% [markdown]
# ## LSTM encodings

# %%
# plot data
colors_lstm1 = [colormap[disease_dict[v]] for v in lstm_disease_class_first]
single_plot(lstm_encoded_umap, lstm_disease_class_first, colors_lstm1)

# %%
# plot cluster results
clusters = outer_clustering_analysis(lstm_encoded_vect, lstm_disease_class_first)
colors_lstm2 = [colormap[v] for v in clusters]
single_plot(lstm_encoded_umap, clusters, colors_lstm2)
# Out:
# Cluster: 0 -- Entropy: 2.327, Purity: 0.322
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 1 -- Entropy: 1.945, Purity: 0.393
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 2 -- Entropy: 1.783, Purity: 0.439
# max(P) in cluster disease malignant tumor of prostate
# Cluster: 3 -- Entropy: 2.013, Purity: 0.467
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 4 -- Entropy: 1.881, Purity: 0.538
# max(P) in cluster disease malignant tumor of prostate
# Cluster: 5 -- Entropy: 0.592, Purity: 0.857
# max(P) in cluster disease malignant tumor of prostate
# Average Entropy: 2.32
# Average Purity: 0.32

# %%
lstm_subplots, lstm_sub_clust = inner_clustering_analysis(lstm_disease_class_first, lstm_encoded_vect, 
                                                          lstm_mrns, lstm_encoded_umap)

lstm_new_disease_dict = {}
for idx, nd in enumerate(set(lstm_sub_clust)):
    lstm_new_disease_dict[nd] = idx
colors_lstm3 = [colormap[lstm_new_disease_dict[v]] for v in lstm_sub_clust]
single_plot(lstm_subplots, lstm_sub_clust, colors_lstm3)
# Out:
# Inspecting disease: alzheimer's disease
#
# 2 0.4139225350128534
# 3 0.33538510332903815
# 4 0.31919150230791027
# 5 0.3192827142872873
# 6 0.31113355595526754
# 7 0.24856781689135451
# 8 0.23899252772728571
# 9 0.22775707718334456
# 10 0.22740338540563423
# Number of clusters found:2, Silhouette score:0.414
#
# Cluster 0 numerosity: 3113
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.17 (24012 out of 142102 terms in the whole dataset-- N patients in cluster 2282)
# % most frequent term:icd9::Alzheimer's disease::331.0::C0002395 = 0.94 (21571 out of 22887 terms in the whole dataset-- N patients in cluster 3113)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.11 (10886 out of 95229 terms in the whole dataset-- N patients in cluster 857)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.23 (10057 out of 43839 terms in the whole dataset-- N patients in cluster 1280)
# % most frequent term:cpt::Phosphatase, alkaline::84075::C0201850|C3516363 = 0.15 (9660 out of 62900 terms in the whole dataset-- N patients in cluster 2155)
# % most frequent term:cpt::Phosphatase, alkaline::1014268::C0201850 = 0.15 (9660 out of 62900 terms in the whole dataset-- N patients in cluster 2155)
# % most frequent term:cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850 = 0.15 (9303 out of 64056 terms in the whole dataset-- N patients in cluster 2000)
# % most frequent term:cpt::Albumin::1011249::C0201838 = 0.15 (9198 out of 60007 terms in the whole dataset-- N patients in cluster 2080)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.34 (9166 out of 27301 terms in the whole dataset-- N patients in cluster 1209)
# % most frequent term:cpt::Urinalysis, by dip stick or tablet reagent for bilirubin, glucose, hemoglobin, ketones, leukocytes, nitrite, ph, protein, specific gravity, urobilinogen, any number of these constituents; automated, without microscopy::81003::C3525585|C3516205|C0373520|C3525584 = 0.22 (8944 out of 40675 terms in the whole dataset-- N patients in cluster 2269)
# % most frequent term:cpt::Protein::1011659::C0202202 = 0.15 (8470 out of 56623 terms in the whole dataset-- N patients in cluster 1974)
# % most frequent term:cpt::Transferase::1011714::C3853637 = 0.15 (8470 out of 56623 terms in the whole dataset-- N patients in cluster 1974)
# % most frequent term:cpt::Bilirubin::1011294::C0201913 = 0.15 (8470 out of 56623 terms in the whole dataset-- N patients in cluster 1974)
# % most frequent term:cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311 = 0.15 (8229 out of 54363 terms in the whole dataset-- N patients in cluster 1911)
# % most frequent term:icd9::Dementia, unspecified, without behavioral disturbance::294.20::C3161078 = 0.69 (8183 out of 11818 terms in the whole dataset-- N patients in cluster 1165)
# % most frequent term:icd9::Benign essential hypertension::401.1::C0155583 = 0.25 (7933 out of 31383 terms in the whole dataset-- N patients in cluster 870)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.26 (7902 out of 29970 terms in the whole dataset-- N patients in cluster 1071)
# % most frequent term:medication::Donepezil::135447::C0527316 = 0.73 (7647 out of 10512 terms in the whole dataset-- N patients in cluster 1617)
# % most frequent term:cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393 = 0.17 (7154 out of 41571 terms in the whole dataset-- N patients in cluster 2041)
# % most frequent term:cpt::Urinalysis; microscopic only::81015::C0202506|C0430397 = 0.21 (6916 out of 33608 terms in the whole dataset-- N patients in cluster 2016)
#
#
# Cluster 1 numerosity: 3
# % most frequent term:icd9::Alzheimer's disease::331.0::C0002395 = 0.00 (8 out of 22887 terms in the whole dataset-- N patients in cluster 3)
# % most frequent term:icd9::Dementia in conditions classified elsewhere without behavioral disturbance::294.10::C0878691 = 0.00 (2 out of 7324 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Aricept::135446::C0527315 = 0.00 (1 out of 2933 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Namenda::405206::C1330412 = 0.00 (1 out of 1617 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Inguinal hernia, without mention of obstruction or gangrene, unilateral or unspecified (not specified as recurrent)::550.90::C0156109 = 0.00 (1 out of 1323 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Acetaminophen 100 mg::437158::C1366476 = 0.03 (1 out of 34 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Quetiapine::51272::C0123091 = 0.00 (1 out of 2248 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Ondansetron 8 mg::328451::C1123368 = 0.00 (1 out of 6340 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Other and unspecified coagulation defects::286.9::C0029496 = 0.00 (1 out of 537 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Pack::746839::C1999262 = 0.00 (1 out of 2049 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Pre-operative cardiovascular examination::V72.81::C0375894 = 0.00 (1 out of 1421 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Other malaise and fatigue::780.79::C0695252 = 0.00 (1 out of 14826 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Trazodone::10737::C0040805 = 0.00 (1 out of 8271 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Propoxyphene::8785::C0033493 = 0.02 (1 out of 52 terms in the whole dataset-- N patients in cluster 1)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[ 831    3]
#  [2282    0]]
# Chi-squared test statistics: chi2_stat = 4.902281839068588 -- p_val = 0.026821232359033057 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Alzheimer's disease::331.0::C0002395
# Count matrix:
#  [[   0    0]
#  [3113    3]]
# empty class(es)
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[2256    3]
#  [ 857    0]]
# Chi-squared test statistics: chi2_stat = 0.17685563888903796 -- p_val = 0.6740894974901648 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[1833    3]
#  [1280    0]]
# Chi-squared test statistics: chi2_stat = 0.7393425605450565 -- p_val = 0.38987156082253294 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::84075::C0201850|C3516363
# Count matrix:
#  [[ 958    3]
#  [2155    0]]
# Chi-squared test statistics: chi2_stat = 3.8793461001868783 -- p_val = 0.048883592827969384 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::1014268::C0201850
# Count matrix:
#  [[ 958    3]
#  [2155    0]]
# Chi-squared test statistics: chi2_stat = 3.8793461001868783 -- p_val = 0.048883592827969384 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850
# Count matrix:
#  [[1113    3]
#  [2000    0]]
# Chi-squared test statistics: chi2_stat = 2.9495787227493606 -- p_val = 0.08589994753658924 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Albumin::1011249::C0201838
# Count matrix:
#  [[1033    3]
#  [2080    0]]
# Chi-squared test statistics: chi2_stat = 3.3941950983470415 -- p_val = 0.06542628831015174 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[1904    3]
#  [1209    0]]
# Chi-squared test statistics: chi2_stat = 0.6194996438308035 -- p_val = 0.4312332822024155 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Urinalysis, by dip stick or tablet reagent for bilirubin, glucose, hemoglobin, ketones, leukocytes, nitrite, ph, protein, specific gravity, urobilinogen, any number of these constituents; automated, without microscopy::81003::C3525585|C3516205|C0373520|C3525584
# Count matrix:
#  [[ 844    3]
#  [2269    0]]
# Chi-squared test statistics: chi2_stat = 4.783351689008916 -- p_val = 0.02873613770783709 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Protein::1011659::C0202202
# Count matrix:
#  [[1139    3]
#  [1974    0]]
# Chi-squared test statistics: chi2_stat = 2.8187288800552674 -- p_val = 0.09317016048999904 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Transferase::1011714::C3853637
# Count matrix:
#  [[1139    3]
#  [1974    0]]
# Chi-squared test statistics: chi2_stat = 2.8187288800552674 -- p_val = 0.09317016048999904 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Bilirubin::1011294::C0201913
# Count matrix:
#  [[1139    3]
#  [1974    0]]
# Chi-squared test statistics: chi2_stat = 2.8187288800552674 -- p_val = 0.09317016048999904 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311
# Count matrix:
#  [[1202    3]
#  [1911    0]]
# Chi-squared test statistics: chi2_stat = 2.525586801309905 -- p_val = 0.1120131047824876 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Dementia, unspecified, without behavioral disturbance::294.20::C3161078
# Count matrix:
#  [[1948    3]
#  [1165    0]]
# Chi-squared test statistics: chi2_stat = 0.5507736064063535 -- p_val = 0.4580017711795732 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Benign essential hypertension::401.1::C0155583
# Count matrix:
#  [[2243    3]
#  [ 870    0]]
# Chi-squared test statistics: chi2_stat = 0.18897290906614223 -- p_val = 0.6637728345620753 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[2042    3]
#  [1071    0]]
# Chi-squared test statistics: chi2_stat = 0.41726339436507504 -- p_val = 0.5183057254150312 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Donepezil::135447::C0527316
# Count matrix:
#  [[1496    3]
#  [1617    0]]
# Chi-squared test statistics: chi2_stat = 1.4926874528596992 -- p_val = 0.22179995410491246 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393
# Count matrix:
#  [[1072    3]
#  [2041    0]]
# Chi-squared test statistics: chi2_stat = 3.1690359679062308 -- p_val = 0.07504673094660787 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Urinalysis; microscopic only::81015::C0202506|C0430397
# Count matrix:
#  [[1097    3]
#  [2016    0]]
# Chi-squared test statistics: chi2_stat = 3.03323838093353 -- p_val = 0.08157505202201484 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Alzheimer's disease::331.0::C0002395
# Count matrix:
#  [[   0    0]
#  [3113    3]]
# empty class(es)
# Odds ratio chi2 test for cluster 1term: icd9::Dementia in conditions classified elsewhere without behavioral disturbance::294.10::C0878691
# Count matrix:
#  [[1230    2]
#  [1883    1]]
# Chi-squared test statistics: chi2_stat = 0.1374938195958942 -- p_val = 0.7107853165585996 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aricept::135446::C0527315
# Count matrix:
#  [[2264    2]
#  [ 849    1]]
# Chi-squared test statistics: chi2_stat = 0.17046749789339727 -- p_val = 0.6796966613345787 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Namenda::405206::C1330412
# Count matrix:
#  [[2585    2]
#  [ 528    1]]
# Chi-squared test statistics: chi2_stat = 0.00020504112151404459 -- p_val = 0.9885752763284629 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Inguinal hernia, without mention of obstruction or gangrene, unilateral or unspecified (not specified as recurrent)::550.90::C0156109
# Count matrix:
#  [[3043    2]
#  [  70    1]]
# Chi-squared test statistics: chi2_stat = 2.791875172100229 -- p_val = 0.09474330185695574 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Acetaminophen 100 mg::437158::C1366476
# Count matrix:
#  [[3109    2]
#  [   4    1]]
# Chi-squared test statistics: chi2_stat = 51.06918302013149 -- p_val = 8.916722538737859e-13 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Quetiapine::51272::C0123091
# Count matrix:
#  [[2726    2]
#  [ 387    1]]
# Chi-squared test statistics: chi2_stat = 0.04893430512766528 -- p_val = 0.8249281471061979 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Ondansetron 8 mg::328451::C1123368
# Count matrix:
#  [[3106    2]
#  [   7    1]]
# Chi-squared test statistics: chi2_stat = 31.577431063296785 -- p_val = 1.9164398305430796e-08 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other and unspecified coagulation defects::286.9::C0029496
# Count matrix:
#  [[3072    2]
#  [  41    1]]
# Chi-squared test statistics: chi2_stat = 5.299439713522492 -- p_val = 0.021332285147279414 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Pack::746839::C1999262
# Count matrix:
#  [[2922    2]
#  [ 191    1]]
# Chi-squared test statistics: chi2_stat = 0.5731145736121614 -- p_val = 0.4490239154219553 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Pre-operative cardiovascular examination::V72.81::C0375894
# Count matrix:
#  [[3065    2]
#  [  48    1]]
# Chi-squared test statistics: chi2_stat = 4.420193128481699 -- p_val = 0.03551601635267968 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other malaise and fatigue::780.79::C0695252
# Count matrix:
#  [[2022    2]
#  [1091    1]]
# Chi-squared test statistics: chi2_stat = 0.29503821364741223 -- p_val = 0.5870098671828243 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Trazodone::10737::C0040805
# Count matrix:
#  [[2325    2]
#  [ 788    1]]
# Chi-squared test statistics: chi2_stat = 0.11893802710546741 -- p_val = 0.7301891509588586 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Propoxyphene::8785::C0033493
# Count matrix:
#  [[3109    2]
#  [   4    1]]
# Chi-squared test statistics: chi2_stat = 51.06918302013149 -- p_val = 8.916722538737859e-13 -- dof = 1
#
#
#
# Inspecting disease: diabetes
#
# 2 0.4155521039417481
# 3 0.40615806212545214
# 4 0.38421740126903603
# 5 0.3835193022006957
# 6 0.3785823059516464
# 7 0.3410979400383916
# 8 0.33378219094203376
# 9 0.33023600222173055
# 10 0.3298610487640897
# Number of clusters found:2, Silhouette score:0.416
#
# Cluster 0 numerosity: 52
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.00 (63 out of 95229 terms in the whole dataset-- N patients in cluster 48)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.00 (51 out of 142102 terms in the whole dataset-- N patients in cluster 40)
# % most frequent term:icd9::Coronary atherosclerosis of unspecified type of vessel, native or graft::414.00::C0837133 = 0.00 (39 out of 29577 terms in the whole dataset-- N patients in cluster 33)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.00 (36 out of 58342 terms in the whole dataset-- N patients in cluster 28)
# % most frequent term:cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393 = 0.00 (34 out of 41571 terms in the whole dataset-- N patients in cluster 33)
# % most frequent term:medication::Glucophage::151827::C0591573 = 0.01 (28 out of 2129 terms in the whole dataset-- N patients in cluster 27)
# % most frequent term:icd9::Other nonspecific abnormal results of function study of cardiovascular system::794.39::C2711989 = 0.02 (27 out of 1744 terms in the whole dataset-- N patients in cluster 26)
# % most frequent term:medication::Aspirin::1191::C0004057 = 0.00 (26 out of 17072 terms in the whole dataset-- N patients in cluster 24)
# % most frequent term:medication::Metformin::6809::C0025598 = 0.00 (21 out of 22884 terms in the whole dataset-- N patients in cluster 16)
# % most frequent term:cpt::Glucose; blood, reagent strip::82948::C0373620 = 0.00 (18 out of 30374 terms in the whole dataset-- N patients in cluster 17)
# % most frequent term:icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134 = 0.00 (17 out of 16921 terms in the whole dataset-- N patients in cluster 17)
# % most frequent term:icd9::Other and unspecified angina pectoris::413.9::C0348588 = 0.00 (15 out of 3922 terms in the whole dataset-- N patients in cluster 15)
# % most frequent term:icd9::Chest pain, unspecified::786.50::C0008031 = 0.00 (13 out of 11667 terms in the whole dataset-- N patients in cluster 10)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.00 (12 out of 25669 terms in the whole dataset-- N patients in cluster 11)
# % most frequent term:medication::Actos::261442::C0875954 = 0.01 (11 out of 1922 terms in the whole dataset-- N patients in cluster 11)
# % most frequent term:icd9::Long-term (current) use of aspirin::V58.66::C2911205 = 0.00 (11 out of 2511 terms in the whole dataset-- N patients in cluster 11)
# % most frequent term:medication::Norvasc::58927::C0162712 = 0.00 (10 out of 5002 terms in the whole dataset-- N patients in cluster 9)
# % most frequent term:icd9::Other chest pain::786.59::C0029537 = 0.00 (9 out of 3762 terms in the whole dataset-- N patients in cluster 9)
# % most frequent term:medication::Crestor::320864::C1098080 = 0.01 (9 out of 1749 terms in the whole dataset-- N patients in cluster 8)
# % most frequent term:medication::Zocor::196503::C0678181 = 0.00 (8 out of 3410 terms in the whole dataset-- N patients in cluster 8)
#
#
# Cluster 1 numerosity: 2153
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.49 (46895 out of 95229 terms in the whole dataset-- N patients in cluster 2133)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.26 (36928 out of 142102 terms in the whole dataset-- N patients in cluster 1933)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.33 (19088 out of 58342 terms in the whole dataset-- N patients in cluster 1616)
# % most frequent term:medication::Metformin::6809::C0025598 = 0.55 (12636 out of 22884 terms in the whole dataset-- N patients in cluster 1551)
# % most frequent term:cpt::Glucose; blood, reagent strip::82948::C0373620 = 0.39 (11908 out of 30374 terms in the whole dataset-- N patients in cluster 1902)
# % most frequent term:cpt::Lipid panel this panel must include the following: cholesterol, serum, total (82465) lipoprotein, direct measurement, high density cholesterol (hdl cholesterol) (83718) triglycerides (84478)::80061::C0202236|C0200382|C3525572|C1445957 = 0.29 (11507 out of 39885 terms in the whole dataset-- N patients in cluster 1774)
# % most frequent term:cpt::Phosphatase, alkaline::84075::C0201850|C3516363 = 0.16 (9759 out of 62900 terms in the whole dataset-- N patients in cluster 1545)
# % most frequent term:cpt::Phosphatase, alkaline::1014268::C0201850 = 0.16 (9759 out of 62900 terms in the whole dataset-- N patients in cluster 1545)
# % most frequent term:icd9::Benign essential hypertension::401.1::C0155583 = 0.29 (9251 out of 31383 terms in the whole dataset-- N patients in cluster 818)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.44 (9151 out of 20762 terms in the whole dataset-- N patients in cluster 636)
# % most frequent term:cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850 = 0.14 (9110 out of 64056 terms in the whole dataset-- N patients in cluster 1475)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.35 (8965 out of 25669 terms in the whole dataset-- N patients in cluster 1452)
# % most frequent term:cpt::Albumin::1011249::C0201838 = 0.15 (8840 out of 60007 terms in the whole dataset-- N patients in cluster 1458)
# % most frequent term:icd9::Esophageal reflux::530.81::C0017168 = 0.29 (8784 out of 29975 terms in the whole dataset-- N patients in cluster 917)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.20 (8659 out of 43839 terms in the whole dataset-- N patients in cluster 1169)
# % most frequent term:cpt::Hemoglobin; glycosylated (a1c)::83036::C0474680|C0373638 = 0.39 (8343 out of 21627 terms in the whole dataset-- N patients in cluster 1795)
# % most frequent term:cpt::Protein::1011659::C0202202 = 0.15 (8250 out of 56623 terms in the whole dataset-- N patients in cluster 1441)
# % most frequent term:cpt::Transferase::1011714::C3853637 = 0.15 (8250 out of 56623 terms in the whole dataset-- N patients in cluster 1441)
# % most frequent term:cpt::Bilirubin::1011294::C0201913 = 0.15 (8250 out of 56623 terms in the whole dataset-- N patients in cluster 1441)
# % most frequent term:cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311 = 0.15 (7963 out of 54363 terms in the whole dataset-- N patients in cluster 1391)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[   4   20]
#  [  48 2133]]
# Chi-squared test statistics: chi2_stat = 15.748374992944635 -- p_val = 7.235006057046642e-05 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[  12  220]
#  [  40 1933]]
# Chi-squared test statistics: chi2_stat = 7.6036974847091345 -- p_val = 0.005824872691353097 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Coronary atherosclerosis of unspecified type of vessel, native or graft::414.00::C0837133
# Count matrix:
#  [[  19 1322]
#  [  33  831]]
# Chi-squared test statistics: chi2_stat = 12.149623845794618 -- p_val = 0.000490977658034985 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[  24  537]
#  [  28 1616]]
# Chi-squared test statistics: chi2_stat = 10.951166301555487 -- p_val = 0.0009354471514885153 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393
# Count matrix:
#  [[  19  517]
#  [  33 1636]]
# Chi-squared test statistics: chi2_stat = 3.675350270262105 -- p_val = 0.05522264938530858 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Glucophage::151827::C0591573
# Count matrix:
#  [[  25 1630]
#  [  27  523]]
# Chi-squared test statistics: chi2_stat = 19.256609845334538 -- p_val = 1.1427405743672223e-05 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other nonspecific abnormal results of function study of cardiovascular system::794.39::C2711989
# Count matrix:
#  [[  26 1747]
#  [  26  406]]
# Chi-squared test statistics: chi2_stat = 29.313228836653874 -- p_val = 6.15738990706508e-08 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Aspirin::1191::C0004057
# Count matrix:
#  [[  28 1011]
#  [  24 1142]]
# Chi-squared test statistics: chi2_stat = 0.7102059986852819 -- p_val = 0.3993754338099256 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Metformin::6809::C0025598
# Count matrix:
#  [[  36  602]
#  [  16 1551]]
# Chi-squared test statistics: chi2_stat = 40.07315324473181 -- p_val = 2.4462798398516057e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Glucose; blood, reagent strip::82948::C0373620
# Count matrix:
#  [[  35  251]
#  [  17 1902]]
# Chi-squared test statistics: chi2_stat = 134.4095580375167 -- p_val = 4.445157713640663e-31 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Coronary atherosclerosis of native coronary artery::414.01::C0837134
# Count matrix:
#  [[  35 1270]
#  [  17  883]]
# Chi-squared test statistics: chi2_stat = 1.1309905192125955 -- p_val = 0.28756415795827706 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other and unspecified angina pectoris::413.9::C0348588
# Count matrix:
#  [[  37 1615]
#  [  15  538]]
# Chi-squared test statistics: chi2_stat = 0.2230453417479521 -- p_val = 0.6367292535026864 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Chest pain, unspecified::786.50::C0008031
# Count matrix:
#  [[  42 1177]
#  [  10  976]]
# Chi-squared test statistics: chi2_stat = 12.956741314262663 -- p_val = 0.0003187715544600947 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[  41  701]
#  [  11 1452]]
# Chi-squared test statistics: chi2_stat = 46.670858589751084 -- p_val = 8.396843707200892e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Actos::261442::C0875954
# Count matrix:
#  [[  41 1802]
#  [  11  351]]
# Chi-squared test statistics: chi2_stat = 0.5530980894480688 -- p_val = 0.45705457234713676 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Long-term (current) use of aspirin::V58.66::C2911205
# Count matrix:
#  [[  41 1699]
#  [  11  454]]
# Chi-squared test statistics: chi2_stat = 0.02569938202422691 -- p_val = 0.8726366707948622 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Norvasc::58927::C0162712
# Count matrix:
#  [[  43 1634]
#  [   9  519]]
# Chi-squared test statistics: chi2_stat = 0.942228103357191 -- p_val = 0.3317054884816431 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other chest pain::786.59::C0029537
# Count matrix:
#  [[  43 1578]
#  [   9  575]]
# Chi-squared test statistics: chi2_stat = 1.846346749623857 -- p_val = 0.17420888751540725 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Crestor::320864::C1098080
# Count matrix:
#  [[  44 1868]
#  [   8  285]]
# Chi-squared test statistics: chi2_stat = 0.05955168536964713 -- p_val = 0.8072059281003572 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Zocor::196503::C0678181
# Count matrix:
#  [[  44 1748]
#  [   8  405]]
# Chi-squared test statistics: chi2_stat = 0.19884346379612966 -- p_val = 0.6556559926218184 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[   4   20]
#  [  48 2133]]
# Chi-squared test statistics: chi2_stat = 15.748374992944635 -- p_val = 7.235006057046642e-05 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[  12  220]
#  [  40 1933]]
# Chi-squared test statistics: chi2_stat = 7.6036974847091345 -- p_val = 0.005824872691353097 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[  24  537]
#  [  28 1616]]
# Chi-squared test statistics: chi2_stat = 10.951166301555487 -- p_val = 0.0009354471514885153 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Metformin::6809::C0025598
# Count matrix:
#  [[  36  602]
#  [  16 1551]]
# Chi-squared test statistics: chi2_stat = 40.07315324473181 -- p_val = 2.4462798398516057e-10 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Glucose; blood, reagent strip::82948::C0373620
# Count matrix:
#  [[  35  251]
#  [  17 1902]]
# Chi-squared test statistics: chi2_stat = 134.4095580375167 -- p_val = 4.445157713640663e-31 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Lipid panel this panel must include the following: cholesterol, serum, total (82465) lipoprotein, direct measurement, high density cholesterol (hdl cholesterol) (83718) triglycerides (84478)::80061::C0202236|C0200382|C3525572|C1445957
# Count matrix:
#  [[  46  379]
#  [   6 1774]]
# Chi-squared test statistics: chi2_stat = 159.32032750628628 -- p_val = 1.592760609420708e-36 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Phosphatase, alkaline::84075::C0201850|C3516363
# Count matrix:
#  [[  51  608]
#  [   1 1545]]
# Chi-squared test statistics: chi2_stat = 114.8683639851284 -- p_val = 8.409877807296176e-27 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Phosphatase, alkaline::1014268::C0201850
# Count matrix:
#  [[  51  608]
#  [   1 1545]]
# Chi-squared test statistics: chi2_stat = 114.8683639851284 -- p_val = 8.409877807296176e-27 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Benign essential hypertension::401.1::C0155583
# Count matrix:
#  [[  49 1335]
#  [   3  818]]
# Chi-squared test statistics: chi2_stat = 21.20239895046285 -- p_val = 4.132469428675312e-06 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[  47 1517]
#  [   5  636]]
# Chi-squared test statistics: chi2_stat = 8.833290528495514 -- p_val = 0.0029578457534910354 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850
# Count matrix:
#  [[  51  678]
#  [   1 1475]]
# Chi-squared test statistics: chi2_stat = 98.7338089778132 -- p_val = 2.8882876817068005e-23 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[  41  701]
#  [  11 1452]]
# Chi-squared test statistics: chi2_stat = 46.670858589751084 -- p_val = 8.396843707200892e-12 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Albumin::1011249::C0201838
# Count matrix:
#  [[  51  695]
#  [   1 1458]]
# Chi-squared test statistics: chi2_stat = 95.27251599182189 -- p_val = 1.6590048680938763e-22 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Esophageal reflux::530.81::C0017168
# Count matrix:
#  [[  50 1236]
#  [   2  917]]
# Chi-squared test statistics: chi2_stat = 29.783946694055953 -- p_val = 4.8297471792963294e-08 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[  51  984]
#  [   1 1169]]
# Chi-squared test statistics: chi2_stat = 53.83460130912037 -- p_val = 2.1809774696071097e-13 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Hemoglobin; glycosylated (a1c)::83036::C0474680|C0373638
# Count matrix:
#  [[  48  358]
#  [   4 1795]]
# Chi-squared test statistics: chi2_stat = 188.57385452632633 -- p_val = 6.51079185816817e-43 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Protein::1011659::C0202202
# Count matrix:
#  [[  51  712]
#  [   1 1441]]
# Chi-squared test statistics: chi2_stat = 91.96551404775033 -- p_val = 8.820019272935003e-22 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Transferase::1011714::C3853637
# Count matrix:
#  [[  51  712]
#  [   1 1441]]
# Chi-squared test statistics: chi2_stat = 91.96551404775033 -- p_val = 8.820019272935003e-22 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Bilirubin::1011294::C0201913
# Count matrix:
#  [[  51  712]
#  [   1 1441]]
# Chi-squared test statistics: chi2_stat = 91.96551404775033 -- p_val = 8.820019272935003e-22 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311
# Count matrix:
#  [[  51  762]
#  [   1 1391]]
# Chi-squared test statistics: chi2_stat = 83.04090781819527 -- p_val = 8.037276967206754e-20 -- dof = 1
#
#
#
# Inspecting disease: malignant neoplasm of female breast
#
# 2 0.4136622286089984
# 3 0.2694500243603665
# 4 0.24663174750030392
# 5 0.24674167313321213
# 6 0.2414647849888048
# 7 0.23855550356198715
# 8 0.24018398772990138
# 9 0.19871302271274632
# 10 0.1998437559171819
# Number of clusters found:2, Silhouette score:0.414
#
# Cluster 0 numerosity: 10119
# % most frequent term:icd9::Malignant neoplasm of breast (female), unspecified::174.9::C0235653 = 0.99 (87990 out of 88939 terms in the whole dataset-- N patients in cluster 10097)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.26 (37547 out of 142102 terms in the whole dataset-- N patients in cluster 3863)
# % most frequent term:cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850 = 0.33 (20821 out of 64056 terms in the whole dataset-- N patients in cluster 4467)
# % most frequent term:cpt::Phosphatase, alkaline::84075::C0201850|C3516363 = 0.30 (18751 out of 62900 terms in the whole dataset-- N patients in cluster 4506)
# % most frequent term:cpt::Phosphatase, alkaline::1014268::C0201850 = 0.30 (18751 out of 62900 terms in the whole dataset-- N patients in cluster 4506)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.19 (18528 out of 95229 terms in the whole dataset-- N patients in cluster 1530)
# % most frequent term:cpt::Albumin::1011249::C0201838 = 0.30 (18107 out of 60007 terms in the whole dataset-- N patients in cluster 4473)
# % most frequent term:cpt::Protein::1011659::C0202202 = 0.30 (17221 out of 56623 terms in the whole dataset-- N patients in cluster 4290)
# % most frequent term:cpt::Transferase::1011714::C3853637 = 0.30 (17221 out of 56623 terms in the whole dataset-- N patients in cluster 4290)
# % most frequent term:cpt::Bilirubin::1011294::C0201913 = 0.30 (17221 out of 56623 terms in the whole dataset-- N patients in cluster 4290)
# % most frequent term:cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311 = 0.30 (16439 out of 54363 terms in the whole dataset-- N patients in cluster 4121)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.26 (15080 out of 58342 terms in the whole dataset-- N patients in cluster 2313)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.34 (14512 out of 43006 terms in the whole dataset-- N patients in cluster 5114)
# % most frequent term:medication::Ondansetron::26225::C0061851 = 0.42 (13180 out of 31640 terms in the whole dataset-- N patients in cluster 5318)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.26 (11395 out of 43839 terms in the whole dataset-- N patients in cluster 2007)
# % most frequent term:medication::Fentanyl::4337::C0015846 = 0.41 (11319 out of 27584 terms in the whole dataset-- N patients in cluster 5142)
# % most frequent term:icd9::Personal history of malignant neoplasm of breast::V10.3::C0260421 = 0.94 (10785 out of 11420 terms in the whole dataset-- N patients in cluster 3948)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.30 (10542 out of 35006 terms in the whole dataset-- N patients in cluster 4234)
# % most frequent term:cpt::Lipid panel this panel must include the following: cholesterol, serum, total (82465) lipoprotein, direct measurement, high density cholesterol (hdl cholesterol) (83718) triglycerides (84478)::80061::C0202236|C0200382|C3525572|C1445957 = 0.26 (10524 out of 39885 terms in the whole dataset-- N patients in cluster 2929)
# % most frequent term:cpt::Ultrasound, breast(s) (unilateral or bilateral), real time with image documentation = 0.93 (10397 out of 11240 terms in the whole dataset-- N patients in cluster 3510)
#
#
# Cluster 1 numerosity: 2
# % most frequent term:icd9::Malignant neoplasm of breast (female), unspecified::174.9::C0235653 = 0.00 (3 out of 88939 terms in the whole dataset-- N patients in cluster 2)
# % most frequent term:icd9::Tricuspid valve disorders, specified as nonrheumatic::424.2::C0701168 = 0.01 (2 out of 293 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Encounter for antineoplastic chemotherapy::V58.11::C1561677 = 0.00 (1 out of 19259 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Zoladex::58328::C0149473 = 0.03 (1 out of 33 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:icd9::Pulmonary valve disorders::424.3::C0034087 = 0.03 (1 out of 40 terms in the whole dataset-- N patients in cluster 1)
# % most frequent term:medication::Tamoxifen 20 mg::330595::C1126289 = 0.00 (1 out of 1946 terms in the whole dataset-- N patients in cluster 1)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Malignant neoplasm of breast (female), unspecified::174.9::C0235653
# Count matrix:
#  [[   22     0]
#  [10097     2]]
# Chi-squared test statistics: chi2_stat = 56.64432598063518 -- p_val = 5.2221319036873637e-14 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[6256    2]
#  [3863    0]]
# Chi-squared test statistics: chi2_stat = 0.14697820529860514 -- p_val = 0.7014399824892958 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850
# Count matrix:
#  [[5652    2]
#  [4467    0]]
# Chi-squared test statistics: chi2_stat = 0.2970921640762882 -- p_val = 0.5857111415482199 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::84075::C0201850|C3516363
# Count matrix:
#  [[5613    2]
#  [4506    0]]
# Chi-squared test statistics: chi2_stat = 0.30863051096254135 -- p_val = 0.5785217768225432 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::1014268::C0201850
# Count matrix:
#  [[5613    2]
#  [4506    0]]
# Chi-squared test statistics: chi2_stat = 0.30863051096254135 -- p_val = 0.5785217768225432 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[8589    2]
#  [1530    0]]
# Chi-squared test statistics: chi2_stat = 0.15226419643071967 -- p_val = 0.6963809338514866 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Albumin::1011249::C0201838
# Count matrix:
#  [[5646    2]
#  [4473    0]]
# Chi-squared test statistics: chi2_stat = 0.2988519360473432 -- p_val = 0.5846030504389013 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Protein::1011659::C0202202
# Count matrix:
#  [[5829    2]
#  [4290    0]]
# Chi-squared test statistics: chi2_stat = 0.24763808604301962 -- p_val = 0.6187431057453284 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Transferase::1011714::C3853637
# Count matrix:
#  [[5829    2]
#  [4290    0]]
# Chi-squared test statistics: chi2_stat = 0.24763808604301962 -- p_val = 0.6187431057453284 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Bilirubin::1011294::C0201913
# Count matrix:
#  [[5829    2]
#  [4290    0]]
# Chi-squared test statistics: chi2_stat = 0.24763808604301962 -- p_val = 0.6187431057453284 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311
# Count matrix:
#  [[5998    2]
#  [4121    0]]
# Chi-squared test statistics: chi2_stat = 0.20472261650751838 -- p_val = 0.6509355896581566 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[7806    2]
#  [2313    0]]
# Chi-squared test statistics: chi2_stat = 0.005227811953298382 -- p_val = 0.9423602922154307 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Oxycodone::7804::C0030049
# Count matrix:
#  [[5005    2]
#  [5114    0]]
# Chi-squared test statistics: chi2_stat = 0.5215290313421622 -- p_val = 0.47019016859160745 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Ondansetron::26225::C0061851
# Count matrix:
#  [[4801    2]
#  [5318    0]]
# Chi-squared test statistics: chi2_stat = 0.6086428912339668 -- p_val = 0.4352992435834314 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[8112    2]
#  [2007    0]]
# Chi-squared test statistics: chi2_stat = 0.03363194024931309 -- p_val = 0.8544919186583838 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Fentanyl::4337::C0015846
# Count matrix:
#  [[4977    2]
#  [5142    0]]
# Chi-squared test statistics: chi2_stat = 0.5329725388432333 -- p_val = 0.4653598165163578 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of malignant neoplasm of breast::V10.3::C0260421
# Count matrix:
#  [[6171    2]
#  [3948    0]]
# Chi-squared test statistics: chi2_stat = 0.16498395699535603 -- p_val = 0.6846087522652629 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[5885    2]
#  [4234    0]]
# Chi-squared test statistics: chi2_stat = 0.232960705471813 -- p_val = 0.6293371472105337 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Lipid panel this panel must include the following: cholesterol, serum, total (82465) lipoprotein, direct measurement, high density cholesterol (hdl cholesterol) (83718) triglycerides (84478)::80061::C0202236|C0200382|C3525572|C1445957
# Count matrix:
#  [[7190    2]
#  [2929    0]]
# Chi-squared test statistics: chi2_stat = 0.015098999347086169 -- p_val = 0.9022037184400266 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Ultrasound, breast(s) (unilateral or bilateral), real time with image documentation
# Count matrix:
#  [[6609    2]
#  [3510    0]]
# Chi-squared test statistics: chi2_stat = 0.08275077984878079 -- p_val = 0.7736036794624275 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Malignant neoplasm of breast (female), unspecified::174.9::C0235653
# Count matrix:
#  [[   22     0]
#  [10097     2]]
# Chi-squared test statistics: chi2_stat = 56.64432598063518 -- p_val = 5.2221319036873637e-14 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Tricuspid valve disorders, specified as nonrheumatic::424.2::C0701168
# Count matrix:
#  [[10071     1]
#  [   48     1]]
# Chi-squared test statistics: chi2_stat = 24.954281833725673 -- p_val = 5.87060042094348e-07 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Encounter for antineoplastic chemotherapy::V58.11::C1561677
# Count matrix:
#  [[9067    1]
#  [1052    1]]
# Chi-squared test statistics: chi2_stat = 0.45717654293654625 -- p_val = 0.49894648423311394 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Zoladex::58328::C0149473
# Count matrix:
#  [[10112     1]
#  [    7     1]]
# Chi-squared test statistics: chi2_stat = 157.29759835404184 -- p_val = 4.4067774211868195e-36 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Pulmonary valve disorders::424.3::C0034087
# Count matrix:
#  [[10114     1]
#  [    5     1]]
# Chi-squared test statistics: chi2_stat = 210.02133608432533 -- p_val = 1.3589731555417593e-47 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Tamoxifen 20 mg::330595::C1126289
# Count matrix:
#  [[9237    1]
#  [ 882    1]]
# Chi-squared test statistics: chi2_stat = 0.6654205295104346 -- p_val = 0.41465278970005903 -- dof = 1
#
#
#
# Inspecting disease: malignant tumor of prostate
#
# 2 0.18624127932774698
# 3 0.18099868359156338
# 4 0.16631039592361363
# 5 0.16633186907528552
# 6 0.16742609318528542
# 7 0.1583506837790739
# 8 0.15791299736552344
# 9 0.15701657564018012
# 10 0.138807130108085
# Number of clusters found:2, Silhouette score:0.186
#
# Cluster 0 numerosity: 8884
# % most frequent term:icd9::Malignant neoplasm of prostate::185::C0376358 = 0.95 (48741 out of 51334 terms in the whole dataset-- N patients in cluster 8884)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.17 (23560 out of 142102 terms in the whole dataset-- N patients in cluster 4565)
# % most frequent term:cpt::Prostate specific antigen (psa); total::84153::C0201544 = 0.89 (21442 out of 23966 terms in the whole dataset-- N patients in cluster 5280)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.20 (11398 out of 58342 terms in the whole dataset-- N patients in cluster 2657)
# % most frequent term:cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850 = 0.16 (10279 out of 64056 terms in the whole dataset-- N patients in cluster 2661)
# % most frequent term:cpt::Phosphatase, alkaline::84075::C0201850|C3516363 = 0.16 (10195 out of 62900 terms in the whole dataset-- N patients in cluster 2750)
# % most frequent term:cpt::Phosphatase, alkaline::1014268::C0201850 = 0.16 (10195 out of 62900 terms in the whole dataset-- N patients in cluster 2750)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.10 (9831 out of 95229 terms in the whole dataset-- N patients in cluster 1464)
# % most frequent term:cpt::Albumin::1011249::C0201838 = 0.16 (9785 out of 60007 terms in the whole dataset-- N patients in cluster 2714)
# % most frequent term:cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393 = 0.23 (9617 out of 41571 terms in the whole dataset-- N patients in cluster 4664)
# % most frequent term:medication::Oxycodone::7804::C0030049 = 0.22 (9405 out of 43006 terms in the whole dataset-- N patients in cluster 5358)
# % most frequent term:cpt::Protein::1011659::C0202202 = 0.16 (9224 out of 56623 terms in the whole dataset-- N patients in cluster 2563)
# % most frequent term:cpt::Transferase::1011714::C3853637 = 0.16 (9224 out of 56623 terms in the whole dataset-- N patients in cluster 2563)
# ...
# % most frequent term:cpt::Phosphatase, alkaline::84075::C0201850|C3516363 = 0.08 (4825 out of 62900 terms in the whole dataset-- N patients in cluster 1470)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.05 (4762 out of 95229 terms in the whole dataset-- N patients in cluster 615)
# % most frequent term:cpt::Albumin::1011249::C0201838 = 0.08 (4583 out of 60007 terms in the whole dataset-- N patients in cluster 1435)
# % most frequent term:cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850 = 0.07 (4560 out of 64056 terms in the whole dataset-- N patients in cluster 1364)
# % most frequent term:cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393 = 0.10 (4349 out of 41571 terms in the whole dataset-- N patients in cluster 1488)
# % most frequent term:cpt::Urinalysis, by dip stick or tablet reagent for bilirubin, glucose, hemoglobin, ketones, leukocytes, nitrite, ph, protein, specific gravity, urobilinogen, any number of these constituents; automated, without microscopy::81003::C3525585|C3516205|C0373520|C3525584 = 0.10 (4252 out of 40675 terms in the whole dataset-- N patients in cluster 1455)
# % most frequent term:cpt::Bilirubin::1011294::C0201913 = 0.07 (4235 out of 56623 terms in the whole dataset-- N patients in cluster 1337)
# % most frequent term:cpt::Protein::1011659::C0202202 = 0.07 (4235 out of 56623 terms in the whole dataset-- N patients in cluster 1337)
# % most frequent term:cpt::Transferase::1011714::C3853637 = 0.07 (4235 out of 56623 terms in the whole dataset-- N patients in cluster 1337)
# % most frequent term:cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311 = 0.07 (4016 out of 54363 terms in the whole dataset-- N patients in cluster 1278)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.15 (3999 out of 27301 terms in the whole dataset-- N patients in cluster 788)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.07 (3797 out of 58342 terms in the whole dataset-- N patients in cluster 947)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.08 (3705 out of 43839 terms in the whole dataset-- N patients in cluster 779)
#
#
# Cluster 1 numerosity: 78
# % most frequent term:icd9::Paralysis agitans::332.0::C0030567 = 0.01 (237 out of 32405 terms in the whole dataset-- N patients in cluster 78)
# % most frequent term:medication::Carbidopa 25 mg::315568::C0984524 = 0.01 (47 out of 3928 terms in the whole dataset-- N patients in cluster 36)
# % most frequent term:medication::Levodopa 100 mg::316141::C0987130 = 0.01 (46 out of 3770 terms in the whole dataset-- N patients in cluster 35)
# % most frequent term:medication::Carbidopa::2019::C0006982 = 0.00 (33 out of 10426 terms in the whole dataset-- N patients in cluster 26)
# % most frequent term:medication::Pramipexole::746741::C0074710 = 0.01 (24 out of 1845 terms in the whole dataset-- N patients in cluster 15)
# % most frequent term:medication::Levodopa::6375::C0023570 = 0.00 (23 out of 9292 terms in the whole dataset-- N patients in cluster 17)
# % most frequent term:medication::Rasagiline 1 mg::608326::C1638357 = 0.02 (16 out of 902 terms in the whole dataset-- N patients in cluster 11)
# % most frequent term:medication::Selegiline::9639::C0036579 = 0.01 (13 out of 998 terms in the whole dataset-- N patients in cluster 11)
# % most frequent term:medication::Amantadine::620::C0002403 = 0.01 (11 out of 1653 terms in the whole dataset-- N patients in cluster 9)
# % most frequent term:icd9::Abnormal involuntary movements::781.0::C0392702 = 0.00 (11 out of 2644 terms in the whole dataset-- N patients in cluster 7)
# % most frequent term:medication::Trihexyphenidyl::10811::C0041009 = 0.02 (9 out of 491 terms in the whole dataset-- N patients in cluster 5)
# % most frequent term:cpt::Magnetic resonance (eg, proton) imaging, brain (including brain stem); without contrast material::70551::C3866606|C0412675|C0202699 = 0.00 (9 out of 4029 terms in the whole dataset-- N patients in cluster 8)
# % most frequent term:medication::Vitamin d3::1244014::C3265062 = 0.00 (8 out of 16811 terms in the whole dataset-- N patients in cluster 8)
# % most frequent term:medication::Clonazepam 0.5 mg::315699::C0985016 = 0.00 (8 out of 4334 terms in the whole dataset-- N patients in cluster 6)
# % most frequent term:medication::Cholecalciferol::2418::C0008318 = 0.00 (7 out of 9824 terms in the whole dataset-- N patients in cluster 7)
# % most frequent term:medication::Aspirin 81 mg::315431::C0983882 = 0.00 (7 out of 25669 terms in the whole dataset-- N patients in cluster 7)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.00 (6 out of 29970 terms in the whole dataset-- N patients in cluster 6)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.00 (6 out of 142102 terms in the whole dataset-- N patients in cluster 5)
# % most frequent term:icd9::Essential and other specified forms of tremor::333.1::C1961111 = 0.00 (5 out of 1516 terms in the whole dataset-- N patients in cluster 2)
# % most frequent term:medication::Calcium::1895::C0006675 = 0.00 (5 out of 10715 terms in the whole dataset-- N patients in cluster 5)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Paralysis agitans::332.0::C0030567
# Count matrix:
#  [[   0    0]
#  [3761   78]]
# empty class(es)
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[1993   73]
#  [1768    5]]
# Chi-squared test statistics: chi2_stat = 49.05512699235397 -- p_val = 2.488688810783566e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Carbidopa::2019::C0006982
# Count matrix:
#  [[1193   52]
#  [2568   26]]
# Chi-squared test statistics: chi2_stat = 41.00755377156396 -- p_val = 1.5164199368281698e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: medication::Levodopa::6375::C0023570
# Count matrix:
#  [[1511   61]
#  [2250   17]]
# Chi-squared test statistics: chi2_stat = 44.14503801402557 -- p_val = 3.0492376726836914e-11 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Abnormality of gait::781.2::C0575081
# Count matrix:
#  [[2631   76]
#  [1130    2]]
# Chi-squared test statistics: chi2_stat = 26.449557023498265 -- p_val = 2.7051050622496823e-07 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[2723   72]
#  [1038    6]]
# Chi-squared test statistics: chi2_stat = 14.305537259949844 -- p_val = 0.0001554070654626793 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::1014268::C0201850
# Count matrix:
#  [[2291   78]
#  [1470    0]]
# Chi-squared test statistics: chi2_stat = 47.763670499077165 -- p_val = 4.808197972767718e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Phosphatase, alkaline::84075::C0201850|C3516363
# Count matrix:
#  [[2291   78]
#  [1470    0]]
# Chi-squared test statistics: chi2_stat = 47.763670499077165 -- p_val = 4.808197972767718e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[3146   77]
#  [ 615    1]]
# Chi-squared test statistics: chi2_stat = 11.788112153424207 -- p_val = 0.0005961015459400709 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Albumin::1011249::C0201838
# Count matrix:
#  [[2326   78]
#  [1435    0]]
# Chi-squared test statistics: chi2_stat = 45.90944987570005 -- p_val = 1.23847099224643e-11 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Comprehensive metabolic panel this panel must include the following: albumin (82040) bilirubin, total (82247) calcium, total (82310) carbon dioxide (bicarbonate) (82374) chloride (82435) creatinine (82565) glucose (82947) phosphatase, alkaline (84075) potassium (84132) protein, total (84155) sodium (84295) transferase, alanine amino (alt) (sgpt) (84460) transferase, aspartate amino (ast) (sgot) (84450) urea nitrogen (bun) (84520)::80053::C0201975|C0201838|C0337438|C0201930|C0201952|C0519825|C0201925|C0201850
# Count matrix:
#  [[2397   78]
#  [1364    0]]
# Chi-squared test statistics: chi2_stat = 42.309176969472105 -- p_val = 7.792604533158271e-11 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Blood count; complete (cbc), automated (hgb, hct, rbc, wbc and platelet count)::85027::C3525787|C3516392|C1144713|C0373763|C3495375|C3525786|C3516393
# Count matrix:
#  [[2273   78]
#  [1488    0]]
# Chi-squared test statistics: chi2_stat = 48.73877346710507 -- p_val = 2.9242766627194095e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Urinalysis, by dip stick or tablet reagent for bilirubin, glucose, hemoglobin, ketones, leukocytes, nitrite, ph, protein, specific gravity, urobilinogen, any number of these constituents; automated, without microscopy::81003::C3525585|C3516205|C0373520|C3525584
# Count matrix:
#  [[2306   78]
#  [1455    0]]
# Chi-squared test statistics: chi2_stat = 46.96233587983676 -- p_val = 7.236407785537588e-12 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Bilirubin::1011294::C0201913
# Count matrix:
#  [[2424   78]
#  [1337    0]]
# Chi-squared test statistics: chi2_stat = 40.99370510788382 -- p_val = 1.5272031955063508e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Protein::1011659::C0202202
# Count matrix:
#  [[2424   78]
#  [1337    0]]
# Chi-squared test statistics: chi2_stat = 40.99370510788382 -- p_val = 1.5272031955063508e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Transferase::1011714::C3853637
# Count matrix:
#  [[2424   78]
#  [1337    0]]
# Chi-squared test statistics: chi2_stat = 40.99370510788382 -- p_val = 1.5272031955063508e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: cpt::Carbon dioxide (bicarbonate)::82374::C0201930|C3516311
# Count matrix:
#  [[2483   78]
#  [1278    0]]
# Chi-squared test statistics: chi2_stat = 38.21572566748128 -- p_val = 6.333989957022991e-10 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[2973   76]
#  [ 788    2]]
# Chi-squared test statistics: chi2_stat = 14.703411033548866 -- p_val = 0.0001258185852023913 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[2814   76]
#  [ 947    2]]
# Chi-squared test statistics: chi2_stat = 19.80424243574368 -- p_val = 8.579204561160486e-06 -- dof = 1
# Odds ratio chi2 test for cluster 0term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[2982   76]
#  [ 779    2]]
# Chi-squared test statistics: chi2_stat = 14.431564638397116 -- p_val = 0.00014534562452477877 -- dof = 1
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Paralysis agitans::332.0::C0030567
# Count matrix:
#  [[   0    0]
#  [3761   78]]
# empty class(es)
# Odds ratio chi2 test for cluster 1term: medication::Carbidopa 25 mg::315568::C0984524
# Count matrix:
#  [[2128   42]
#  [1633   36]]
# Chi-squared test statistics: chi2_stat = 0.13456114738943406 -- p_val = 0.7137489820550511 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Levodopa 100 mg::316141::C0987130
# Count matrix:
#  [[2181   43]
#  [1580   35]]
# Chi-squared test statistics: chi2_stat = 0.1527775291105451 -- p_val = 0.6958950583091253 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Carbidopa::2019::C0006982
# Count matrix:
#  [[1193   52]
#  [2568   26]]
# Chi-squared test statistics: chi2_stat = 41.00755377156396 -- p_val = 1.5164199368281698e-10 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Pramipexole::746741::C0074710
# Count matrix:
#  [[3192   63]
#  [ 569   15]]
# Chi-squared test statistics: chi2_stat = 0.7041404501672355 -- p_val = 0.40139593059381684 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Levodopa::6375::C0023570
# Count matrix:
#  [[1511   61]
#  [2250   17]]
# Chi-squared test statistics: chi2_stat = 44.14503801402557 -- p_val = 3.0492376726836914e-11 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Rasagiline 1 mg::608326::C1638357
# Count matrix:
#  [[3321   67]
#  [ 440   11]]
# Chi-squared test statistics: chi2_stat = 0.2255219920075774 -- p_val = 0.6348642687974407 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Selegiline::9639::C0036579
# Count matrix:
#  [[3319   67]
#  [ 442   11]]
# Chi-squared test statistics: chi2_stat = 0.2112070843846212 -- p_val = 0.6458229443763586 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Amantadine::620::C0002403
# Count matrix:
#  [[3147   69]
#  [ 614    9]]
# Chi-squared test statistics: chi2_stat = 0.9600019669460274 -- p_val = 0.3271863822201919 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Abnormal involuntary movements::781.0::C0392702
# Count matrix:
#  [[3287   71]
#  [ 474    7]]
# Chi-squared test statistics: chi2_stat = 0.6168435863972376 -- p_val = 0.4322226530807416 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Trihexyphenidyl::10811::C0041009
# Count matrix:
#  [[3591   73]
#  [ 170    5]]
# Chi-squared test statistics: chi2_stat = 0.26826405270279124 -- p_val = 0.6044986445472653 -- dof = 1
# Odds ratio chi2 test for cluster 1term: cpt::Magnetic resonance (eg, proton) imaging, brain (including brain stem); without contrast material::70551::C3866606|C0412675|C0202699
# Count matrix:
#  [[2897   70]
#  [ 864    8]]
# Chi-squared test statistics: chi2_stat = 6.333040584302375 -- p_val = 0.011850896889854003 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Vitamin d3::1244014::C3265062
# Count matrix:
#  [[3052   70]
#  [ 709    8]]
# Chi-squared test statistics: chi2_stat = 3.1723047955253194 -- p_val = 0.0748966849872637 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Clonazepam 0.5 mg::315699::C0985016
# Count matrix:
#  [[3245   72]
#  [ 516    6]]
# Chi-squared test statistics: chi2_stat = 1.8778219041299902 -- p_val = 0.17058190916342392 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Cholecalciferol::2418::C0008318
# Count matrix:
#  [[3146   71]
#  [ 615    7]]
# Chi-squared test statistics: chi2_stat = 2.544173350949378 -- p_val = 0.11070183684054247 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Aspirin 81 mg::315431::C0983882
# Count matrix:
#  [[2738   71]
#  [1023    7]]
# Chi-squared test statistics: chi2_stat = 12.018393703256715 -- p_val = 0.0005267808201028985 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[2723   72]
#  [1038    6]]
# Chi-squared test statistics: chi2_stat = 14.305537259949844 -- p_val = 0.0001554070654626793 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[1993   73]
#  [1768    5]]
# Chi-squared test statistics: chi2_stat = 49.05512699235397 -- p_val = 2.488688810783566e-12 -- dof = 1
# Odds ratio chi2 test for cluster 1term: icd9::Essential and other specified forms of tremor::333.1::C1961111
# Count matrix:
#  [[3589   76]
#  [ 172    2]]
# Chi-squared test statistics: chi2_stat = 0.32416188669894325 -- p_val = 0.569117173047474 -- dof = 1
# Odds ratio chi2 test for cluster 1term: medication::Calcium::1895::C0006675
# Count matrix:
#  [[3284   73]
#  [ 477    5]]
# Chi-squared test statistics: chi2_stat = 2.196925177793799 -- p_val = 0.13828633842176016 -- dof = 1

# %% [markdown]
# ## Results
# ```mixed-nobn-act-relu-10-overlap5-l32```

# %% [markdown]
# __Outer analysis (scaled)__
#
# ```
# Cluster: 0 -- Entropy: 2.346, Purity: 0.341
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 1 -- Entropy: 2.087, Purity: 0.382
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 2 -- Entropy: 1.662, Purity: 0.527
# max(P) in cluster disease OTH
# Cluster: 3 -- Entropy: 0.347, Purity: 0.953
# max(P) in cluster disease multiple myeloma
# Cluster: 4 -- Entropy: 1.719, Purity: 0.408
# max(P) in cluster disease parkinson's disease
# Cluster: 5 -- Entropy: 0.826, Purity: 0.839
# max(P) in cluster disease malignant tumor of prostate
# Average Entropy: 1.85
# Average Purity: 0.48
# ```
#
# __Inner analysis (scaled)__
#
# ```
# OTH -- 2 -- 0.199
# Alzheimer's -- 2 -- 0.254
# Breast Cancer -- 2 -- 0.205
# Prostate Cancer -- 3 -- 0.090
# MM -- 2 -- 0.182
# Parkinson -- 2 -- 0.262
# ```

# %% [markdown]
# ```mixed-icdmed-nobn-noact-norelu-10-overlap5-l64```

# %% [markdown]
# __Outer analysis (scaled)__
#
# ```
# Cluster: 0 -- Entropy: 2.257, Purity: 0.323
# max(P) in cluster disease alzheimer's disease
# Cluster: 1 -- Entropy: 2.197, Purity: 0.407
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 2 -- Entropy: 0.280, Purity: 0.963
# max(P) in cluster disease malignant tumor of prostate
# Cluster: 3 -- Entropy: 1.935, Purity: 0.343
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 4 -- Entropy: 0.479, Purity: 0.929
# max(P) in cluster disease OTH
# Cluster: 5 -- Entropy: 1.460, Purity: 0.525
# max(P) in cluster disease multiple myeloma
# Average Entropy: 1.75
# Average Purity: 0.50
# ```
#
# __Inner analysis (scaled)__
#
# ```
# OTH -- 3 -- 0.108
# Alzheimer's -- 3 -- 0.126
# Breast Cancer -- 2 -- 0.111
# Prostate Cancer -- 5 -- 0.125
# MM -- 2 -- 0.175
# Parkinson -- 2 -- 0.119
# ```

# %% [markdown]
# ```mixed-nobn-noact-norelu-10-overlap5-l32```

# %% [markdown]
# __Outer analysis (scaled)__
#
# ```
# Cluster: 0 -- Entropy: 2.388, Purity: 0.257
# max(P) in cluster disease OTH
# Cluster: 1 -- Entropy: 2.390, Purity: 0.317
# max(P) in cluster disease OTH
# Cluster: 2 -- Entropy: 1.628, Purity: 0.519
# max(P) in cluster disease OTH
# Cluster: 3 -- Entropy: 0.170, Purity: 0.979
# max(P) in cluster disease malignant tumor of prostate
# Cluster: 4 -- Entropy: 0.430, Purity: 0.938
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 5 -- Entropy: 0.191, Purity: 0.976
# max(P) in cluster disease multiple myeloma
# Average Entropy: 1.77
# Average Purity: 0.48
# ```
#
# __Inner analysis (scaled)__
#
# ```
# OTH -- 2 -- 0.097
# Alzheimer's -- 2 -- 0.153
# Breast Cancer -- 4 -- 0.108
# Prostate Cancer -- 3 -- 0.105
# MM -- 2 -- 0.217
# Parkinson -- 2 -- 0.211
# ```

# %% [markdown]
# ```mixed-icdmed-2019-03-08-10-35-14-median-nobn-noact-norelu-10-l64```

# %% [markdown]
# __Outer analysis (scaled)__
#
# ```
# Cluster: 0 -- Entropy: 1.655, Purity: 0.460
# max(P) in cluster disease parkinson's disease
# Cluster: 1 -- Entropy: 2.436, Purity: 0.260
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 2 -- Entropy: 0.727, Purity: 0.859
# max(P) in cluster disease OTH
# Cluster: 3 -- Entropy: 1.753, Purity: 0.394
# max(P) in cluster disease malignant tumor of prostate
# Cluster: 4 -- Entropy: 0.267, Purity: 0.967
# max(P) in cluster disease malignant neoplasm of female breast
# Cluster: 5 -- Entropy: 1.446, Purity: 0.638
# max(P) in cluster disease malignant tumor of prostate
# Average Entropy: 1.77
# Average Purity: 0.47
# ```
#
# __Inner analysis (scaled)__
#
# ```
# OTH -- 2 -- 0.121
# Alzheimer's -- 2 -- 0.105
# Breast Cancer -- 3 -- 0.095
# Prostate Cancer -- 3 -- 0.116
# MM -- 5 -- 0.139
# Parkinson -- 2 -- 0.147
# ```
