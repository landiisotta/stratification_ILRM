# %% [markdown]
# # CNN - AE model validation

# %%
import os
import csv
import random
import umap
import numpy as np
from os import path
from scipy import stats
from sklearn import preprocessing
from sklearn.manifold.t_sne import TSNE
from sklearn import metrics
from sklearn.metrics import silhouette_score
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits import mplot3d
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
# data directories
homedir = os.path.expanduser('~')
prjdir = 'data1/stratification_ILRM'
datadir = 'data'
outdir = path.join(homedir, prjdir, datadir, 'neurodev-disorder')
expdir = path.join(homedir, prjdir, datadir, 'experiments/neurodev-disorder-2019-03-14-05-15-16-nobn-noact-norelu-10-l64')
# sub-sampling
n_samples = None

# get the list of diagnosed diseases associated with mrns
with open(path.join(outdir, 'cohort-mrn_diseases.csv')) as f:
    rd = csv.reader(f)
    mrn_disease = {r[0]: r[1::] for r in rd}

# evaluate potential disease classes

# read encoded vectors file and ordered medical record numbers
with open(path.join(expdir, 'NDDmrns.csv')) as f:
    rd = csv.reader(f)
    mrns = [r[0] for r in rd]
    
# (1) first diagnosis
gt_disease = {}
for m in mrn_disease:
    if mrn_disease[m][0]!='pervasive developmental disorder' and mrn_disease[m][0]!='OTH' and m in mrns:
        gt_disease[m] = mrn_disease[m][0]
    else:
        pass

with open(path.join(expdir, 'NDDencoded_vect.csv')) as f:
    rd = csv.reader(f)
    encoded = [list(map(float, r)) for r in rd]

tmp_mrns = []
tmp_encoded = []
for idx, m in enumerate(mrns):
    if m in gt_disease.keys():
        tmp_mrns.append(m)
        tmp_encoded.append(encoded[idx])
    else:
        pass
mrns = tmp_mrns
encoded = tmp_encoded

# %%
len(gt_disease)
# Out:
# 8137

# %%
set_mrns = set(mrns)
    
# read the vocabulary
with open(path.join(outdir, 'cohort-eval_vocab.csv')) as f:    
    rd = csv.reader(f)
#     next(rd)
    vocab = {r[1]: r[0] for r in rd}
len_vocab = len(vocab)

# read raw data
with open(path.join(outdir, 'cohort-eval_ehr.csv')) as f:
    rd = csv.reader(f)
    raw_ehr = {}
    for r in rd:
        if r[0] in gt_disease.keys():
            raw_ehr.setdefault(r[0], list()).extend(list(map(int, r[1::])))

# %%
len(raw_ehr)
# Out:
# 8137

# %%
disease_count = {}
for d in gt_disease.values():
    if d not in disease_count:
        disease_count[d] = 1
    else:
        disease_count[d] += 1
print(len(gt_disease))
# Out:
# 8137

# %%
disease_count
# Out:
# {'attention deficit': 5924, 'autism': 814, 'mental retardation': 1399}

# %% [markdown]
# >`svd_tfidf():` returns the SVD matrix of the TFIDF matrix of the raw ehr data;
#
# >`silhouette_analysis():` hierarchical clustering on input data maximizing the Silhouette Index
#
# >`single_plot():` one plot of all the clusters
#
# >`nonoveralp_plot():` N different plots, one per cluster, with N = no. of clusters
#
# > `outer_clustering_analysis():` external validation of clustering (entropy and Purity scores)

# %%
# Hierarchical clustering parameters
# Frequency count analysis parameters
ehr_strat_model = True

if ehr_strat_model == False:
    HCpar = {'linkage_clu':'complete',
             'affinity_clu':'cosine',
             'min_cl':3,
             'max_cl':11}
else:
    HCpar = {'linkage_clu':'ward',
             'affinity_clu':'euclidean',
             'min_cl':3,
             'max_cl':11}
FRpar = {'n_terms':10,
        'ty_terms':['icd9']}

# %%
# analyze clustering using silhouette scores
def silhouette_analysis(data,
                        min_clu=HCpar['min_cl'],
                        max_clu=HCpar['max_cl'],
                       preproc=False):
    if preproc:
        data = preprocessing.scale(data)
    # bound analysis range
    if min_clu < 2:
        min_clu = 2

    # run analysis for every clustering size
    best_silh = 0
    silh_scores = []
    for n in range(min_clu, max_clu, 1):
        hclu = AgglomerativeClustering(n_clusters=n,
                                       linkage=HCpar['linkage_clu'],
                                       affinity=HCpar['affinity_clu'])
        lbl = hclu.fit_predict(data).tolist()
        silh = silhouette_score(data, lbl, metric=HCpar['affinity_clu'])
        if silh < 0:
            break
        print(' -- {0}: {1:.3f}'.format(n, silh))
        silh_scores.append(silh)
        if silh > best_silh:
            best_silh = silh
            n_clu = n
            label = lbl
    try:
        print('No. of clusters: {0} -- Silhouette Score: {1:.3f}\n'.format(
            n_clu, best_silh))

    except UnboundLocalError:
        hclu = AgglomerativeClustering(n_clusters=min_clu,
                                       linkage=HCpar['linkage_clu'],
                                       affinity=HCpar['affinity_clu'])
        n_clu = min_clu
        label = hclu.fit_predict(data).tolist()
        print('No. of Clusters: {0} -- Silhouette Score: {1:.3f}\n'.format(
            n_clu, best_silh))

    plt.plot(range(min_clu, max_clu, 1), silh_scores)
    return (n_clu, label, silh_scores)


# SVD matrix of the TFIDF matrix of the raw ehr data
def svd_tfidf(data, len_vocab, n_dimensions=200, tfidf=False):
    if tfidf:
    # apply tf-idf
        tfidf = TfidfTransformer()
        mtx = tfidf.fit_transform(data)
    else:
        scaler = MinMaxScaler()
        mtx = scaler.fit_transform(data)
    # reduce size of the matrix
    svd = TruncatedSVD(n_components=n_dimensions)
    svd_mtx = svd.fit_transform(mtx)

    return svd_mtx


# one plot with all the clusters
def single_plot(data, mrn_disease, colors, leg_labels=None):
    plt.figure(figsize=(20,10))
    for cl in set(mrn_disease):
        x = [d[0] for j, d in enumerate(data) if mrn_disease[j] == cl]
        y = [d[1] for j, d in enumerate(data) if mrn_disease[j] == cl]
        cols = [c for j, c in enumerate(colors) if mrn_disease[j] == cl]
        plt.xticks([])
        plt.yticks([])
        plt.scatter(x,y,c=cols, label=cl)
    if leg_labels is not None:
        plt.legend(labels=leg_labels, loc=2, fontsize=10, markerscale=2)
    else:
        plt.legend(loc=2, fontsize=10, markerscale=2)
#     plt.savefig(path.join(homedir, prjdir, datadir, 'neurodev-disorder/neurodev-data.png'))
 
    
# non-overlapping plots, one per cluster
def nonoverlap_plot(data, mrn_disease, colors):
    fig, ax = plt.subplots(len(set(mrn_disease)), 1, figsize=(20, 10*len(set(mrn_disease))))
    for idx, cl in enumerate(set(mrn_disease)):
        x = [d[0] for j, d in enumerate(data) if mrn_disease[j] == cl]
        y = [d[1] for j, d in enumerate(data) if mrn_disease[j] == cl]
        cols = [c for j, c in enumerate(colors) if mrn_disease[j] == cl]
        ax[idx].set_xticks([])
        ax[idx].set_yticks([])
        ax[idx].scatter(x, y, c=cols, label=cl)
        ax[idx].legend()

        
# external clustering analysis
def outer_clustering_analysis(data, gt_clu, preproc=False):
    
    if preproc:
        data = preprocessing.scale(data)
        
    label_clu = sorted(set(gt_clu))

    # format clustering ground truth
    didx = {d: i for i, d in enumerate(label_clu)}
    idxd = {i:d for d, i in didx.items()}
    gt = [didx[d] for d in gt_clu]

    # validate cluster number
    if len(label_clu) == 1:
        n_clu = 3
    else:
        n_clu = len(label_clu)

    # run clustering
    hclust = AgglomerativeClustering(n_clusters=n_clu,
                                     linkage=HCpar['linkage_clu'],
                                     affinity=HCpar['affinity_clu'])
    clusters = hclust.fit_predict(data).tolist()

    # count cluster occurrences
    cnt_clu = [0] * n_clu
    for c in clusters:
        cnt_clu[c] += 1
    class_clu = [[0] * n_clu for _ in range(len(label_clu))]
    for i, gi in enumerate(gt):
        class_clu[gi][clusters[i]] += 1

    # compute entropy and purity
    entropy = 0
    purity = 0
    pur_vec = []
    for j in range(0, max(clusters) + 1):
        en = 0
        pu = []
        for i in range(0, max(gt) + 1):
            pij = class_clu[i][j] / cnt_clu[j]
            pu.append(pij)
            if pij != 0:
                en += -(pij * np.log2(pij))
        max_pu = max(pu)
        print(
            'Cluster: {0} -- '
            'Entropy: {1:.3f}, '
            'Purity: {2:.3f}'.format(j, en, max_pu))
        for idx, p in enumerate(pu):
            print("P={0:.2f} in cluster disease {1}".format(p, idxd[idx]))
        cweight = cnt_clu[j] / len(gt)
        entropy += cweight * en
        purity += cweight * max_pu
        pur_vec.append(pu)
    print('Average Entropy: {0:.2f}'.format(entropy))
    print('Average Purity: {0:.2f}'.format(purity))
    
    return clusters, pur_vec, idxd

#Input: ehr lists corresponding to a cluster 
#Output: dictionary of term counts
def FreqDict(tokens):
    freq_dict = {}
    tok = []
    for seq in tokens:
        tok.extend(seq)
    
    tok = set(tok)
    for t in tok:
        for seq in tokens:
            if t in seq:
                if t not in freq_dict:
                    freq_dict[t] = 1
                else:
                    freq_dict[t] += 1
    return freq_dict
#Input: dictionary cluster:ehrs; list mrns
#Output:
def freq_term(data, pred_class):
    list_terms = []
    for subc in range(len(set(pred_class))):
        tmp_data = {}
        for j in range(len(pred_class)):
            if pred_class[j] == subc:
                tmp_data.setdefault(subc, list()).append([rd for rd in data[j] 
                                                           if rd!=0 and 
                                                           (str.split(vocab[str(rd)], "::")[0] 
                                                           in FRpar['ty_terms'])])
        print("Cluster {0} numerosity: {1}".format(subc, len(tmp_data[subc])))
        term_count = FreqDict(tmp_data[subc])
        clust_mostfreq = []
        for l in range(FRpar['n_terms']):
            try:
                MFMT = max(term_count, key=(lambda key: term_count[key]))
                num_MFMT = 0
                subc_termc = 0
                for ehr in tmp_data[subc]:
                    for e in ehr:
                        if e == MFMT:
                            subc_termc += 1
                for seq in raw_ehr.values():
                    for t in seq:
                        if t == MFMT:
                            num_MFMT += 1
                print("% most frequent term:{0} "
                       "= {1:.2f} ({2} out of {3} terms in the whole dataset"
                       "-- N patients in cluster {4})".format(vocab[str(MFMT)], 
                                                              subc_termc/num_MFMT, 
                                                              subc_termc,
                                                              num_MFMT,
                                                              term_count[MFMT]))
                term_count.pop(MFMT)
                clust_mostfreq.append(MFMT)
            except ValueError:
                pass
        print("\n")
        list_terms.append(clust_mostfreq)
    return list_terms

##Hierarchical clustering function. Max silhouette.
def hclust_ehr(data):
    best_silh = -1
    list_silh = []
    for nc in range(HCpar['min_cl'],HCpar['max_cl'],1):
        hclust = AgglomerativeClustering(n_clusters=nc, 
                                         linkage=HCpar['linkage_clu'], 
                                         affinity=HCpar['affinity_clu'])
        tmp_label = hclust.fit_predict(data).tolist()
        tmp_silh = silhouette_score(data, tmp_label, metric=HCpar['affinity_clu'])
        print(nc, tmp_silh)
        list_silh.append(float(tmp_silh))
        if tmp_silh > best_silh:
            best_silh = tmp_silh
            n_clust = nc
            label = tmp_label
    try:
        print("Number of clusters found:{0}, Silhouette score:{1:.3f}\n".format(n_clust, best_silh))
    except UnboundLocalError:
        hclust = AgglomerativeClustering(n_clusters=HCpar['min_cl'],
                                         linkage=HCpar['linkage_clu'],
                                         affinity=HCpar['affinity_clu'])
        n_clust = HCpar['min_cl']
        label = hclust.fit_predict(data).tolist()
        best_silh = silhouette_score(data, label)
        print("Number of clusters found:{0}, Silhouette score:{1:.3f}\n".format(n_clust, best_silh))
    return n_clust, label, list_silh

def chi_test(data, new_classes, term, mrns):
    count_mat = np.zeros((2, len(set(new_classes))), dtype=int)
    for c in set(new_classes):
        for idx, m in enumerate(mrns):
            if new_classes[idx] == c:
                if term in data[idx]:
                    count_mat[1][c] += 1
                else:
                    count_mat[0][c] += 1
    print("Count matrix:\n {0}".format(count_mat))
    chi2_stat, p_val, dof, ex = stats.chi2_contingency(count_mat)
    string = "Chi-squared test statistics: chi2_stat = {0} -- p_val = {1} -- dof = {2}".format(
                                                                  chi2_stat,
                                                                  p_val,
                                                                  dof)#row = classes, columns = vocab
    print(string)


##Internal clustering validation
def inner_clustering_analysis(disease_class, data, mrns, viz_data, preproc=False):
    if preproc:
        data = preprocessing.scale(data)
    dis_viz_data = []
    subclass_dis = []
    for dis in sorted(set(disease_class)):
        tmp_data = []
        tmp_mrn = []
        tmp_raw_ehr = []
        for idx, d in enumerate(disease_class):
            if d == dis:
                dis_viz_data.append(viz_data[idx])
                tmp_data.append(data[idx])
                tmp_mrn.append(mrns[idx])
                tmp_raw_ehr.append(raw_ehr[mrns[idx]])
        print("Inspecting disease: {0}\n".format(dis))
        n_clust, label, _ = hclust_ehr(tmp_data)
        subclass_dis.extend([dis + ': subclust ' + str(l) for l in label])
        list_terms = freq_term(tmp_raw_ehr, label)
        for l in range(len(set(label))):
            for lt in range(len(list_terms[l])):
                print("Odds ratio chi2 test for cluster {0}"
                      "term: {1}".format(l, vocab[str(list_terms[l][lt])]))
                try:
                    chi_test(tmp_raw_ehr, label, list_terms[l][lt], tmp_mrn)
                except ValueError:
                    print("empty class(es)")
                    pass
            print("\n\n")
    return(dis_viz_data, subclass_dis)

# %% [markdown]
# ## Run t-SNE for data visualization

# %%
# initialize T-SNE
# reducer = umap.UMAP(n_neighbors=200, min_dist=0.5, metric = HCpar['affinity_clu'], n_components=2)
tsne = TSNE(n_components=2, n_iter=5000, perplexity=40, random_state=42)

# %%
# plot colors
col_dict = matplotlib.colors.CSS4_COLORS
c_out = ['mintcream', 'cornsilk', 'lavenderblush', 'aliceblue', 'antiquewhite', 'aqua', 'aquamarine', 'azure', 'beige', 'powderblue', 'floralwhite', 'ghostwhite',
 'lightcoral', 'lightcyan', 'lightgoldenrodyellow', 'lightgray', 'lightgreen', 'lightgrey', 'lightpink', 'lightsalmon', 'lightseagreen', 'lightskyblue',
 'lightslategray', 'lightslategrey', 'lightsteelblue', 'lightyellow', 'linen', 'palegoldenrod', 'palegreen', 'paleturquoise', 'palevioletred', 'papayawhip',
 'peachpuff', 'mistyrose', 'lemonchiffon', 'lightblue', 'seashell', 'white', 'blanchedalmond', 'oldlace', 'moccasin', 'snow', 'darkgray',
 'ivory', 'whitesmoke']
colormap = [c for c in col_dict if c not in c_out]

# %%
# t-SNE on the CNN encoded vectors
# encoded = preprocessing.scale(encoded)
# encoded_umap = reducer.fit_transform(encoded).tolist()
encoded_tsne = tsne.fit_transform(encoded).tolist()

print('Computed: CNN - AE encoded vectors umap')
# Out:
# Computed: CNN - AE encoded vectors umap

# %% [markdown]
# ### t-SNE visualization and external clustering validation

# %%
# choose the disease classes: first_disease, oth_disease
disease_class_first = [gt_disease[m] for m in mrns]
# raw_disease_class_first = [gt_disease[m] for m in mrn_list]
# lstm_disease_class_first = [gt_disease[m] for m in lstm_mrns]
disease_dict = {d: i for i, d in enumerate(set(disease_class_first))}

# %% [markdown]
# ### CNN - AE encodings

# %%
# plot data
colors_en1 = [colormap[disease_dict[v]] for v in disease_class_first]
single_plot(encoded_tsne, disease_class_first, colors_en1)

# %%
# nonoverlap_plot(encoded_umap, disease_class_first, colors_en1)

# %%
# plot cluster results
clusters, pur_vec, idxd = outer_clustering_analysis(encoded, disease_class_first, preproc=True)
# Out:
# Cluster: 0 -- Entropy: 1.340, Purity: 0.555
# P=0.56 in cluster disease attention deficit
# P=0.10 in cluster disease autism
# P=0.34 in cluster disease mental retardation
# Cluster: 1 -- Entropy: 0.761, Purity: 0.850
# P=0.85 in cluster disease attention deficit
# P=0.08 in cluster disease autism
# P=0.07 in cluster disease mental retardation
# Cluster: 2 -- Entropy: 0.824, Purity: 0.823
# P=0.82 in cluster disease attention deficit
# P=0.13 in cluster disease autism
# P=0.05 in cluster disease mental retardation
# Average Entropy: 1.00
# Average Purity: 0.73

# %%
labels = []
for p in pur_vec:
    idx = p.index(max(p))
    labels.append(idxd[idx])
colors_en2 = [colormap[v] for v in clusters]
single_plot(encoded_tsne, clusters, colors_en2, labels)
for i in range(len(set(clusters))):
    print("Cluster numerosity:{0}".format(clusters.count(i)))
# Out:
# Cluster numerosity:3181
# Cluster numerosity:2977
# Cluster numerosity:1979

# %%
# data to plot
n_groups = 3
colors_en2 = ['b', 'g', 'm']
# create plot
fig, ax = plt.subplots(figsize=(20,10))
index = np.arange(n_groups)
bar_width = 0.15
opacity = 0.8

for idx in range(n_groups):
    rects = plt.bar(index, [p[idx] for p in pur_vec], bar_width,
    alpha=opacity,
    color=colors_en2[idx],
    label=idxd[idx])
    index = index + bar_width
    print(index)
plt.xlabel('')
plt.ylabel('Purity score', size=15)
plt.title('')
plt.xticks(np.arange(n_groups) + 0.375, 
           ('Clust:0', 'Clust:1', 'Clust:2'), size=15)
plt.yticks(size=15)
plt.legend(markerscale=5, fontsize=15)
 
# plt.tight_layout()
plt.show()
# Out:
# [0.15 1.15 2.15]
# [0.3 1.3 2.3]
# [0.45 1.45 2.45]

# %%
 _, _, _ = silhouette_analysis(encoded, preproc=False)
# Out:
#  -- 2: 0.202
#  -- 3: 0.187
#  -- 4: 0.192
#  -- 5: 0.199
#  -- 6: 0.189
#  -- 7: 0.186
#  -- 8: 0.143
#  -- 9: 0.106
#  -- 10: 0.098
# No. of clusters: 2 -- Silhouette Score: 0.202

# %%
# inner clustering analysis
encoded_subplots, en_sub_clust = inner_clustering_analysis(disease_class_first, encoded, mrns, 
                                                           encoded_tsne, preproc=True)
# Out:
# Inspecting disease: attention deficit
#
# 3 0.1328594167854572
# 4 0.13504455487180567
# 5 0.08321791635800177
# 6 0.0805761415566909
# 7 0.07181162843485969
# 8 0.06926809307362114
# 9 0.06759244804094718
# 10 0.0644176783102479
# Number of clusters found:4, Silhouette score:0.135
#
# Cluster 0 numerosity: 2112
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.13 (6249 out of 46765 terms in the whole dataset-- N patients in cluster 1667)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.31 (2918 out of 9379 terms in the whole dataset-- N patients in cluster 895)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.08 (522 out of 6728 terms in the whole dataset-- N patients in cluster 246)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.03 (271 out of 8097 terms in the whole dataset-- N patients in cluster 221)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.07 (449 out of 5988 terms in the whole dataset-- N patients in cluster 221)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.07 (370 out of 5071 terms in the whole dataset-- N patients in cluster 199)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.08 (481 out of 5970 terms in the whole dataset-- N patients in cluster 175)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.07 (464 out of 6913 terms in the whole dataset-- N patients in cluster 162)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.02 (201 out of 10742 terms in the whole dataset-- N patients in cluster 144)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.08 (255 out of 3284 terms in the whole dataset-- N patients in cluster 137)
#
#
# Cluster 1 numerosity: 1808
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.39 (18357 out of 46765 terms in the whole dataset-- N patients in cluster 1585)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.40 (3733 out of 9379 terms in the whole dataset-- N patients in cluster 793)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.29 (2362 out of 8097 terms in the whole dataset-- N patients in cluster 776)
# % most frequent term:icd9::Depressive disorder, not elsewhere classified::311::C0868892 = 0.50 (3454 out of 6913 terms in the whole dataset-- N patients in cluster 592)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.20 (1465 out of 7284 terms in the whole dataset-- N patients in cluster 569)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.21 (2226 out of 10742 terms in the whole dataset-- N patients in cluster 533)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.49 (2934 out of 5988 terms in the whole dataset-- N patients in cluster 484)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.37 (2214 out of 5970 terms in the whole dataset-- N patients in cluster 479)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.17 (2151 out of 12937 terms in the whole dataset-- N patients in cluster 449)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.45 (3038 out of 6728 terms in the whole dataset-- N patients in cluster 441)
#
#
# Cluster 2 numerosity: 1155
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.37 (17489 out of 46765 terms in the whole dataset-- N patients in cluster 1058)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.55 (7101 out of 12937 terms in the whole dataset-- N patients in cluster 814)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.41 (2957 out of 7284 terms in the whole dataset-- N patients in cluster 784)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.46 (1809 out of 3942 terms in the whole dataset-- N patients in cluster 601)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.48 (5140 out of 10742 terms in the whole dataset-- N patients in cluster 600)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.42 (1789 out of 4215 terms in the whole dataset-- N patients in cluster 556)
# % most frequent term:icd9::Acute pharyngitis::462::C0001344 = 0.49 (1225 out of 2488 terms in the whole dataset-- N patients in cluster 491)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.41 (645 out of 1586 terms in the whole dataset-- N patients in cluster 480)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.23 (1883 out of 8097 terms in the whole dataset-- N patients in cluster 477)
# % most frequent term:icd9::Unspecified viral infection::079.99::C0153114 = 0.49 (960 out of 1971 terms in the whole dataset-- N patients in cluster 469)
#
#
# Cluster 3 numerosity: 849
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.08 (3933 out of 46765 terms in the whole dataset-- N patients in cluster 728)
# % most frequent term:icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002 = 0.10 (964 out of 9379 terms in the whole dataset-- N patients in cluster 291)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.03 (378 out of 12937 terms in the whole dataset-- N patients in cluster 180)
# % most frequent term:icd9::Unspecified disturbance of conduct::312.9::C0149654 = 0.07 (334 out of 5071 terms in the whole dataset-- N patients in cluster 162)
# % most frequent term:icd9::Oppositional defiant disorder::313.81::C0029121 = 0.07 (503 out of 6728 terms in the whole dataset-- N patients in cluster 158)
# % most frequent term:icd9::Unspecified episodic mood disorder::296.90::C1456434 = 0.07 (422 out of 5988 terms in the whole dataset-- N patients in cluster 157)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.02 (194 out of 8097 terms in the whole dataset-- N patients in cluster 147)
# % most frequent term:icd9::Anxiety state, unspecified::300.00::C0700613 = 0.06 (375 out of 5970 terms in the whole dataset-- N patients in cluster 138)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.07 (216 out of 3284 terms in the whole dataset-- N patients in cluster 125)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.02 (243 out of 10742 terms in the whole dataset-- N patients in cluster 124)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 445  223   97  121]
#  [1667 1585 1058  728]]
# Chi-squared test statistics: chi2_stat = 111.22494765520467 -- p_val = 5.9800382793053585e-24 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[1217 1015  724  558]
#  [ 895  793  431  291]]
# Chi-squared test statistics: chi2_stat = 29.945953609092207 -- p_val = 1.4166590302517674e-06 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Oppositional defiant disorder::313.81::C0029121
# Count matrix:
#  [[1866 1367  849  691]
#  [ 246  441  306  158]]
# Chi-squared test statistics: chi2_stat = 147.31709120870585 -- p_val = 9.988155779551236e-32 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1891 1032  678  702]
#  [ 221  776  477  147]]
# Chi-squared test statistics: chi2_stat = 679.600610200243 -- p_val = 5.562975236557686e-147 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified episodic mood disorder::296.90::C1456434
# Count matrix:
#  [[1891 1324  909  692]
#  [ 221  484  246  157]]
# Chi-squared test statistics: chi2_stat = 176.80616511962742 -- p_val = 4.3167177064728135e-38 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified disturbance of conduct::312.9::C0149654
# Count matrix:
#  [[1913 1389  730  687]
#  [ 199  419  425  162]]
# Chi-squared test statistics: chi2_stat = 358.20109627716676 -- p_val = 2.4993734358141643e-77 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[1937 1329  874  711]
#  [ 175  479  281  138]]
# Chi-squared test statistics: chi2_stat = 255.18637874654615 -- p_val = 4.943593039164233e-55 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[1950 1216  874  726]
#  [ 162  592  281  123]]
# Chi-squared test statistics: chi2_stat = 420.24499030229174 -- p_val = 9.113410527245555e-91 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1968 1275  555  725]
#  [ 144  533  600  124]]
# Chi-squared test statistics: chi2_stat = 916.098536349477 -- p_val = 2.85177228387596e-198 -- dof = 3
# Odds ratio chi2 test for cluster 0term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[1975 1389  847  724]
#  [ 137  419  308  125]]
# Chi-squared test statistics: chi2_stat = 297.7854394308108 -- p_val = 2.9995517622402766e-64 -- dof = 3
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 445  223   97  121]
#  [1667 1585 1058  728]]
# Chi-squared test statistics: chi2_stat = 111.22494765520467 -- p_val = 5.9800382793053585e-24 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[1217 1015  724  558]
#  [ 895  793  431  291]]
# Chi-squared test statistics: chi2_stat = 29.945953609092207 -- p_val = 1.4166590302517674e-06 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1891 1032  678  702]
#  [ 221  776  477  147]]
# Chi-squared test statistics: chi2_stat = 679.600610200243 -- p_val = 5.562975236557686e-147 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Depressive disorder, not elsewhere classified::311::C0868892
# Count matrix:
#  [[1950 1216  874  726]
#  [ 162  592  281  123]]
# Chi-squared test statistics: chi2_stat = 420.24499030229174 -- p_val = 9.113410527245555e-91 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[2015 1239  371  745]
#  [  97  569  784  104]]
# Chi-squared test statistics: chi2_stat = 1657.7281895390797 -- p_val = 0.0 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1968 1275  555  725]
#  [ 144  533  600  124]]
# Chi-squared test statistics: chi2_stat = 916.098536349477 -- p_val = 2.85177228387596e-198 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified episodic mood disorder::296.90::C1456434
# Count matrix:
#  [[1891 1324  909  692]
#  [ 221  484  246  157]]
# Chi-squared test statistics: chi2_stat = 176.80616511962742 -- p_val = 4.3167177064728135e-38 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[1937 1329  874  711]
#  [ 175  479  281  138]]
# Chi-squared test statistics: chi2_stat = 255.18637874654615 -- p_val = 4.943593039164233e-55 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[1991 1359  341  669]
#  [ 121  449  814  180]]
# Chi-squared test statistics: chi2_stat = 1633.2899946574444 -- p_val = 0.0 -- dof = 3
# Odds ratio chi2 test for cluster 1term: icd9::Oppositional defiant disorder::313.81::C0029121
# Count matrix:
#  [[1866 1367  849  691]
#  [ 246  441  306  158]]
# Chi-squared test statistics: chi2_stat = 147.31709120870585 -- p_val = 9.988155779551236e-32 -- dof = 3
#
#
#
# Odds ratio chi2 test for cluster 2term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 445  223   97  121]
#  [1667 1585 1058  728]]
# Chi-squared test statistics: chi2_stat = 111.22494765520467 -- p_val = 5.9800382793053585e-24 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[1991 1359  341  669]
#  [ 121  449  814  180]]
# Chi-squared test statistics: chi2_stat = 1633.2899946574444 -- p_val = 0.0 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[2015 1239  371  745]
#  [  97  569  784  104]]
# Chi-squared test statistics: chi2_stat = 1657.7281895390797 -- p_val = 0.0 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[2053 1387  554  773]
#  [  59  421  601   76]]
# Chi-squared test statistics: chi2_stat = 1229.5613450620165 -- p_val = 2.8269249716638232e-266 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1968 1275  555  725]
#  [ 144  533  600  124]]
# Chi-squared test statistics: chi2_stat = 916.098536349477 -- p_val = 2.85177228387596e-198 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[2059 1401  599  775]
#  [  53  407  556   74]]
# Chi-squared test statistics: chi2_stat = 1108.902356615786 -- p_val = 4.262757292130122e-240 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Acute pharyngitis::462::C0001344
# Count matrix:
#  [[2059 1434  664  774]
#  [  53  374  491   75]]
# Chi-squared test statistics: chi2_stat = 914.5182264463517 -- p_val = 6.279147482708972e-198 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390
# Count matrix:
#  [[2071 1556  675  794]
#  [  41  252  480   55]]
# Chi-squared test statistics: chi2_stat = 1024.9411525095982 -- p_val = 6.991481769669108e-222 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1891 1032  678  702]
#  [ 221  776  477  147]]
# Chi-squared test statistics: chi2_stat = 679.600610200243 -- p_val = 5.562975236557686e-147 -- dof = 3
# Odds ratio chi2 test for cluster 2term: icd9::Unspecified viral infection::079.99::C0153114
# Count matrix:
#  [[2073 1538  686  810]
#  [  39  270  469   39]]
# Chi-squared test statistics: chi2_stat = 1014.3498586138646 -- p_val = 1.3873572548661004e-219 -- dof = 3
#
#
#
# Odds ratio chi2 test for cluster 3term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[ 445  223   97  121]
#  [1667 1585 1058  728]]
# Chi-squared test statistics: chi2_stat = 111.22494765520467 -- p_val = 5.9800382793053585e-24 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Attention deficit disorder without mention of hyperactivity::314.00::C0339002
# Count matrix:
#  [[1217 1015  724  558]
#  [ 895  793  431  291]]
# Chi-squared test statistics: chi2_stat = 29.945953609092207 -- p_val = 1.4166590302517674e-06 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[1991 1359  341  669]
#  [ 121  449  814  180]]
# Chi-squared test statistics: chi2_stat = 1633.2899946574444 -- p_val = 0.0 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Unspecified disturbance of conduct::312.9::C0149654
# Count matrix:
#  [[1913 1389  730  687]
#  [ 199  419  425  162]]
# Chi-squared test statistics: chi2_stat = 358.20109627716676 -- p_val = 2.4993734358141643e-77 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Oppositional defiant disorder::313.81::C0029121
# Count matrix:
#  [[1866 1367  849  691]
#  [ 246  441  306  158]]
# Chi-squared test statistics: chi2_stat = 147.31709120870585 -- p_val = 9.988155779551236e-32 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Unspecified episodic mood disorder::296.90::C1456434
# Count matrix:
#  [[1891 1324  909  692]
#  [ 221  484  246  157]]
# Chi-squared test statistics: chi2_stat = 176.80616511962742 -- p_val = 4.3167177064728135e-38 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[1891 1032  678  702]
#  [ 221  776  477  147]]
# Chi-squared test statistics: chi2_stat = 679.600610200243 -- p_val = 5.562975236557686e-147 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Anxiety state, unspecified::300.00::C0700613
# Count matrix:
#  [[1937 1329  874  711]
#  [ 175  479  281  138]]
# Chi-squared test statistics: chi2_stat = 255.18637874654615 -- p_val = 4.943593039164233e-55 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[1975 1389  847  724]
#  [ 137  419  308  125]]
# Chi-squared test statistics: chi2_stat = 297.7854394308108 -- p_val = 2.9995517622402766e-64 -- dof = 3
# Odds ratio chi2 test for cluster 3term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[1968 1275  555  725]
#  [ 144  533  600  124]]
# Chi-squared test statistics: chi2_stat = 916.098536349477 -- p_val = 2.85177228387596e-198 -- dof = 3
#
#
#
# Inspecting disease: autism
#
# 3 0.16158041004391785
# 4 0.13906397200750092
# 5 0.09003324761681017
# 6 0.08847209570178932
# 7 0.09109718100902431
# 8 0.09874145923033957
# 9 0.08743578068631043
# 10 0.07956297845205887
# Number of clusters found:3, Silhouette score:0.162
#
# Cluster 0 numerosity: 358
# % most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.41 (1982 out of 4845 terms in the whole dataset-- N patients in cluster 356)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.04 (360 out of 8097 terms in the whole dataset-- N patients in cluster 128)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.04 (458 out of 12937 terms in the whole dataset-- N patients in cluster 109)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.03 (246 out of 7284 terms in the whole dataset-- N patients in cluster 98)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.03 (313 out of 10742 terms in the whole dataset-- N patients in cluster 81)
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.04 (270 out of 6009 terms in the whole dataset-- N patients in cluster 76)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.04 (169 out of 4215 terms in the whole dataset-- N patients in cluster 76)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.07 (278 out of 3926 terms in the whole dataset-- N patients in cluster 72)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.03 (129 out of 3942 terms in the whole dataset-- N patients in cluster 70)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.07 (325 out of 4815 terms in the whole dataset-- N patients in cluster 68)
#
#
# Cluster 1 numerosity: 148
# % most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.18 (885 out of 4845 terms in the whole dataset-- N patients in cluster 148)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.11 (1420 out of 12937 terms in the whole dataset-- N patients in cluster 134)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.08 (557 out of 7284 terms in the whole dataset-- N patients in cluster 128)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390 = 0.19 (301 out of 1586 terms in the whole dataset-- N patients in cluster 111)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.08 (330 out of 3942 terms in the whole dataset-- N patients in cluster 110)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.07 (309 out of 4215 terms in the whole dataset-- N patients in cluster 93)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555 = 0.19 (322 out of 1717 terms in the whole dataset-- N patients in cluster 93)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against varicella::V05.4::C0375770 = 0.18 (124 out of 677 terms in the whole dataset-- N patients in cluster 91)
# % most frequent term:icd9::Fever, unspecified::780.60::C0015967 = 0.12 (253 out of 2092 terms in the whole dataset-- N patients in cluster 87)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against poliomyelitis::V04.0::C1962940 = 0.37 (226 out of 604 terms in the whole dataset-- N patients in cluster 85)
#
#
# Cluster 2 numerosity: 308
# % most frequent term:icd9::Autistic disorder, current or active state::299.00::C0154446 = 0.20 (956 out of 4845 terms in the whole dataset-- N patients in cluster 306)
# % most frequent term:icd9::Attention deficit disorder with hyperactivity::314.01::C1263846 = 0.00 (84 out of 46765 terms in the whole dataset-- N patients in cluster 50)
# % most frequent term:icd9::Unspecified delay in development::315.9::n/a = 0.01 (24 out of 2984 terms in the whole dataset-- N patients in cluster 23)
# % most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.01 (35 out of 3524 terms in the whole dataset-- N patients in cluster 23)
# % most frequent term:icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453 = 0.02 (27 out of 1172 terms in the whole dataset-- N patients in cluster 22)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.01 (47 out of 4815 terms in the whole dataset-- N patients in cluster 22)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.00 (21 out of 8097 terms in the whole dataset-- N patients in cluster 21)
# % most frequent term:icd9::Other developmental speech or language disorder::315.39::C0154633 = 0.02 (28 out of 1405 terms in the whole dataset-- N patients in cluster 20)
# % most frequent term:icd9::Examination of participant in clinical trial::V70.7::C0949168 = 0.17 (31 out of 182 terms in the whole dataset-- N patients in cluster 18)
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.00 (24 out of 6009 terms in the whole dataset-- N patients in cluster 18)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Autistic disorder, current or active state::299.00::C0154446
# Count matrix:
#  [[  2   0   2]
#  [356 148 306]]
# Chi-squared test statistics: chi2_stat = 0.9211265801582375 -- p_val = 0.6309281498252972 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[230  75 287]
#  [128  73  21]]
# Chi-squared test statistics: chi2_stat = 114.23652108812723 -- p_val = 1.5626245020835864e-25 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[249  14 293]
#  [109 134  15]]
# Chi-squared test statistics: chi2_stat = 339.3538333219169 -- p_val = 2.0429201299970995e-74 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[260  20 304]
#  [ 98 128   4]]
# Chi-squared test statistics: chi2_stat = 358.1025112333141 -- p_val = 1.7339146173761904e-78 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[277  83 297]
#  [ 81  65  11]]
# Chi-squared test statistics: chi2_stat = 109.11030944418985 -- p_val = 2.0276703227389207e-24 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[282 143 290]
#  [ 76   5  18]]
# Chi-squared test statistics: chi2_stat = 49.74646123584671 -- p_val = 1.5764971701979207e-11 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[282  55 304]
#  [ 76  93   4]]
# Chi-squared test statistics: chi2_stat = 226.20150287736297 -- p_val = 7.602698203190545e-50 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[286 109 302]
#  [ 72  39   6]]
# Chi-squared test statistics: chi2_stat = 65.46743060006608 -- p_val = 6.080342914979295e-15 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[288  38 305]
#  [ 70 110   3]]
# Chi-squared test statistics: chi2_stat = 311.7617708735082 -- p_val = 2.0035104898464102e-68 -- dof = 2
# Odds ratio chi2 test for cluster 0term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[290 144 286]
#  [ 68   4  22]]
# Chi-squared test statistics: chi2_stat = 36.62194859995585 -- p_val = 1.1159504283980909e-08 -- dof = 2
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Autistic disorder, current or active state::299.00::C0154446
# Count matrix:
#  [[  2   0   2]
#  [356 148 306]]
# Chi-squared test statistics: chi2_stat = 0.9211265801582375 -- p_val = 0.6309281498252972 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[249  14 293]
#  [109 134  15]]
# Chi-squared test statistics: chi2_stat = 339.3538333219169 -- p_val = 2.0429201299970995e-74 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[260  20 304]
#  [ 98 128   4]]
# Chi-squared test statistics: chi2_stat = 358.1025112333141 -- p_val = 1.7339146173761904e-78 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against diphtheria-tetanus-pertussis, combined [dtp] [dtap]::V06.1::C0260390
# Count matrix:
#  [[306  37 304]
#  [ 52 111   4]]
# Chi-squared test statistics: chi2_stat = 347.0511275525528 -- p_val = 4.353165542082706e-76 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[288  38 305]
#  [ 70 110   3]]
# Chi-squared test statistics: chi2_stat = 311.7617708735082 -- p_val = 2.0035104898464102e-68 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[282  55 304]
#  [ 76  93   4]]
# Chi-squared test statistics: chi2_stat = 226.20150287736297 -- p_val = 7.602698203190545e-50 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against viral hepatitis::V05.3::C0476555
# Count matrix:
#  [[310  55 307]
#  [ 48  93   1]]
# Chi-squared test statistics: chi2_stat = 278.48898881784993 -- p_val = 3.3642204218872825e-61 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against varicella::V05.4::C0375770
# Count matrix:
#  [[329  57 305]
#  [ 29  91   3]]
# Chi-squared test statistics: chi2_stat = 309.84831601877664 -- p_val = 5.215465333066949e-68 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Fever, unspecified::780.60::C0015967
# Count matrix:
#  [[295  61 304]
#  [ 63  87   4]]
# Chi-squared test statistics: chi2_stat = 216.07576940883007 -- p_val = 1.2015527351253098e-47 -- dof = 2
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against poliomyelitis::V04.0::C1962940
# Count matrix:
#  [[336  63 307]
#  [ 22  85   1]]
# Chi-squared test statistics: chi2_stat = 311.4807006673649 -- p_val = 2.305819143052299e-68 -- dof = 2
#
#
#
# Odds ratio chi2 test for cluster 2term: icd9::Autistic disorder, current or active state::299.00::C0154446
# Count matrix:
#  [[  2   0   2]
#  [356 148 306]]
# Chi-squared test statistics: chi2_stat = 0.9211265801582375 -- p_val = 0.6309281498252972 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Attention deficit disorder with hyperactivity::314.01::C1263846
# Count matrix:
#  [[310 130 258]
#  [ 48  18  50]]
# Chi-squared test statistics: chi2_stat = 1.7276364607562142 -- p_val = 0.4215494326932916 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Unspecified delay in development::315.9::n/a
# Count matrix:
#  [[308  86 285]
#  [ 50  62  23]]
# Chi-squared test statistics: chi2_stat = 88.79654374039478 -- p_val = 5.224870378933441e-20 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Other convulsions::780.39::C0490011
# Count matrix:
#  [[294 136 285]
#  [ 64  12  23]]
# Chi-squared test statistics: chi2_stat = 19.576051136944997 -- p_val = 5.611959224801307e-05 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Unspecified pervasive developmental disorder, current or active state::299.90::C0154453
# Count matrix:
#  [[314 110 286]
#  [ 44  38  22]]
# Chi-squared test statistics: chi2_stat = 30.945111061729207 -- p_val = 1.907016769231381e-07 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[290 144 286]
#  [ 68   4  22]]
# Chi-squared test statistics: chi2_stat = 36.62194859995585 -- p_val = 1.1159504283980909e-08 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[230  75 287]
#  [128  73  21]]
# Chi-squared test statistics: chi2_stat = 114.23652108812723 -- p_val = 1.5626245020835864e-25 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Other developmental speech or language disorder::315.39::C0154633
# Count matrix:
#  [[320  74 288]
#  [ 38  74  20]]
# Chi-squared test statistics: chi2_stat = 154.02586207569087 -- p_val = 3.5785658656025907e-34 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Examination of participant in clinical trial::V70.7::C0949168
# Count matrix:
#  [[354 147 290]
#  [  4   1  18]]
# Chi-squared test statistics: chi2_stat = 16.517385834048845 -- p_val = 0.0002589973010373038 -- dof = 2
# Odds ratio chi2 test for cluster 2term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[282 143 290]
#  [ 76   5  18]]
# Chi-squared test statistics: chi2_stat = 49.74646123584671 -- p_val = 1.5764971701979207e-11 -- dof = 2
#
#
#
# Inspecting disease: mental retardation
#
# 3 0.12554395854681963
# 4 0.13536284881684146
# 5 0.15402354044720365
# 6 0.1146504161581859
# 7 0.11684868847338299
# 8 0.11228916686710223
# 9 0.11428097350954823
# 10 0.06506301584389475
# Number of clusters found:5, Silhouette score:0.154
#
# Cluster 0 numerosity: 695
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.61 (3666 out of 6009 terms in the whole dataset-- N patients in cluster 575)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.26 (2086 out of 8097 terms in the whole dataset-- N patients in cluster 464)
# % most frequent term:icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841 = 0.36 (1716 out of 4718 terms in the whole dataset-- N patients in cluster 329)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.64 (3091 out of 4815 terms in the whole dataset-- N patients in cluster 298)
# % most frequent term:icd9::Constipation, unspecified::564.00::C0009806 = 0.43 (1673 out of 3926 terms in the whole dataset-- N patients in cluster 297)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.15 (1066 out of 7284 terms in the whole dataset-- N patients in cluster 291)
# % most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.58 (2060 out of 3524 terms in the whole dataset-- N patients in cluster 271)
# % most frequent term:icd9::Severe intellectual disabilities::318.1::C0036857 = 0.71 (992 out of 1398 terms in the whole dataset-- N patients in cluster 261)
# % most frequent term:icd9::Profound intellectual disabilities::318.2::C3161330 = 0.80 (1740 out of 2187 terms in the whole dataset-- N patients in cluster 251)
# % most frequent term:icd9::Anemia, unspecified::285.9::C0002871 = 0.48 (867 out of 1807 terms in the whole dataset-- N patients in cluster 229)
#
#
# Cluster 1 numerosity: 133
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.07 (401 out of 6009 terms in the whole dataset-- N patients in cluster 91)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.05 (357 out of 7284 terms in the whole dataset-- N patients in cluster 87)
# % most frequent term:icd9::Cough::786.2::C0010200 = 0.05 (203 out of 4215 terms in the whole dataset-- N patients in cluster 65)
# % most frequent term:icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222 = 0.04 (163 out of 3942 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Routine infant or child health check::V20.2::C0260545 = 0.04 (511 out of 12937 terms in the whole dataset-- N patients in cluster 61)
# % most frequent term:icd9::Routine general medical examination at a health care facility::V70.0::C0260851 = 0.04 (146 out of 3284 terms in the whole dataset-- N patients in cluster 61)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.03 (270 out of 8097 terms in the whole dataset-- N patients in cluster 59)
# % most frequent term:icd9::Dental examination::V72.2::C0490066 = 0.06 (263 out of 4334 terms in the whole dataset-- N patients in cluster 52)
# % most frequent term:icd9::Asthma, unspecified type, unspecified::493.90::C0155886 = 0.05 (534 out of 10742 terms in the whole dataset-- N patients in cluster 52)
# % most frequent term:icd9::Screening examination for pulmonary tuberculosis::V74.1::C2910575 = 0.09 (137 out of 1542 terms in the whole dataset-- N patients in cluster 50)
#
#
# Cluster 2 numerosity: 405
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.13 (802 out of 6009 terms in the whole dataset-- N patients in cluster 272)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.02 (161 out of 8097 terms in the whole dataset-- N patients in cluster 106)
# % most frequent term:icd9::Mild intellectual disabilities::317::C0026106 = 0.09 (203 out of 2260 terms in the whole dataset-- N patients in cluster 98)
# % most frequent term:icd9::Other convulsions::780.39::C0490011 = 0.08 (270 out of 3524 terms in the whole dataset-- N patients in cluster 97)
# % most frequent term:icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721 = 0.07 (356 out of 4815 terms in the whole dataset-- N patients in cluster 87)
# % most frequent term:icd9::Infantile cerebral palsy, unspecified::343.9::C0392549 = 0.12 (392 out of 3347 terms in the whole dataset-- N patients in cluster 84)
# % most frequent term:icd9::Severe intellectual disabilities::318.1::C0036857 = 0.12 (165 out of 1398 terms in the whole dataset-- N patients in cluster 75)
# % most frequent term:icd9::Profound intellectual disabilities::318.2::C3161330 = 0.12 (268 out of 2187 terms in the whole dataset-- N patients in cluster 62)
# % most frequent term:icd9::Generalized convulsive epilepsy, without mention of intractable epilepsy::345.10::C0154709 = 0.14 (230 out of 1653 terms in the whole dataset-- N patients in cluster 58)
# % most frequent term:icd9::Moderate intellectual disabilities::318.0::C0026351 = 0.14 (120 out of 847 terms in the whole dataset-- N patients in cluster 51)
#
#
# Cluster 3 numerosity: 87
# % most frequent term:icd9::Unspecified intellectual disabilities::319::C3161331 = 0.10 (573 out of 6009 terms in the whole dataset-- N patients in cluster 77)
# % most frequent term:icd9::Unspecified essential hypertension::401.9::C0085580 = 0.22 (1091 out of 4906 terms in the whole dataset-- N patients in cluster 69)
# % most frequent term:icd9::Other and unspecified hyperlipidemia::272.4::C0348494 = 0.27 (651 out of 2395 terms in the whole dataset-- N patients in cluster 63)
# % most frequent term:icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113 = 0.34 (1151 out of 3407 terms in the whole dataset-- N patients in cluster 57)
# % most frequent term:icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452 = 0.03 (192 out of 7284 terms in the whole dataset-- N patients in cluster 51)
# % most frequent term:icd9::Pure hypercholesterolemia::272.0::C0678189 = 0.23 (365 out of 1622 terms in the whole dataset-- N patients in cluster 41)
# % most frequent term:icd9::Unspecified vitamin d deficiency::268.9::C0042870 = 0.11 (234 out of 2227 terms in the whole dataset-- N patients in cluster 31)
# % most frequent term:icd9::Benign essential hypertension::401.1::C0155583 = 0.31 (278 out of 893 terms in the whole dataset-- N patients in cluster 30)
# % most frequent term:icd9::Other abnormal glucose::790.29::C1260443 = 0.15 (96 out of 629 terms in the whole dataset-- N patients in cluster 30)
# % most frequent term:icd9::Personal history of allergy to medicinal agents::V14::C0260483 = 0.01 (99 out of 8097 terms in the whole dataset-- N patients in cluster 29)
#
#
# Cluster 4 numerosity: 79
# % most frequent term:icd9::Family history of intellectual disabilities::V18.4::C0260530 = 0.50 (176 out of 349 terms in the whole dataset-- N patients in cluster 77)
# % most frequent term:icd9::Supervision of other normal pregnancy::V22.1::C0038843 = 0.44 (475 out of 1073 terms in the whole dataset-- N patients in cluster 74)
# % most frequent term:icd9::Outcome of delivery, single liveborn::V27.0::C1313895 = 0.45 (121 out of 268 terms in the whole dataset-- N patients in cluster 73)
# % most frequent term:icd9::Encounter for routine screening for malformation using ultrasonics::V28.3::C2349862 = 0.40 (92 out of 231 terms in the whole dataset-- N patients in cluster 56)
# % most frequent term:icd9::Supervision of normal first pregnancy::V22.0::C0260550 = 0.33 (235 out of 714 terms in the whole dataset-- N patients in cluster 47)
# % most frequent term:icd9::Suspected problem with fetal growth not found::V89.04::C2349931 = 0.52 (78 out of 151 terms in the whole dataset-- N patients in cluster 45)
# % most frequent term:icd9::Other known or suspected fetal abnormality, not elsewhere classified, affecting management of mother, antepartum condition or complication::655.83::C0157095 = 0.58 (99 out of 172 terms in the whole dataset-- N patients in cluster 44)
# % most frequent term:icd9::Other investigation and testing::V26.29::C0878723 = 0.56 (95 out of 170 terms in the whole dataset-- N patients in cluster 41)
# % most frequent term:icd9::Screening for genetic disease carrier status::V82.71::C1719700 = 0.48 (89 out of 185 terms in the whole dataset-- N patients in cluster 40)
# % most frequent term:icd9::Abnormality in fetal heart rate or rhythm, delivered, with or without mention of antepartum condition::659.71::C0695247 = 0.41 (41 out of 99 terms in the whole dataset-- N patients in cluster 37)
#
#
# Odds ratio chi2 test for cluster 0term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[120  42 133  10  76]
#  [575  91 272  77   3]]
# Chi-squared test statistics: chi2_stat = 243.03374122151303 -- p_val = 2.0610547610962828e-51 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[231  74 299  58  48]
#  [464  59 106  29  31]]
# Chi-squared test statistics: chi2_stat = 184.82955337088958 -- p_val = 6.842077972644696e-39 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Personal history of allergy, other than to medicinal agents, presenting hazards to health::V15.0::C0877841
# Count matrix:
#  [[366 103 360  68  77]
#  [329  30  45  19   2]]
# Chi-squared test statistics: chi2_stat = 201.41436535333207 -- p_val = 1.8654254600043916e-42 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[397 111 318  77  76]
#  [298  22  87  10   3]]
# Chi-squared test statistics: chi2_stat = 120.3166500631111 -- p_val = 4.571165875304994e-25 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Constipation, unspecified::564.00::C0009806
# Count matrix:
#  [[398 100 368  64  76]
#  [297  33  37  23   3]]
# Chi-squared test statistics: chi2_stat = 169.71366014106462 -- p_val = 1.2048189740190368e-35 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[404  46 365  36  53]
#  [291  87  40  51  26]]
# Chi-squared test statistics: chi2_stat = 201.2578559828471 -- p_val = 2.0157153267505348e-42 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Other convulsions::780.39::C0490011
# Count matrix:
#  [[424 101 308  80  79]
#  [271  32  97   7   0]]
# Chi-squared test statistics: chi2_stat = 90.94044484771473 -- p_val = 8.31204836529783e-19 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Severe intellectual disabilities::318.1::C0036857
# Count matrix:
#  [[434 109 330  74  79]
#  [261  24  75  13   0]]
# Chi-squared test statistics: chi2_stat = 95.78510929195822 -- p_val = 7.758370632129793e-20 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Profound intellectual disabilities::318.2::C3161330
# Count matrix:
#  [[444 112 343  71  79]
#  [251  21  62  16   0]]
# Chi-squared test statistics: chi2_stat = 100.4111143605233 -- p_val = 8.041196073168349e-21 -- dof = 4
# Odds ratio chi2 test for cluster 0term: icd9::Anemia, unspecified::285.9::C0002871
# Count matrix:
#  [[466 116 384  61  66]
#  [229  17  21  26  13]]
# Chi-squared test statistics: chi2_stat = 126.95717840711329 -- p_val = 1.7418650946748814e-26 -- dof = 4
#
#
#
# Odds ratio chi2 test for cluster 1term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[120  42 133  10  76]
#  [575  91 272  77   3]]
# Chi-squared test statistics: chi2_stat = 243.03374122151303 -- p_val = 2.0610547610962828e-51 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[404  46 365  36  53]
#  [291  87  40  51  26]]
# Chi-squared test statistics: chi2_stat = 201.2578559828471 -- p_val = 2.0157153267505348e-42 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Cough::786.2::C0010200
# Count matrix:
#  [[467  68 368  63  76]
#  [228  65  37  24   3]]
# Chi-squared test statistics: chi2_stat = 134.57988349075958 -- p_val = 4.080433971725017e-28 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Acute upper respiratory infections of unspecified site::465.9::C0264222
# Count matrix:
#  [[514  71 379  71  75]
#  [181  62  26  16   4]]
# Chi-squared test statistics: chi2_stat = 129.06508436193118 -- p_val = 6.1706376309356206e-27 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Routine infant or child health check::V20.2::C0260545
# Count matrix:
#  [[620  72 376  85  77]
#  [ 75  61  29   2   2]]
# Chi-squared test statistics: chi2_stat = 167.86739149064027 -- p_val = 3.000123371060452e-35 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Routine general medical examination at a health care facility::V70.0::C0260851
# Count matrix:
#  [[502  72 371  58  69]
#  [193  61  34  29  10]]
# Chi-squared test statistics: chi2_stat = 105.6783001211264 -- p_val = 6.072211576640146e-22 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[231  74 299  58  48]
#  [464  59 106  29  31]]
# Chi-squared test statistics: chi2_stat = 184.82955337088958 -- p_val = 6.842077972644696e-39 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Dental examination::V72.2::C0490066
# Count matrix:
#  [[533  81 382  81  71]
#  [162  52  23   6   8]]
# Chi-squared test statistics: chi2_stat = 105.88717721929355 -- p_val = 5.480642186309865e-22 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Asthma, unspecified type, unspecified::493.90::C0155886
# Count matrix:
#  [[523  81 370  75  69]
#  [172  52  35  12  10]]
# Chi-squared test statistics: chi2_stat = 77.26676277991444 -- p_val = 6.603843483409225e-16 -- dof = 4
# Odds ratio chi2 test for cluster 1term: icd9::Screening examination for pulmonary tuberculosis::V74.1::C2910575
# Count matrix:
#  [[561  83 388  71  66]
#  [134  50  17  16  13]]
# Chi-squared test statistics: chi2_stat = 91.83339535778433 -- p_val = 5.369811080450988e-19 -- dof = 4
#
#
#
# Odds ratio chi2 test for cluster 2term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[120  42 133  10  76]
#  [575  91 272  77   3]]
# Chi-squared test statistics: chi2_stat = 243.03374122151303 -- p_val = 2.0610547610962828e-51 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[231  74 299  58  48]
#  [464  59 106  29  31]]
# Chi-squared test statistics: chi2_stat = 184.82955337088958 -- p_val = 6.842077972644696e-39 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Mild intellectual disabilities::317::C0026106
# Count matrix:
#  [[493  90 307  65  78]
#  [202  43  98  22   1]]
# Chi-squared test statistics: chi2_stat = 31.843266415770422 -- p_val = 2.0595143959421333e-06 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Other convulsions::780.39::C0490011
# Count matrix:
#  [[424 101 308  80  79]
#  [271  32  97   7   0]]
# Chi-squared test statistics: chi2_stat = 90.94044484771473 -- p_val = 8.31204836529783e-19 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Epilepsy, unspecified, without mention of intractable epilepsy::345.90::C0154721
# Count matrix:
#  [[397 111 318  77  76]
#  [298  22  87  10   3]]
# Chi-squared test statistics: chi2_stat = 120.3166500631111 -- p_val = 4.571165875304994e-25 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Infantile cerebral palsy, unspecified::343.9::C0392549
# Count matrix:
#  [[486  97 321  85  79]
#  [209  36  84   2   0]]
# Chi-squared test statistics: chi2_stat = 65.0491581232149 -- p_val = 2.512569715465072e-13 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Severe intellectual disabilities::318.1::C0036857
# Count matrix:
#  [[434 109 330  74  79]
#  [261  24  75  13   0]]
# Chi-squared test statistics: chi2_stat = 95.78510929195822 -- p_val = 7.758370632129793e-20 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Profound intellectual disabilities::318.2::C3161330
# Count matrix:
#  [[444 112 343  71  79]
#  [251  21  62  16   0]]
# Chi-squared test statistics: chi2_stat = 100.4111143605233 -- p_val = 8.041196073168349e-21 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Generalized convulsive epilepsy, without mention of intractable epilepsy::345.10::C0154709
# Count matrix:
#  [[512 118 347  84  79]
#  [183  15  58   3   0]]
# Chi-squared test statistics: chi2_stat = 68.5259812181145 -- p_val = 4.6461303118887943e-14 -- dof = 4
# Odds ratio chi2 test for cluster 2term: icd9::Moderate intellectual disabilities::318.0::C0026351
# Count matrix:
#  [[566 102 354  81  79]
#  [129  31  51   6   0]]
# Chi-squared test statistics: chi2_stat = 33.16577150291359 -- p_val = 1.1046746254230323e-06 -- dof = 4
#
#
#
# Odds ratio chi2 test for cluster 3term: icd9::Unspecified intellectual disabilities::319::C3161331
# Count matrix:
#  [[120  42 133  10  76]
#  [575  91 272  77   3]]
# Chi-squared test statistics: chi2_stat = 243.03374122151303 -- p_val = 2.0610547610962828e-51 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Unspecified essential hypertension::401.9::C0085580
# Count matrix:
#  [[470 112 354  18  79]
#  [225  21  51  69   0]]
# Chi-squared test statistics: chi2_stat = 215.1059831353702 -- p_val = 2.1182199131145327e-45 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Other and unspecified hyperlipidemia::272.4::C0348494
# Count matrix:
#  [[573 119 367  24  79]
#  [122  14  38  63   0]]
# Chi-squared test statistics: chi2_stat = 226.8969933094752 -- p_val = 6.145454604754681e-48 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Diabetes mellitus without mention of complication, type ii or unspecified type, not stated as uncontrolled::250.00::C0375113
# Count matrix:
#  [[565 127 374  30  79]
#  [130   6  31  57   0]]
# Chi-squared test statistics: chi2_stat = 211.47937721462688 -- p_val = 1.2769169478658243e-44 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Need for prophylactic vaccination and inoculation against influenza::V04.81::C1260452
# Count matrix:
#  [[404  46 365  36  53]
#  [291  87  40  51  26]]
# Chi-squared test statistics: chi2_stat = 201.2578559828471 -- p_val = 2.0157153267505348e-42 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Pure hypercholesterolemia::272.0::C0678189
# Count matrix:
#  [[588 132 386  46  78]
#  [107   1  19  41   1]]
# Chi-squared test statistics: chi2_stat = 153.39230973434744 -- p_val = 3.8166530661661577e-32 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Unspecified vitamin d deficiency::268.9::C0042870
# Count matrix:
#  [[601 123 382  56  79]
#  [ 94  10  23  31   0]]
# Chi-squared test statistics: chi2_stat = 79.58970178689219 -- p_val = 2.1277529382917157e-16 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Benign essential hypertension::401.1::C0155583
# Count matrix:
#  [[625 129 392  57  79]
#  [ 70   4  13  30   0]]
# Chi-squared test statistics: chi2_stat = 106.31844135765574 -- p_val = 4.435230584044742e-22 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Other abnormal glucose::790.29::C1260443
# Count matrix:
#  [[629 128 392  57  78]
#  [ 66   5  13  30   1]]
# Chi-squared test statistics: chi2_stat = 103.0848825727768 -- p_val = 2.167266974377748e-21 -- dof = 4
# Odds ratio chi2 test for cluster 3term: icd9::Personal history of allergy to medicinal agents::V14::C0260483
# Count matrix:
#  [[231  74 299  58  48]
#  [464  59 106  29  31]]
# Chi-squared test statistics: chi2_stat = 184.82955337088958 -- p_val = 6.842077972644696e-39 -- dof = 4
#
#
#
# Odds ratio chi2 test for cluster 4term: icd9::Family history of intellectual disabilities::V18.4::C0260530
# Count matrix:
#  [[667 121 364  87   2]
#  [ 28  12  41   0  77]]
# Chi-squared test statistics: chi2_stat = 634.5181010779114 -- p_val = 5.235109618918188e-136 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Supervision of other normal pregnancy::V22.1::C0038843
# Count matrix:
#  [[672 122 397  87   5]
#  [ 23  11   8   0  74]]
# Chi-squared test statistics: chi2_stat = 809.1280913426341 -- p_val = 8.09332229141927e-174 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Outcome of delivery, single liveborn::V27.0::C1313895
# Count matrix:
#  [[674 125 401  87   6]
#  [ 21   8   4   0  73]]
# Chi-squared test statistics: chi2_stat = 865.0807102753571 -- p_val = 6.125479521177571e-186 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Encounter for routine screening for malformation using ultrasonics::V28.3::C2349862
# Count matrix:
#  [[676 127 397  87  23]
#  [ 19   6   8   0  56]]
# Chi-squared test statistics: chi2_stat = 587.2514035526244 -- p_val = 8.897102697409208e-126 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Supervision of normal first pregnancy::V22.0::C0260550
# Count matrix:
#  [[687 125 402  87  32]
#  [  8   8   3   0  47]]
# Chi-squared test statistics: chi2_stat = 566.0369152908632 -- p_val = 3.4673056915977354e-121 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Suspected problem with fetal growth not found::V89.04::C2349931
# Count matrix:
#  [[680 126 403  87  34]
#  [ 15   7   2   0  45]]
# Chi-squared test statistics: chi2_stat = 489.0721528389088 -- p_val = 1.546844638826197e-104 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Other known or suspected fetal abnormality, not elsewhere classified, affecting management of mother, antepartum condition or complication::655.83::C0157095
# Count matrix:
#  [[683 127 399  87  35]
#  [ 12   6   6   0  44]]
# Chi-squared test statistics: chi2_stat = 470.72191126515474 -- p_val = 1.4375119064740168e-100 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Other investigation and testing::V26.29::C0878723
# Count matrix:
#  [[682 130 386  87  38]
#  [ 13   3  19   0  41]]
# Chi-squared test statistics: chi2_stat = 357.22811993351286 -- p_val = 4.822138676584917e-76 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Screening for genetic disease carrier status::V82.71::C1719700
# Count matrix:
#  [[680 128 381  87  39]
#  [ 15   5  24   0  40]]
# Chi-squared test statistics: chi2_stat = 303.75942266376785 -- p_val = 1.6742847036386475e-64 -- dof = 4
# Odds ratio chi2 test for cluster 4term: icd9::Abnormality in fetal heart rate or rhythm, delivered, with or without mention of antepartum condition::659.71::C0695247
# Count matrix:
#  [[688 128 402  87  42]
#  [  7   5   3   0  37]]
# Chi-squared test statistics: chi2_stat = 438.0538103538458 -- p_val = 1.6607317303452862e-93 -- dof = 4

# %%
encoded_new_disease_dict = {}
for idx, nd in enumerate(set(en_sub_clust)):
    encoded_new_disease_dict[nd] = idx
colors_en3 = [colormap[encoded_new_disease_dict[v]] for v in en_sub_clust]
single_plot(encoded_subplots, en_sub_clust, colors_en3)
